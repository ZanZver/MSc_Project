# %% [markdown]
# # Install libraries

# %%
# !pip3 install polars
# !pip3 install Web3

# %% [markdown]
# # Import libraries

# %%
from web3 import Web3
import polars as pl
import json

# %% [markdown]
# # Functions

# %%
def create_connection(node_ip="http://127.0.0.1:8545"):
    # Connect to the local Ethereum node
    w3 = Web3(Web3.HTTPProvider(node_ip))

    # Check connection
    if not w3.is_connected():
        raise Exception("Failed to connect to the Ethereum node.")

    # Use the first account for transactions (ensure it's unlocked)
    account = w3.eth.accounts[0]
    
    return account, w3

# %%
def read_data(data_path='data.parquet'):
    """
    Load data from a Parquet file using Polars.
    
    Args:
        data_path (str): Path to the Parquet file.
    
    Returns:
        list[dict]: Data loaded from the Parquet file, converted to a list of dictionaries.
    """
    # Load data from a Parquet file into a Polars DataFrame
    df = pl.read_parquet(data_path)
    
    # Convert Polars DataFrame to a list of dictionaries
    return df.to_dicts()

# %%
# Function to store data in blockchain
def store_data_in_blockchain(data_to_store, account, w3):
    # Convert the data to hexadecimal (Ethereum stores data in hex)
    data_hex = Web3.to_hex(text=json.dumps(data_to_store))

    # Create and send a transaction
    tx = {
        'from': account,
        'to': None,  # Null address for data-only transaction
        'value': 0,  # No Ether transfer
        'gas': 3000000,  # Gas limit
        'gasPrice': w3.to_wei('20', 'gwei'),
        'data': data_hex
    }
    tx_hash = w3.eth.send_transaction(tx)
    return tx_hash

# %%
# Function to retrieve data from blockchain
def retrieve_data_from_blockchain(w3, tx_hash):
    # Get the transaction details
    tx = w3.eth.get_transaction(tx_hash)
    # Decode the `input` field from HexBytes to text
    return Web3.to_text(hexstr=tx['input'].hex())

# %%
# Store data
def store_data(data, account, w3, tx_hashes):
    for record in data:
        tx_hash = store_data_in_blockchain(record, account, w3)
        #print(f"Stored record with transaction hash: {tx_hash.hex()}")
        tx_hashes.append(tx_hash)
    return tx_hashes

# %%
# Retrieve data
def retrive_data(w3, tx_hashes) -> None:
    for tx_hash in tx_hashes:
        stored_data = retrieve_data_from_blockchain(w3, tx_hash)
        print(f"Retrieved data from transaction {tx_hash.hex()}: {stored_data}")

# %%
# Function to append new data to the blockchain
def append_data_to_blockchain(record, Web3, account, w3):
    """
    Add a new record (or update) to the blockchain.
    
    Args:
        record (dict): The record to store or update.
    
    Returns:
        str: Transaction hash of the appended record.
    """
    # Convert the data to hexadecimal (Ethereum stores data in hex)
    data_hex = Web3.to_hex(text=json.dumps(record))

    # Create and send a transaction
    tx = {
        'from': account,
        'to': None,  # Null address for data-only transaction
        'value': 0,  # No Ether transfer
        'gas': 3000000,  # Gas limit
        'gasPrice': w3.to_wei('20', 'gwei'),
        'data': data_hex
    }
    tx_hash = w3.eth.send_transaction(tx)
    return tx_hash

# %%
# Function to fetch and decode the latest transaction for a specific key
def get_latest_record(key, w3, key_field='vin'):
    """
    Fetch the latest record for a given key from the blockchain.

    Args:
        key (str): The unique identifier for the record.
        key_field (str): The field name used as the key in the record.

    Returns:
        dict or None: The latest record if found, otherwise None.
    """
    latest_record = None

    # Iterate through the blockchain's transactions
    for block_number in range(w3.eth.block_number + 1):
        block = w3.eth.get_block(block_number, full_transactions=True)
        for tx in block.transactions:
            if tx.to is None:  # Data-only transactions
                # Decode the transaction input (data field)
                data_hex = tx.input.hex()  # Convert HexBytes to a hex string
                try:
                    record = json.loads(Web3.to_text(hexstr=data_hex))
                    if record.get(key_field) == key:
                        latest_record = record
                except Exception as e:
                    print(f"Error decoding transaction: {e}")

    return latest_record

# %%
def get_record_history(w3, key, key_field='vin'):
    """
    Fetch the history of a specific record from the blockchain.

    Args:
        key (str): The unique identifier for the record.
        key_field (str): The field name used as the key in the record.

    Returns:
        list[dict]: A list of all records matching the key in their history.
    """
    history = []

    # Iterate through all blocks
    for block_number in range(w3.eth.block_number + 1):
        block = w3.eth.get_block(block_number, full_transactions=True)
        for tx in block.transactions:
            if tx.to is None:  # Data-only transactions
                try:
                    # Decode the transaction input (data field)
                    data_hex = tx.input.hex()  # Convert HexBytes to a hex string
                    record = json.loads(Web3.to_text(hexstr=data_hex))
                    
                    # Check if the transaction contains the relevant key
                    if record.get(key_field) == key:
                        history.append(record)
                except Exception as e:
                    print(f"Error decoding transaction: {e}")

    return history

# %%
# Function to append a "deleted" record to the blockchain
def delete_record(key, w3, account, key_field='vin') -> None:
    """
    Mark a record as deleted on the blockchain.

    Args:
        key (str): The unique identifier for the record to delete.
        key_field (str): The field name used as the key in the record.

    Returns:
        str: Transaction hash of the deletion transaction.
    """
    # Create the deletion record
    deletion_record = {
        key_field: key,
        "deleted": True
    }

    # Convert the data to hexadecimal (Ethereum stores data in hex)
    data_hex = Web3.to_hex(text=json.dumps(deletion_record))

    # Create and send a transaction
    tx = {
        'from': account,
        'to': None,  # Null address for data-only transaction
        'value': 0,  # No Ether transfer
        'gas': 3000000,  # Gas limit
        'gasPrice': w3.to_wei('20', 'gwei'),
        'data': data_hex
    }
    # tx_hash = 
    w3.eth.send_transaction(tx)
    # return tx_hash

# %% [markdown]
# # Main

# %% [markdown]
# ## Create connection

# %%
tx_hashes = []

account, w3 = create_connection()

# %% [markdown]
# ## Read data from parquet

# %%
data = read_data("../Data/Transform/Small/data.parquet")

# %% [markdown]
# ## Save data to blockchain

# %%
tx_hashes = store_data(data, account, w3, tx_hashes)

# %% [markdown]
# ## Retrive data from blockchain

# %%
retrive_data(w3, tx_hashes)

# %% [markdown]
# # Testing

# %% [markdown]
# ## Test 1 - fetch data from blockchain

# %%
# Retrieve the latest record for a specific VIN
vin = "82HFE9767U326DEZ2"
latest_record = get_latest_record(vin, w3)
print(f"Latest record for VIN {vin}: {latest_record}")
# Out:
# Latest record for VIN 82HFE9767U326DEZ2: {'vin': '82HFE9767U326DEZ2', 'license_plate': 'WU37 WRN', 'vehicle_make': 'Mitsubishi', 'vehicle_model': 'Outlander', 'vehicle_year': 2000, 'full_vehicleInfo': {'Year': 2000, 'Make': 'Mitsubishi', 'Model': 'Outlander', 'Category': 'SUV'}, 'vehicle_category': 'SUV', 'vehicle_make_model': 'Mitsubishi Outlander', 'vehicle_year_make_model': '2000 Mitsubishi Outlander', 'vehicle_year_make_model_cat': '2000 Mitsubishi Outlander (SUV)'}

# %%
# Function to fetch and decode the latest transaction for a specific key
def get_all_data(w3):
    latest_record = []

    # Iterate through the blockchain's transactions
    for block_number in range(w3.eth.block_number + 1):
        block = w3.eth.get_block(block_number, full_transactions=True)
        for tx in block.transactions:
            if tx.to is None:  # Data-only transactions
                # Decode the transaction input (data field)
                data_hex = tx.input.hex()  # Convert HexBytes to a hex string
                try:
                    record = json.loads(Web3.to_text(hexstr=data_hex))
                    latest_record.append(record)
                except Exception as e:
                    print(f"Error decoding transaction: {e}")

    return latest_record

# %%
get_all_data(w3)
# Out:
# [{'vin': '82HFE9767U326DEZ2',
#   'license_plate': 'WU37 WRN',
#   'vehicle_make': 'Mitsubishi',
#   'vehicle_model': 'Montero',
#   'vehicle_year': 1999,
#   'full_vehicleInfo': {'Year': 1999,
#    'Make': 'Mitsubishi',
#    'Model': 'Montero',
#    'Category': 'SUV'},
#   'vehicle_category': 'SUV',
#   'vehicle_make_model': 'Mitsubishi Montero',
#   'vehicle_year_make_model': '1999 Mitsubishi Montero',
#   'vehicle_year_make_model_cat': '1999 Mitsubishi Montero (SUV)'},
#  {'vin': 'H1AUMH0D9M76R7NNG',
#   'license_plate': 'XO18 RDM',
#   'vehicle_make': 'Ferrari',
#   'vehicle_model': '612 Scaglietti',
#   'vehicle_year': 2006,
#   'full_vehicleInfo': {'Year': 2006,
#    'Make': 'Ferrari',
#    'Model': '612 Scaglietti',
#    'Category': 'Coupe'},
#   'vehicle_category': 'Coupe',
#   'vehicle_make_model': 'Ferrari 612 Scaglietti',
#   'vehicle_year_make_model': '2006 Ferrari 612 Scaglietti',
#   'vehicle_year_make_model_cat': '2006 Ferrari 612 Scaglietti (Coupe)'},
#  {'vin': 'JPC53EJ63E7RHWPAP',
#   'license_plate': 'GV19IWV',
#   'vehicle_make': 'GMC',
#   'vehicle_model': 'Envoy',
#   'vehicle_year': 2002,
#   'full_vehicleInfo': {'Year': 2002,
#    'Make': 'GMC',
#    'Model': 'Envoy',
#    'Category': 'SUV'},
#   'vehicle_category': 'SUV',
#   'vehicle_make_model': 'GMC Envoy',
#   'vehicle_year_make_model': '2002 GMC Envoy',
#   'vehicle_year_make_model_cat': '2002 GMC Envoy (SUV)'},
#  {'vin': 'AFAWRHEL34E3LSH5D',
#   'license_plate': 'GU72PMU',
#   'vehicle_make': 'GMC',
#   'vehicle_model': 'Suburban 2500',
#   'vehicle_year': 1995,
#   'full_vehicleInfo': {'Year': 1995,
#    'Make': 'GMC',
#    'Model': 'Suburban 2500',
#    'Category': 'SUV'},
#   'vehicle_category': 'SUV',
#   'vehicle_make_model': 'GMC Suburban 2500',
#   'vehicle_year_make_model': '1995 GMC Suburban 2500',
#   'vehicle_year_make_model_cat': '1995 GMC Suburban 2500 (SUV)'},
#  {'vin': 'G9FGUSPE39ZY6480A',
#   'license_plate': 'TC78MMT',
#   'vehicle_make': 'GMC',
#   'vehicle_model': 'Terrain',
#   'vehicle_year': 2019,
#   'full_vehicleInfo': {'Year': 2019,
#    'Make': 'GMC',
#    'Model': 'Terrain',
#    'Category': 'SUV'},
#   'vehicle_category': 'SUV',
#   'vehicle_make_model': 'GMC Terrain',
#   'vehicle_year_make_model': '2019 GMC Terrain',
#   'vehicle_year_make_model_cat': '2019 GMC Terrain (SUV)'},
#  {'vin': 'G18HM8JU4AW1GZBZ7',
#   'license_plate': 'UQ52TGE',
#   'vehicle_make': 'Jeep',
#   'vehicle_model': 'Grand Cherokee',
#   'vehicle_year': 1999,
#   'full_vehicleInfo': {'Year': 1999,
#    'Make': 'Jeep',
#    'Model': 'Grand Cherokee',
#    'Category': 'SUV'},
#   'vehicle_category': 'SUV',
#   'vehicle_make_model': 'Jeep Grand Cherokee',
#   'vehicle_year_make_model': '1999 Jeep Grand Cherokee',
#   'vehicle_year_make_model_cat': '1999 Jeep Grand Cherokee (SUV)'},
#  {'vin': '1LY28PKF94F66Y599',
#   'license_plate': 'RF63IQT',
#   'vehicle_make': 'Ford',
#   'vehicle_model': 'Econoline E250 Cargo',
#   'vehicle_year': 1997,
#   'full_vehicleInfo': {'Year': 1997,
#    'Make': 'Ford',
#    'Model': 'Econoline E250 Cargo',
#    'Category': 'Van/Minivan'},
#   'vehicle_category': 'Van/Minivan',
#   'vehicle_make_model': 'Ford Econoline E250 Cargo',
#   'vehicle_year_make_model': '1997 Ford Econoline E250 Cargo',
#   'vehicle_year_make_model_cat': '1997 Ford Econoline E250 Cargo (Van/Minivan)'},
#  {'vin': 'CKSPVV8F5E5M2EE15',
#   'license_plate': 'HC83 BKC',
#   'vehicle_make': 'BMW',
#   'vehicle_model': 'i3',
#   'vehicle_year': 2018,
#   'full_vehicleInfo': {'Year': 2018,
#    'Make': 'BMW',
#    'Model': 'i3',
#    'Category': 'Hatchback'},
#   'vehicle_category': 'Hatchback',
#   'vehicle_make_model': 'BMW i3',
#   'vehicle_year_make_model': '2018 BMW i3',
#   'vehicle_year_make_model_cat': '2018 BMW i3 (Hatchback)'},
#  {'vin': 'HYD9XFXT2C77UNUTW',
#   'license_plate': 'VU65 UDB',
#   'vehicle_make': 'GMC',
#   'vehicle_model': 'Savana 2500 Cargo',
#   'vehicle_year': 2013,
#   'full_vehicleInfo': {'Year': 2013,
#    'Make': 'GMC',
#    'Model': 'Savana 2500 Cargo',
#    'Category': 'Van/Minivan'},
#   'vehicle_category': 'Van/Minivan',
#   'vehicle_make_model': 'GMC Savana 2500 Cargo',
#   'vehicle_year_make_model': '2013 GMC Savana 2500 Cargo',
#   'vehicle_year_make_model_cat': '2013 GMC Savana 2500 Cargo (Van/Minivan)'},
#  {'vin': '7FCCV9UB3HWF5V741',
#   'license_plate': 'YH73 FNP',
#   'vehicle_make': 'Ford',
#   'vehicle_model': 'Escape',
#   'vehicle_year': 2009,
#   'full_vehicleInfo': {'Year': 2009,
#    'Make': 'Ford',
#    'Model': 'Escape',
#    'Category': 'SUV'},
#   'vehicle_category': 'SUV',
#   'vehicle_make_model': 'Ford Escape',
#   'vehicle_year_make_model': '2009 Ford Escape',
#   'vehicle_year_make_model_cat': '2009 Ford Escape (SUV)'},
#  {'vin': 'S4AR1RGW6JUY0CJD4',
#   'license_plate': 'XK78 BBS',
#   'vehicle_make': 'Mitsubishi',
#   'vehicle_model': 'Outlander',
#   'vehicle_year': 2019,
#   'full_vehicleInfo': {'Year': 2019,
#    'Make': 'Mitsubishi',
#    'Model': 'Outlander',
#    'Category': 'SUV'},
#   'vehicle_category': 'SUV',
#   'vehicle_make_model': 'Mitsubishi Outlander',
#   'vehicle_year_make_model': '2019 Mitsubishi Outlander',
#   'vehicle_year_make_model_cat': '2019 Mitsubishi Outlander (SUV)'},
#  {'vin': 'A4Z6B55F2S8F36TLG',
#   'license_plate': 'VW62 KHI',
#   'vehicle_make': 'Volkswagen',
#   'vehicle_model': 'Passat',
#   'vehicle_year': 1992,
#   'full_vehicleInfo': {'Year': 1992,
#    'Make': 'Volkswagen',
#    'Model': 'Passat',
#    'Category': 'Sedan, Wagon'},
#   'vehicle_category': 'Sedan, Wagon',
#   'vehicle_make_model': 'Volkswagen Passat',
#   'vehicle_year_make_model': '1992 Volkswagen Passat',
#   'vehicle_year_make_model_cat': '1992 Volkswagen Passat (Sedan, Wagon)'},
#  {'vin': 'KWL51W752DZG9N5FP',
#   'license_plate': 'FO98RWJ',
#   'vehicle_make': 'Mercedes-Benz',
#   'vehicle_model': 'CL-Class',
#   'vehicle_year': 2010,
#   'full_vehicleInfo': {'Year': 2010,
#    'Make': 'Mercedes-Benz',
#    'Model': 'CL-Class',
#    'Category': 'Coupe'},
#   'vehicle_category': 'Coupe',
#   'vehicle_make_model': 'Mercedes-Benz CL-Class',
#   'vehicle_year_make_model': '2010 Mercedes-Benz CL-Class',
#   'vehicle_year_make_model_cat': '2010 Mercedes-Benz CL-Class (Coupe)'},
#  {'vin': '1K79G8702HJDMDGZY',
#   'license_plate': 'BC00UNI',
#   'vehicle_make': 'Chevrolet',
#   'vehicle_model': 'G-Series 2500',
#   'vehicle_year': 1997,
#   'full_vehicleInfo': {'Year': 1997,
#    'Make': 'Chevrolet',
#    'Model': 'G-Series 2500',
#    'Category': 'Van/Minivan'},
#   'vehicle_category': 'Van/Minivan',
#   'vehicle_make_model': 'Chevrolet G-Series 2500',
#   'vehicle_year_make_model': '1997 Chevrolet G-Series 2500',
#   'vehicle_year_make_model_cat': '1997 Chevrolet G-Series 2500 (Van/Minivan)'},
#  {'vin': 'M9GAVU186503P0U93',
#   'license_plate': 'LZ31BLG',
#   'vehicle_make': 'Land Rover',
#   'vehicle_model': 'Range Rover Velar',
#   'vehicle_year': 2020,
#   'full_vehicleInfo': {'Year': 2020,
#    'Make': 'Land Rover',
#    'Model': 'Range Rover Velar',
#    'Category': 'SUV'},
#   'vehicle_category': 'SUV',
#   'vehicle_make_model': 'Land Rover Range Rover Velar',
#   'vehicle_year_make_model': '2020 Land Rover Range Rover Velar',
#   'vehicle_year_make_model_cat': '2020 Land Rover Range Rover Velar (SUV)'},
#  {'vin': 'NT0FABT29BMTFHA7R',
#   'license_plate': 'PH43 GOL',
#   'vehicle_make': 'Volkswagen',
#   'vehicle_model': 'GTI',
#   'vehicle_year': 2012,
#   'full_vehicleInfo': {'Year': 2012,
#    'Make': 'Volkswagen',
#    'Model': 'GTI',
#    'Category': 'Hatchback'},
#   'vehicle_category': 'Hatchback',
#   'vehicle_make_model': 'Volkswagen GTI',
#   'vehicle_year_make_model': '2012 Volkswagen GTI',
#   'vehicle_year_make_model_cat': '2012 Volkswagen GTI (Hatchback)'},
#  {'vin': 'E2CSMH5H5NZSM28GB',
#   'license_plate': 'BD56TNL',
#   'vehicle_make': 'Ford',
#   'vehicle_model': 'Escape',
#   'vehicle_year': 2018,
#   'full_vehicleInfo': {'Year': 2018,
#    'Make': 'Ford',
#    'Model': 'Escape',
#    'Category': 'SUV'},
#   'vehicle_category': 'SUV',
#   'vehicle_make_model': 'Ford Escape',
#   'vehicle_year_make_model': '2018 Ford Escape',
#   'vehicle_year_make_model_cat': '2018 Ford Escape (SUV)'},
#  {'vin': 'Z8RCG3U12CPU5ML8K',
#   'license_plate': 'VN48KMW',
#   'vehicle_make': 'Mercedes-Benz',
#   'vehicle_model': 'M-Class',
#   'vehicle_year': 2013,
#   'full_vehicleInfo': {'Year': 2013,
#    'Make': 'Mercedes-Benz',
#    'Model': 'M-Class',
#    'Category': 'SUV'},
#   'vehicle_category': 'SUV',
#   'vehicle_make_model': 'Mercedes-Benz M-Class',
#   'vehicle_year_make_model': '2013 Mercedes-Benz M-Class',
#   'vehicle_year_make_model_cat': '2013 Mercedes-Benz M-Class (SUV)'},
#  {'vin': '9CTRBKS17KJDULWVV',
#   'license_plate': 'QP21 ZZX',
#   'vehicle_make': 'Acura',
#   'vehicle_model': 'TSX',
#   'vehicle_year': 2008,
#   'full_vehicleInfo': {'Year': 2008,
#    'Make': 'Acura',
#    'Model': 'TSX',
#    'Category': 'Sedan'},
#   'vehicle_category': 'Sedan',
#   'vehicle_make_model': 'Acura TSX',
#   'vehicle_year_make_model': '2008 Acura TSX',
#   'vehicle_year_make_model_cat': '2008 Acura TSX (Sedan)'},
#  {'vin': 'JZM6FKEC6023FX5WT',
#   'license_plate': 'WW32 MPM',
#   'vehicle_make': 'Lotus',
#   'vehicle_model': 'Elise',
#   'vehicle_year': 2010,
#   'full_vehicleInfo': {'Year': 2010,
#    'Make': 'Lotus',
#    'Model': 'Elise',
#    'Category': 'Coupe'},
#   'vehicle_category': 'Coupe',
#   'vehicle_make_model': 'Lotus Elise',
#   'vehicle_year_make_model': '2010 Lotus Elise',
#   'vehicle_year_make_model_cat': '2010 Lotus Elise (Coupe)'},
#  {'vin': '17UEBW4F58W9WLVZU',
#   'license_plate': 'FX34POI',
#   'vehicle_make': 'Toyota',
#   'vehicle_model': 'Highlander',
#   'vehicle_year': 2009,
#   'full_vehicleInfo': {'Year': 2009,
#    'Make': 'Toyota',
#    'Model': 'Highlander',
#    'Category': 'SUV'},
#   'vehicle_category': 'SUV',
#   'vehicle_make_model': 'Toyota Highlander',
#   'vehicle_year_make_model': '2009 Toyota Highlander',
#   'vehicle_year_make_model_cat': '2009 Toyota Highlander (SUV)'},
#  {'vin': 'YFHV5JFH2ML690ER0',
#   'license_plate': 'CN76 NKR',
#   'vehicle_make': 'Cadillac',
#   'vehicle_model': 'DeVille',
#   'vehicle_year': 1992,
#   'full_vehicleInfo': {'Year': 1992,
#    'Make': 'Cadillac',
#    'Model': 'DeVille',
#    'Category': 'Sedan, Coupe'},
#   'vehicle_category': 'Sedan, Coupe',
#   'vehicle_make_model': 'Cadillac DeVille',
#   'vehicle_year_make_model': '1992 Cadillac DeVille',
#   'vehicle_year_make_model_cat': '1992 Cadillac DeVille (Sedan, Coupe)'},
#  {'vin': '4DTR2RX15NKRTEYEH',
#   'license_plate': 'PA62MKV',
#   'vehicle_make': 'Mitsubishi',
#   'vehicle_model': 'i-MiEV',
#   'vehicle_year': 2017,
#   'full_vehicleInfo': {'Year': 2017,
#    'Make': 'Mitsubishi',
#    'Model': 'i-MiEV',
#    'Category': 'Hatchback'},
#   'vehicle_category': 'Hatchback',
#   'vehicle_make_model': 'Mitsubishi i-MiEV',
#   'vehicle_year_make_model': '2017 Mitsubishi i-MiEV',
#   'vehicle_year_make_model_cat': '2017 Mitsubishi i-MiEV (Hatchback)'},
#  {'vin': 'W92S26U95WB4GRLDW',
#   'license_plate': 'KY64MIY',
#   'vehicle_make': 'Chrysler',
#   'vehicle_model': 'LeBaron',
#   'vehicle_year': 1992,
#   'full_vehicleInfo': {'Year': 1992,
#    'Make': 'Chrysler',
#    'Model': 'LeBaron',
#    'Category': 'Sedan, Coupe, Convertible'},
#   'vehicle_category': 'Sedan, Coupe, Convertible',
#   'vehicle_make_model': 'Chrysler LeBaron',
#   'vehicle_year_make_model': '1992 Chrysler LeBaron',
#   'vehicle_year_make_model_cat': '1992 Chrysler LeBaron (Sedan, Coupe, Convertible)'},
#  {'vin': '6X24NE5352FC20F9X',
#   'license_plate': 'SG52 OWI',
#   'vehicle_make': 'Ford',
#   'vehicle_model': 'Expedition',
#   'vehicle_year': 2006,
#   'full_vehicleInfo': {'Year': 2006,
#    'Make': 'Ford',
#    'Model': 'Expedition',
#    'Category': 'SUV'},
#   'vehicle_category': 'SUV',
#   'vehicle_make_model': 'Ford Expedition',
#   'vehicle_year_make_model': '2006 Ford Expedition',
#   'vehicle_year_make_model_cat': '2006 Ford Expedition (SUV)'},
#  {'vin': '8AK72KRS8C5F7K83N',
#   'license_plate': 'VL50CQU',
#   'vehicle_make': 'Honda',
#   'vehicle_model': 'del Sol',
#   'vehicle_year': 1995,
#   'full_vehicleInfo': {'Year': 1995,
#    'Make': 'Honda',
#    'Model': 'del Sol',
#    'Category': 'Coupe'},
#   'vehicle_category': 'Coupe',
#   'vehicle_make_model': 'Honda del Sol',
#   'vehicle_year_make_model': '1995 Honda del Sol',
#   'vehicle_year_make_model_cat': '1995 Honda del Sol (Coupe)'},
#  {'vin': 'TY7UPW0U6BHXWUHLF',
#   'license_plate': 'IO99 HYO',
#   'vehicle_make': 'Chrysler',
#   'vehicle_model': '300M',
#   'vehicle_year': 2001,
#   'full_vehicleInfo': {'Year': 2001,
#    'Make': 'Chrysler',
#    'Model': '300M',
#    'Category': 'Sedan'},
#   'vehicle_category': 'Sedan',
#   'vehicle_make_model': 'Chrysler 300M',
#   'vehicle_year_make_model': '2001 Chrysler 300M',
#   'vehicle_year_make_model_cat': '2001 Chrysler 300M (Sedan)'},
#  {'vin': 'RM2YLBYD6NGMHH1C6',
#   'license_plate': 'XN37 PRY',
#   'vehicle_make': 'Ford',
#   'vehicle_model': 'F250 Super Cab',
#   'vehicle_year': 1997,
#   'full_vehicleInfo': {'Year': 1997,
#    'Make': 'Ford',
#    'Model': 'F250 Super Cab',
#    'Category': 'Pickup'},
#   'vehicle_category': 'Pickup',
#   'vehicle_make_model': 'Ford F250 Super Cab',
#   'vehicle_year_make_model': '1997 Ford F250 Super Cab',
#   'vehicle_year_make_model_cat': '1997 Ford F250 Super Cab (Pickup)'},
#  {'vin': 'YV26JESF0KPXNUMNW',
#   'license_plate': 'JI35HDX',
#   'vehicle_make': 'Lexus',
#   'vehicle_model': 'GS',
#   'vehicle_year': 2011,
#   'full_vehicleInfo': {'Year': 2011,
#    'Make': 'Lexus',
#    'Model': 'GS',
#    'Category': 'Sedan'},
#   'vehicle_category': 'Sedan',
#   'vehicle_make_model': 'Lexus GS',
#   'vehicle_year_make_model': '2011 Lexus GS',
#   'vehicle_year_make_model_cat': '2011 Lexus GS (Sedan)'},
#  {'vin': '8BCDXHJ76CJEPBK19',
#   'license_plate': 'BB27RJW',
#   'vehicle_make': 'Audi',
#   'vehicle_model': 'A8',
#   'vehicle_year': 2002,
#   'full_vehicleInfo': {'Year': 2002,
#    'Make': 'Audi',
#    'Model': 'A8',
#    'Category': 'Sedan'},
#   'vehicle_category': 'Sedan',
#   'vehicle_make_model': 'Audi A8',
#   'vehicle_year_make_model': '2002 Audi A8',
#   'vehicle_year_make_model_cat': '2002 Audi A8 (Sedan)'},
#  {'vin': '71JXXVMB24GX85SY5',
#   'license_plate': 'EE13 ZSJ',
#   'vehicle_make': 'Toyota',
#   'vehicle_model': 'Sienna',
#   'vehicle_year': 2013,
#   'full_vehicleInfo': {'Year': 2013,
#    'Make': 'Toyota',
#    'Model': 'Sienna',
#    'Category': 'Van/Minivan'},
#   'vehicle_category': 'Van/Minivan',
#   'vehicle_make_model': 'Toyota Sienna',
#   'vehicle_year_make_model': '2013 Toyota Sienna',
#   'vehicle_year_make_model_cat': '2013 Toyota Sienna (Van/Minivan)'},
#  {'vin': '8TERVVKU1K47DDG6A',
#   'license_plate': 'FR67 CFA',
#   'vehicle_make': 'Cadillac',
#   'vehicle_model': 'Escalade ESV',
#   'vehicle_year': 2008,
#   'full_vehicleInfo': {'Year': 2008,
#    'Make': 'Cadillac',
#    'Model': 'Escalade ESV',
#    'Category': 'SUV'},
#   'vehicle_category': 'SUV',
#   'vehicle_make_model': 'Cadillac Escalade ESV',
#   'vehicle_year_make_model': '2008 Cadillac Escalade ESV',
#   'vehicle_year_make_model_cat': '2008 Cadillac Escalade ESV (SUV)'},
#  {'vin': 'XJ3EJJW51EGCU8E0H',
#   'license_plate': 'CB99 FZJ',
#   'vehicle_make': 'Nissan',
#   'vehicle_model': 'LEAF',
#   'vehicle_year': 2012,
#   'full_vehicleInfo': {'Year': 2012,
#    'Make': 'Nissan',
#    'Model': 'LEAF',
#    'Category': 'Hatchback'},
#   'vehicle_category': 'Hatchback',
#   'vehicle_make_model': 'Nissan LEAF',
#   'vehicle_year_make_model': '2012 Nissan LEAF',
#   'vehicle_year_make_model_cat': '2012 Nissan LEAF (Hatchback)'},
#  {'vin': 'JV8WKSHZ8YV63ULG2',
#   'license_plate': 'HV49 SSA',
#   'vehicle_make': 'MAZDA',
#   'vehicle_model': 'Millenia',
#   'vehicle_year': 2001,
#   'full_vehicleInfo': {'Year': 2001,
#    'Make': 'MAZDA',
#    'Model': 'Millenia',
#    'Category': 'Sedan'},
#   'vehicle_category': 'Sedan',
#   'vehicle_make_model': 'MAZDA Millenia',
#   'vehicle_year_make_model': '2001 MAZDA Millenia',
#   'vehicle_year_make_model_cat': '2001 MAZDA Millenia (Sedan)'},
#  {'vin': '3BXVHBUY96XNTML7A',
#   'license_plate': 'NW68PJV',
#   'vehicle_make': 'Toyota',
#   'vehicle_model': 'Matrix',
#   'vehicle_year': 2012,
#   'full_vehicleInfo': {'Year': 2012,
#    'Make': 'Toyota',
#    'Model': 'Matrix',
#    'Category': 'Wagon'},
#   'vehicle_category': 'Wagon',
#   'vehicle_make_model': 'Toyota Matrix',
#   'vehicle_year_make_model': '2012 Toyota Matrix',
#   'vehicle_year_make_model_cat': '2012 Toyota Matrix (Wagon)'},
#  {'vin': '3W6LGL8S1Z1WT4CPY',
#   'license_plate': 'YB24GIR',
#   'vehicle_make': 'Nissan',
#   'vehicle_model': 'Murano',
#   'vehicle_year': 2006,
#   'full_vehicleInfo': {'Year': 2006,
#    'Make': 'Nissan',
#    'Model': 'Murano',
#    'Category': 'SUV'},
#   'vehicle_category': 'SUV',
#   'vehicle_make_model': 'Nissan Murano',
#   'vehicle_year_make_model': '2006 Nissan Murano',
#   'vehicle_year_make_model_cat': '2006 Nissan Murano (SUV)'},
#  {'vin': 'VY82FAK12T6E8W80Y',
#   'license_plate': 'QW73INP',
#   'vehicle_make': 'MAZDA',
#   'vehicle_model': 'B-Series Cab Plus',
#   'vehicle_year': 1999,
#   'full_vehicleInfo': {'Year': 1999,
#    'Make': 'MAZDA',
#    'Model': 'B-Series Cab Plus',
#    'Category': 'Pickup'},
#   'vehicle_category': 'Pickup',
#   'vehicle_make_model': 'MAZDA B-Series Cab Plus',
#   'vehicle_year_make_model': '1999 MAZDA B-Series Cab Plus',
#   'vehicle_year_make_model_cat': '1999 MAZDA B-Series Cab Plus (Pickup)'},
#  {'vin': 'W0RCZ95H9TMZH1JKY',
#   'license_plate': 'OR88 PLK',
#   'vehicle_make': 'Saab',
#   'vehicle_model': '3-Sep',
#   'vehicle_year': 2001,
#   'full_vehicleInfo': {'Year': 2001,
#    'Make': 'Saab',
#    'Model': '3-Sep',
#    'Category': 'Hatchback, Convertible'},
#   'vehicle_category': 'Hatchback, Convertible',
#   'vehicle_make_model': 'Saab 3-Sep',
#   'vehicle_year_make_model': '2001 Saab 3-Sep',
#   'vehicle_year_make_model_cat': '2001 Saab 3-Sep (Hatchback, Convertible)'},
#  {'vin': 'RWLCFRET53LXRR0Y3',
#   'license_plate': 'QS18 KDO',
#   'vehicle_make': 'Geo',
#   'vehicle_model': 'Storm',
#   'vehicle_year': 1993,
#   'full_vehicleInfo': {'Year': 1993,
#    'Make': 'Geo',
#    'Model': 'Storm',
#    'Category': 'Coupe'},
#   'vehicle_category': 'Coupe',
#   'vehicle_make_model': 'Geo Storm',
#   'vehicle_year_make_model': '1993 Geo Storm',
#   'vehicle_year_make_model_cat': '1993 Geo Storm (Coupe)'},
#  {'vin': 'W10T05XG0MS6MRLY3',
#   'license_plate': 'HU16 VJH',
#   'vehicle_make': 'Audi',
#   'vehicle_model': 'TT',
#   'vehicle_year': 2005,
#   'full_vehicleInfo': {'Year': 2005,
#    'Make': 'Audi',
#    'Model': 'TT',
#    'Category': 'Coupe, Convertible'},
#   'vehicle_category': 'Coupe, Convertible',
#   'vehicle_make_model': 'Audi TT',
#   'vehicle_year_make_model': '2005 Audi TT',
#   'vehicle_year_make_model_cat': '2005 Audi TT (Coupe, Convertible)'},
#  {'vin': '77VAK23L34JNPU0FT',
#   'license_plate': 'FF93 CTM',
#   'vehicle_make': 'Nissan',
#   'vehicle_model': 'Maxima',
#   'vehicle_year': 2003,
#   'full_vehicleInfo': {'Year': 2003,
#    'Make': 'Nissan',
#    'Model': 'Maxima',
#    'Category': 'Sedan'},
#   'vehicle_category': 'Sedan',
#   'vehicle_make_model': 'Nissan Maxima',
#   'vehicle_year_make_model': '2003 Nissan Maxima',
#   'vehicle_year_make_model_cat': '2003 Nissan Maxima (Sedan)'},
#  {'vin': 'Y0EWGWG10WJA5VNKU',
#   'license_plate': 'OJ13GMP',
#   'vehicle_make': 'Acura',
#   'vehicle_model': 'RL',
#   'vehicle_year': 2003,
#   'full_vehicleInfo': {'Year': 2003,
#    'Make': 'Acura',
#    'Model': 'RL',
#    'Category': 'Sedan'},
#   'vehicle_category': 'Sedan',
#   'vehicle_make_model': 'Acura RL',
#   'vehicle_year_make_model': '2003 Acura RL',
#   'vehicle_year_make_model_cat': '2003 Acura RL (Sedan)'},
#  {'vin': 'RNJJ2SH104YJENECG',
#   'license_plate': 'UD47 UUB',
#   'vehicle_make': 'GMC',
#   'vehicle_model': 'Savana 2500 Cargo',
#   'vehicle_year': 1999,
#   'full_vehicleInfo': {'Year': 1999,
#    'Make': 'GMC',
#    'Model': 'Savana 2500 Cargo',
#    'Category': 'Van/Minivan'},
#   'vehicle_category': 'Van/Minivan',
#   'vehicle_make_model': 'GMC Savana 2500 Cargo',
#   'vehicle_year_make_model': '1999 GMC Savana 2500 Cargo',
#   'vehicle_year_make_model_cat': '1999 GMC Savana 2500 Cargo (Van/Minivan)'},
#  {'vin': '3P96JLTB4C9PZHAGX',
#   'license_plate': 'XK12ZDO',
#   'vehicle_make': 'Acura',
#   'vehicle_model': 'TSX',
#   'vehicle_year': 2010,
#   'full_vehicleInfo': {'Year': 2010,
#    'Make': 'Acura',
#    'Model': 'TSX',
#    'Category': 'Sedan'},
#   'vehicle_category': 'Sedan',
#   'vehicle_make_model': 'Acura TSX',
#   'vehicle_year_make_model': '2010 Acura TSX',
#   'vehicle_year_make_model_cat': '2010 Acura TSX (Sedan)'},
#  {'vin': 'ESP6S1G88WPGRP7EX',
#   'license_plate': 'TR17 KTH',
#   'vehicle_make': 'Chevrolet',
#   'vehicle_model': 'Silverado 1500 Crew Cab',
#   'vehicle_year': 2011,
#   'full_vehicleInfo': {'Year': 2011,
#    'Make': 'Chevrolet',
#    'Model': 'Silverado 1500 Crew Cab',
#    'Category': 'Pickup'},
#   'vehicle_category': 'Pickup',
#   'vehicle_make_model': 'Chevrolet Silverado 1500 Crew Cab',
#   'vehicle_year_make_model': '2011 Chevrolet Silverado 1500 Crew Cab',
#   'vehicle_year_make_model_cat': '2011 Chevrolet Silverado 1500 Crew Cab (Pickup)'},
#  {'vin': 'KT8933KY587F9RWPT',
#   'license_plate': 'NU64 DPT',
#   'vehicle_make': 'Chevrolet',
#   'vehicle_model': 'Suburban 3500HD',
#   'vehicle_year': 2016,
#   'full_vehicleInfo': {'Year': 2016,
#    'Make': 'Chevrolet',
#    'Model': 'Suburban 3500HD',
#    'Category': 'SUV'},
#   'vehicle_category': 'SUV',
#   'vehicle_make_model': 'Chevrolet Suburban 3500HD',
#   'vehicle_year_make_model': '2016 Chevrolet Suburban 3500HD',
#   'vehicle_year_make_model_cat': '2016 Chevrolet Suburban 3500HD (SUV)'},
#  {'vin': '3PDVVFP72PN4SHC8W',
#   'license_plate': 'VG00 UUT',
#   'vehicle_make': 'GMC',
#   'vehicle_model': '1500 Club Coupe',
#   'vehicle_year': 1999,
#   'full_vehicleInfo': {'Year': 1999,
#    'Make': 'GMC',
#    'Model': '1500 Club Coupe',
#    'Category': 'Pickup'},
#   'vehicle_category': 'Pickup',
#   'vehicle_make_model': 'GMC 1500 Club Coupe',
#   'vehicle_year_make_model': '1999 GMC 1500 Club Coupe',
#   'vehicle_year_make_model_cat': '1999 GMC 1500 Club Coupe (Pickup)'},
#  {'vin': 'MF9D5DDE5M01H09GB',
#   'license_plate': 'VA39 EAL',
#   'vehicle_make': 'Aston Martin',
#   'vehicle_model': 'DBS',
#   'vehicle_year': 2008,
#   'full_vehicleInfo': {'Year': 2008,
#    'Make': 'Aston Martin',
#    'Model': 'DBS',
#    'Category': 'Coupe'},
#   'vehicle_category': 'Coupe',
#   'vehicle_make_model': 'Aston Martin DBS',
#   'vehicle_year_make_model': '2008 Aston Martin DBS',
#   'vehicle_year_make_model_cat': '2008 Aston Martin DBS (Coupe)'},
#  {'vin': 'L2BG49T835XVPZ7VZ',
#   'license_plate': 'TB84 XZV',
#   'vehicle_make': 'Chevrolet',
#   'vehicle_model': 'Express 2500 Cargo',
#   'vehicle_year': 2017,
#   'full_vehicleInfo': {'Year': 2017,
#    'Make': 'Chevrolet',
#    'Model': 'Express 2500 Cargo',
#    'Category': 'Van/Minivan'},
#   'vehicle_category': 'Van/Minivan',
#   'vehicle_make_model': 'Chevrolet Express 2500 Cargo',
#   'vehicle_year_make_model': '2017 Chevrolet Express 2500 Cargo',
#   'vehicle_year_make_model_cat': '2017 Chevrolet Express 2500 Cargo (Van/Minivan)'},
#  {'vin': 'W24XSU7Y3V56L059H',
#   'license_plate': 'MT89QJO',
#   'vehicle_make': 'Hyundai',
#   'vehicle_model': 'Equus',
#   'vehicle_year': 2014,
#   'full_vehicleInfo': {'Year': 2014,
#    'Make': 'Hyundai',
#    'Model': 'Equus',
#    'Category': 'Sedan'},
#   'vehicle_category': 'Sedan',
#   'vehicle_make_model': 'Hyundai Equus',
#   'vehicle_year_make_model': '2014 Hyundai Equus',
#   'vehicle_year_make_model_cat': '2014 Hyundai Equus (Sedan)'},
#  {'vin': 'U78DUVET5MWST7LUL',
#   'license_plate': 'LE11VPC',
#   'vehicle_make': 'MAZDA',
#   'vehicle_model': 'B-Series Regular Cab',
#   'vehicle_year': 2009,
#   'full_vehicleInfo': {'Year': 2009,
#    'Make': 'MAZDA',
#    'Model': 'B-Series Regular Cab',
#    'Category': 'Pickup'},
#   'vehicle_category': 'Pickup',
#   'vehicle_make_model': 'MAZDA B-Series Regular Cab',
#   'vehicle_year_make_model': '2009 MAZDA B-Series Regular Cab',
#   'vehicle_year_make_model_cat': '2009 MAZDA B-Series Regular Cab (Pickup)'},
#  {'vin': '6U7P94M8XTNU4JKN7',
#   'license_plate': 'EV58 PHD',
#   'vehicle_make': 'Mercedes-Benz',
#   'vehicle_model': 'Sprinter 2500 Crew',
#   'vehicle_year': 2016,
#   'full_vehicleInfo': {'Year': 2016,
#    'Make': 'Mercedes-Benz',
#    'Model': 'Sprinter 2500 Crew',
#    'Category': 'Van/Minivan'},
#   'vehicle_category': 'Van/Minivan',
#   'vehicle_make_model': 'Mercedes-Benz Sprinter 2500 Crew',
#   'vehicle_year_make_model': '2016 Mercedes-Benz Sprinter 2500 Crew',
#   'vehicle_year_make_model_cat': '2016 Mercedes-Benz Sprinter 2500 Crew (Van/Minivan)'},
#  {'vin': 'P8HEU2H22BHKMN1B0',
#   'license_plate': 'CE18XUA',
#   'vehicle_make': 'Kia',
#   'vehicle_model': 'Sportage',
#   'vehicle_year': 2019,
#   'full_vehicleInfo': {'Year': 2019,
#    'Make': 'Kia',
#    'Model': 'Sportage',
#    'Category': 'SUV'},
#   'vehicle_category': 'SUV',
#   'vehicle_make_model': 'Kia Sportage',
#   'vehicle_year_make_model': '2019 Kia Sportage',
#   'vehicle_year_make_model_cat': '2019 Kia Sportage (SUV)'},
#  {'vin': 'DRTWMAPK2L640A46H',
#   'license_plate': 'VN64PTO',
#   'vehicle_make': 'smart',
#   'vehicle_model': 'fortwo electric drive',
#   'vehicle_year': 2014,
#   'full_vehicleInfo': {'Year': 2014,
#    'Make': 'smart',
#    'Model': 'fortwo electric drive',
#    'Category': 'Hatchback, Convertible'},
#   'vehicle_category': 'Hatchback, Convertible',
#   'vehicle_make_model': 'smart fortwo electric drive',
#   'vehicle_year_make_model': '2014 smart fortwo electric drive',
#   'vehicle_year_make_model_cat': '2014 smart fortwo electric drive (Hatchback, Convertible)'},
#  {'vin': 'DZ8NU8JY1K3ES41DK',
#   'license_plate': 'YE51 YIJ',
#   'vehicle_make': 'INFINITI',
#   'vehicle_model': 'Q',
#   'vehicle_year': 1996,
#   'full_vehicleInfo': {'Year': 1996,
#    'Make': 'INFINITI',
#    'Model': 'Q',
#    'Category': 'Sedan'},
#   'vehicle_category': 'Sedan',
#   'vehicle_make_model': 'INFINITI Q',
#   'vehicle_year_make_model': '1996 INFINITI Q',
#   'vehicle_year_make_model_cat': '1996 INFINITI Q (Sedan)'},
#  {'vin': '1YUB9REZ5N5S3U2W5',
#   'license_plate': 'SN64SMW',
#   'vehicle_make': 'Ford',
#   'vehicle_model': 'E350 Super Duty Cargo',
#   'vehicle_year': 2003,
#   'full_vehicleInfo': {'Year': 2003,
#    'Make': 'Ford',
#    'Model': 'E350 Super Duty Cargo',
#    'Category': 'Van/Minivan'},
#   'vehicle_category': 'Van/Minivan',
#   'vehicle_make_model': 'Ford E350 Super Duty Cargo',
#   'vehicle_year_make_model': '2003 Ford E350 Super Duty Cargo',
#   'vehicle_year_make_model_cat': '2003 Ford E350 Super Duty Cargo (Van/Minivan)'},
#  {'vin': '8S2LAWP67U7FUS6SK',
#   'license_plate': 'HK81YFC',
#   'vehicle_make': 'Suzuki',
#   'vehicle_model': 'XL-7',
#   'vehicle_year': 2002,
#   'full_vehicleInfo': {'Year': 2002,
#    'Make': 'Suzuki',
#    'Model': 'XL-7',
#    'Category': 'SUV'},
#   'vehicle_category': 'SUV',
#   'vehicle_make_model': 'Suzuki XL-7',
#   'vehicle_year_make_model': '2002 Suzuki XL-7',
#   'vehicle_year_make_model_cat': '2002 Suzuki XL-7 (SUV)'},
#  {'vin': 'ZCNN0F709GCB05BYW',
#   'license_plate': 'VS55UUT',
#   'vehicle_make': 'GMC',
#   'vehicle_model': 'Sierra 3500 Extended Cab',
#   'vehicle_year': 2001,
#   'full_vehicleInfo': {'Year': 2001,
#    'Make': 'GMC',
#    'Model': 'Sierra 3500 Extended Cab',
#    'Category': 'Pickup'},
#   'vehicle_category': 'Pickup',
#   'vehicle_make_model': 'GMC Sierra 3500 Extended Cab',
#   'vehicle_year_make_model': '2001 GMC Sierra 3500 Extended Cab',
#   'vehicle_year_make_model_cat': '2001 GMC Sierra 3500 Extended Cab (Pickup)'},
#  {'vin': '0V5XVKH46NZ5KWV34',
#   'license_plate': 'JC98UCT',
#   'vehicle_make': 'BMW',
#   'vehicle_model': 'Z3',
#   'vehicle_year': 1999,
#   'full_vehicleInfo': {'Year': 1999,
#    'Make': 'BMW',
#    'Model': 'Z3',
#    'Category': 'Convertible, Coupe'},
#   'vehicle_category': 'Convertible, Coupe',
#   'vehicle_make_model': 'BMW Z3',
#   'vehicle_year_make_model': '1999 BMW Z3',
#   'vehicle_year_make_model_cat': '1999 BMW Z3 (Convertible, Coupe)'},
#  {'vin': 'RW3VCLXZ404V7M6ZB',
#   'license_plate': 'HW89 OOQ',
#   'vehicle_make': 'Chevrolet',
#   'vehicle_model': 'Venture Cargo',
#   'vehicle_year': 2004,
#   'full_vehicleInfo': {'Year': 2004,
#    'Make': 'Chevrolet',
#    'Model': 'Venture Cargo',
#    'Category': 'Van/Minivan'},
#   'vehicle_category': 'Van/Minivan',
#   'vehicle_make_model': 'Chevrolet Venture Cargo',
#   'vehicle_year_make_model': '2004 Chevrolet Venture Cargo',
#   'vehicle_year_make_model_cat': '2004 Chevrolet Venture Cargo (Van/Minivan)'},
#  {'vin': 'APPJRTM46M5M7RJG0',
#   'license_plate': 'CS46VEL',
#   'vehicle_make': 'Toyota',
#   'vehicle_model': 'Supra',
#   'vehicle_year': 1994,
#   'full_vehicleInfo': {'Year': 1994,
#    'Make': 'Toyota',
#    'Model': 'Supra',
#    'Category': 'Hatchback'},
#   'vehicle_category': 'Hatchback',
#   'vehicle_make_model': 'Toyota Supra',
#   'vehicle_year_make_model': '1994 Toyota Supra',
#   'vehicle_year_make_model_cat': '1994 Toyota Supra (Hatchback)'},
#  {'vin': '96KRM96U2ZP2PKBDM',
#   'license_plate': 'GH41EEC',
#   'vehicle_make': 'Audi',
#   'vehicle_model': 'RS 5',
#   'vehicle_year': 2014,
#   'full_vehicleInfo': {'Year': 2014,
#    'Make': 'Audi',
#    'Model': 'RS 5',
#    'Category': 'Convertible, Coupe'},
#   'vehicle_category': 'Convertible, Coupe',
#   'vehicle_make_model': 'Audi RS 5',
#   'vehicle_year_make_model': '2014 Audi RS 5',
#   'vehicle_year_make_model_cat': '2014 Audi RS 5 (Convertible, Coupe)'},
#  {'vin': 'Z3M9R0ABXAV3TPFVJ',
#   'license_plate': 'HR73HJZ',
#   'vehicle_make': 'Toyota',
#   'vehicle_model': 'T100 Xtracab',
#   'vehicle_year': 1995,
#   'full_vehicleInfo': {'Year': 1995,
#    'Make': 'Toyota',
#    'Model': 'T100 Xtracab',
#    'Category': 'Pickup'},
#   'vehicle_category': 'Pickup',
#   'vehicle_make_model': 'Toyota T100 Xtracab',
#   'vehicle_year_make_model': '1995 Toyota T100 Xtracab',
#   'vehicle_year_make_model_cat': '1995 Toyota T100 Xtracab (Pickup)'},
#  {'vin': 'PVWJRZTAXC9G4XP78',
#   'license_plate': 'CY82FIO',
#   'vehicle_make': 'Ford',
#   'vehicle_model': 'Econoline E250 Cargo',
#   'vehicle_year': 1994,
#   'full_vehicleInfo': {'Year': 1994,
#    'Make': 'Ford',
#    'Model': 'Econoline E250 Cargo',
#    'Category': 'Van/Minivan'},
#   'vehicle_category': 'Van/Minivan',
#   'vehicle_make_model': 'Ford Econoline E250 Cargo',
#   'vehicle_year_make_model': '1994 Ford Econoline E250 Cargo',
#   'vehicle_year_make_model_cat': '1994 Ford Econoline E250 Cargo (Van/Minivan)'},
#  {'vin': 'U6EVN2T43SZPFR6PE',
#   'license_plate': 'KD22 WUK',
#   'vehicle_make': 'Ford',
#   'vehicle_model': 'Aerostar Passenger',
#   'vehicle_year': 1997,
#   'full_vehicleInfo': {'Year': 1997,
#    'Make': 'Ford',
#    'Model': 'Aerostar Passenger',
#    'Category': 'Van/Minivan'},
#   'vehicle_category': 'Van/Minivan',
#   'vehicle_make_model': 'Ford Aerostar Passenger',
#   'vehicle_year_make_model': '1997 Ford Aerostar Passenger',
#   'vehicle_year_make_model_cat': '1997 Ford Aerostar Passenger (Van/Minivan)'},
#  {'vin': '3JX9XV1672GD0U8JF',
#   'license_plate': 'DB97HNU',
#   'vehicle_make': 'MAZDA',
#   'vehicle_model': 'CX-9',
#   'vehicle_year': 2015,
#   'full_vehicleInfo': {'Year': 2015,
#    'Make': 'MAZDA',
#    'Model': 'CX-9',
#    'Category': 'SUV'},
#   'vehicle_category': 'SUV',
#   'vehicle_make_model': 'MAZDA CX-9',
#   'vehicle_year_make_model': '2015 MAZDA CX-9',
#   'vehicle_year_make_model_cat': '2015 MAZDA CX-9 (SUV)'},
#  {'vin': '58Y2ZF0J3U1NFTB6P',
#   'license_plate': 'QR80 QZQ',
#   'vehicle_make': 'Ford',
#   'vehicle_model': 'Freestyle',
#   'vehicle_year': 2007,
#   'full_vehicleInfo': {'Year': 2007,
#    'Make': 'Ford',
#    'Model': 'Freestyle',
#    'Category': 'SUV'},
#   'vehicle_category': 'SUV',
#   'vehicle_make_model': 'Ford Freestyle',
#   'vehicle_year_make_model': '2007 Ford Freestyle',
#   'vehicle_year_make_model_cat': '2007 Ford Freestyle (SUV)'},
#  {'vin': 'RX3RPG2N35NF7M93N',
#   'license_plate': 'UF72YVO',
#   'vehicle_make': 'Acura',
#   'vehicle_model': 'RL',
#   'vehicle_year': 2004,
#   'full_vehicleInfo': {'Year': 2004,
#    'Make': 'Acura',
#    'Model': 'RL',
#    'Category': 'Sedan'},
#   'vehicle_category': 'Sedan',
#   'vehicle_make_model': 'Acura RL',
#   'vehicle_year_make_model': '2004 Acura RL',
#   'vehicle_year_make_model_cat': '2004 Acura RL (Sedan)'},
#  {'vin': '95W3JC3C63LKZSXG3',
#   'license_plate': 'JL54 YBU',
#   'vehicle_make': 'Ford',
#   'vehicle_model': 'F150 Super Cab',
#   'vehicle_year': 2007,
#   'full_vehicleInfo': {'Year': 2007,
#    'Make': 'Ford',
#    'Model': 'F150 Super Cab',
#    'Category': 'Pickup'},
#   'vehicle_category': 'Pickup',
#   'vehicle_make_model': 'Ford F150 Super Cab',
#   'vehicle_year_make_model': '2007 Ford F150 Super Cab',
#   'vehicle_year_make_model_cat': '2007 Ford F150 Super Cab (Pickup)'},
#  {'vin': '8PUSVRMBXYYPH6U6U',
#   'license_plate': 'RJ54 KDC',
#   'vehicle_make': 'Chevrolet',
#   'vehicle_model': 'Avalanche 1500',
#   'vehicle_year': 2003,
#   'full_vehicleInfo': {'Year': 2003,
#    'Make': 'Chevrolet',
#    'Model': 'Avalanche 1500',
#    'Category': 'Pickup'},
#   'vehicle_category': 'Pickup',
#   'vehicle_make_model': 'Chevrolet Avalanche 1500',
#   'vehicle_year_make_model': '2003 Chevrolet Avalanche 1500',
#   'vehicle_year_make_model_cat': '2003 Chevrolet Avalanche 1500 (Pickup)'},
#  {'vin': 'KVUAVNV3XNUH45SPZ',
#   'license_plate': 'AE70 TVZ',
#   'vehicle_make': 'Kia',
#   'vehicle_model': 'Forte',
#   'vehicle_year': 2010,
#   'full_vehicleInfo': {'Year': 2010,
#    'Make': 'Kia',
#    'Model': 'Forte',
#    'Category': 'Sedan, Coupe'},
#   'vehicle_category': 'Sedan, Coupe',
#   'vehicle_make_model': 'Kia Forte',
#   'vehicle_year_make_model': '2010 Kia Forte',
#   'vehicle_year_make_model_cat': '2010 Kia Forte (Sedan, Coupe)'},
#  {'vin': '95FPPR30XVPPV59PS',
#   'license_plate': 'UI27HDA',
#   'vehicle_make': 'Chevrolet',
#   'vehicle_model': 'Tahoe (New)',
#   'vehicle_year': 2000,
#   'full_vehicleInfo': {'Year': 2000,
#    'Make': 'Chevrolet',
#    'Model': 'Tahoe (New)',
#    'Category': 'SUV'},
#   'vehicle_category': 'SUV',
#   'vehicle_make_model': 'Chevrolet Tahoe (New)',
#   'vehicle_year_make_model': '2000 Chevrolet Tahoe (New)',
#   'vehicle_year_make_model_cat': '2000 Chevrolet Tahoe (New) (SUV)'},
#  {'vin': 'R8GGVDJY2C895VBV6',
#   'license_plate': 'VL84WCR',
#   'vehicle_make': 'Mercedes-Benz',
#   'vehicle_model': 'CL-Class',
#   'vehicle_year': 2005,
#   'full_vehicleInfo': {'Year': 2005,
#    'Make': 'Mercedes-Benz',
#    'Model': 'CL-Class',
#    'Category': 'Coupe'},
#   'vehicle_category': 'Coupe',
#   'vehicle_make_model': 'Mercedes-Benz CL-Class',
#   'vehicle_year_make_model': '2005 Mercedes-Benz CL-Class',
#   'vehicle_year_make_model_cat': '2005 Mercedes-Benz CL-Class (Coupe)'},
#  {'vin': 'KABPZE8C19FY2PPW9',
#   'license_plate': 'CJ78 MWX',
#   'vehicle_make': 'Toyota',
#   'vehicle_model': 'Yaris iA',
#   'vehicle_year': 2017,
#   'full_vehicleInfo': {'Year': 2017,
#    'Make': 'Toyota',
#    'Model': 'Yaris iA',
#    'Category': 'Sedan'},
#   'vehicle_category': 'Sedan',
#   'vehicle_make_model': 'Toyota Yaris iA',
#   'vehicle_year_make_model': '2017 Toyota Yaris iA',
#   'vehicle_year_make_model_cat': '2017 Toyota Yaris iA (Sedan)'},
#  {'vin': 'TT59L5VW2N9B9UZ48',
#   'license_plate': 'JF35 FKW',
#   'vehicle_make': 'Toyota',
#   'vehicle_model': 'Prius',
#   'vehicle_year': 2010,
#   'full_vehicleInfo': {'Year': 2010,
#    'Make': 'Toyota',
#    'Model': 'Prius',
#    'Category': 'Hatchback'},
#   'vehicle_category': 'Hatchback',
#   'vehicle_make_model': 'Toyota Prius',
#   'vehicle_year_make_model': '2010 Toyota Prius',
#   'vehicle_year_make_model_cat': '2010 Toyota Prius (Hatchback)'},
#  {'vin': 'J6GCH9K61ZA0AM326',
#   'license_plate': 'UY39 SIU',
#   'vehicle_make': 'BMW',
#   'vehicle_model': 'M6',
#   'vehicle_year': 2019,
#   'full_vehicleInfo': {'Year': 2019,
#    'Make': 'BMW',
#    'Model': 'M6',
#    'Category': 'Coupe'},
#   'vehicle_category': 'Coupe',
#   'vehicle_make_model': 'BMW M6',
#   'vehicle_year_make_model': '2019 BMW M6',
#   'vehicle_year_make_model_cat': '2019 BMW M6 (Coupe)'},
#  {'vin': 'T2YJKXFS6KW54AVTX',
#   'license_plate': 'GK55TEK',
#   'vehicle_make': 'Mercedes-Benz',
#   'vehicle_model': 'Mercedes-AMG S-Class',
#   'vehicle_year': 2017,
#   'full_vehicleInfo': {'Year': 2017,
#    'Make': 'Mercedes-Benz',
#    'Model': 'Mercedes-AMG S-Class',
#    'Category': 'Sedan, Coupe, Convertible'},
#   'vehicle_category': 'Sedan, Coupe, Convertible',
#   'vehicle_make_model': 'Mercedes-Benz Mercedes-AMG S-Class',
#   'vehicle_year_make_model': '2017 Mercedes-Benz Mercedes-AMG S-Class',
#   'vehicle_year_make_model_cat': '2017 Mercedes-Benz Mercedes-AMG S-Class (Sedan, Coupe, Convertible)'},
#  {'vin': 'S9PZ7LFW78HVF074J',
#   'license_plate': 'TN95HFK',
#   'vehicle_make': 'Nissan',
#   'vehicle_model': 'Maxima',
#   'vehicle_year': 2018,
#   'full_vehicleInfo': {'Year': 2018,
#    'Make': 'Nissan',
#    'Model': 'Maxima',
#    'Category': 'Sedan'},
#   'vehicle_category': 'Sedan',
#   'vehicle_make_model': 'Nissan Maxima',
#   'vehicle_year_make_model': '2018 Nissan Maxima',
#   'vehicle_year_make_model_cat': '2018 Nissan Maxima (Sedan)'},
#  {'vin': 'CAYZWYKY426SZWFDN',
#   'license_plate': 'BJ74 PTU',
#   'vehicle_make': 'Nissan',
#   'vehicle_model': 'Rogue',
#   'vehicle_year': 2018,
#   'full_vehicleInfo': {'Year': 2018,
#    'Make': 'Nissan',
#    'Model': 'Rogue',
#    'Category': 'SUV'},
#   'vehicle_category': 'SUV',
#   'vehicle_make_model': 'Nissan Rogue',
#   'vehicle_year_make_model': '2018 Nissan Rogue',
#   'vehicle_year_make_model_cat': '2018 Nissan Rogue (SUV)'},
#  {'vin': '17U9GPSP33S4CPJ5R',
#   'license_plate': 'YR91ITV',
#   'vehicle_make': 'MAZDA',
#   'vehicle_model': 'Millenia',
#   'vehicle_year': 2002,
#   'full_vehicleInfo': {'Year': 2002,
#    'Make': 'MAZDA',
#    'Model': 'Millenia',
#    'Category': 'Sedan'},
#   'vehicle_category': 'Sedan',
#   'vehicle_make_model': 'MAZDA Millenia',
#   'vehicle_year_make_model': '2002 MAZDA Millenia',
#   'vehicle_year_make_model_cat': '2002 MAZDA Millenia (Sedan)'},
#  {'vin': '97SPMP0C2ZSZ3339M',
#   'license_plate': 'QO25ETQ',
#   'vehicle_make': 'BMW',
#   'vehicle_model': 'X3',
#   'vehicle_year': 2010,
#   'full_vehicleInfo': {'Year': 2010,
#    'Make': 'BMW',
#    'Model': 'X3',
#    'Category': 'SUV'},
#   'vehicle_category': 'SUV',
#   'vehicle_make_model': 'BMW X3',
#   'vehicle_year_make_model': '2010 BMW X3',
#   'vehicle_year_make_model_cat': '2010 BMW X3 (SUV)'},
#  {'vin': 'LASKMZZY4KX2PM8TK',
#   'license_plate': 'TP99 IUZ',
#   'vehicle_make': 'Ford',
#   'vehicle_model': 'Expedition EL',
#   'vehicle_year': 2016,
#   'full_vehicleInfo': {'Year': 2016,
#    'Make': 'Ford',
#    'Model': 'Expedition EL',
#    'Category': 'SUV'},
#   'vehicle_category': 'SUV',
#   'vehicle_make_model': 'Ford Expedition EL',
#   'vehicle_year_make_model': '2016 Ford Expedition EL',
#   'vehicle_year_make_model_cat': '2016 Ford Expedition EL (SUV)'},
#  {'vin': 'E4XAR0F338C2VLT0T',
#   'license_plate': 'NQ02 YTP',
#   'vehicle_make': 'Toyota',
#   'vehicle_model': 'Highlander',
#   'vehicle_year': 2004,
#   'full_vehicleInfo': {'Year': 2004,
#    'Make': 'Toyota',
#    'Model': 'Highlander',
#    'Category': 'SUV'},
#   'vehicle_category': 'SUV',
#   'vehicle_make_model': 'Toyota Highlander',
#   'vehicle_year_make_model': '2004 Toyota Highlander',
#   'vehicle_year_make_model_cat': '2004 Toyota Highlander (SUV)'},
#  {'vin': 'DLXRLBWM5NGXCFHKE',
#   'license_plate': 'YJ75WGW',
#   'vehicle_make': 'BMW',
#   'vehicle_model': 'X1',
#   'vehicle_year': 2014,
#   'full_vehicleInfo': {'Year': 2014,
#    'Make': 'BMW',
#    'Model': 'X1',
#    'Category': 'SUV'},
#   'vehicle_category': 'SUV',
#   'vehicle_make_model': 'BMW X1',
#   'vehicle_year_make_model': '2014 BMW X1',
#   'vehicle_year_make_model_cat': '2014 BMW X1 (SUV)'},
#  {'vin': 'XNHJ8RSN80J3J6NVG',
#   'license_plate': 'GG42RIR',
#   'vehicle_make': 'Subaru',
#   'vehicle_model': 'Legacy',
#   'vehicle_year': 1995,
#   'full_vehicleInfo': {'Year': 1995,
#    'Make': 'Subaru',
#    'Model': 'Legacy',
#    'Category': 'Sedan, Wagon'},
#   'vehicle_category': 'Sedan, Wagon',
#   'vehicle_make_model': 'Subaru Legacy',
#   'vehicle_year_make_model': '1995 Subaru Legacy',
#   'vehicle_year_make_model_cat': '1995 Subaru Legacy (Sedan, Wagon)'},
#  {'vin': '7FF4EE472TMX791AT',
#   'license_plate': 'PU54GYJ',
#   'vehicle_make': 'Dodge',
#   'vehicle_model': 'Sprinter 2500 Cargo',
#   'vehicle_year': 2006,
#   'full_vehicleInfo': {'Year': 2006,
#    'Make': 'Dodge',
#    'Model': 'Sprinter 2500 Cargo',
#    'Category': 'Van/Minivan'},
#   'vehicle_category': 'Van/Minivan',
#   'vehicle_make_model': 'Dodge Sprinter 2500 Cargo',
#   'vehicle_year_make_model': '2006 Dodge Sprinter 2500 Cargo',
#   'vehicle_year_make_model_cat': '2006 Dodge Sprinter 2500 Cargo (Van/Minivan)'},
#  {'vin': '46E3BTB33SYBJ31K7',
#   'license_plate': 'JO72URQ',
#   'vehicle_make': 'Suzuki',
#   'vehicle_model': 'Samurai',
#   'vehicle_year': 1994,
#   'full_vehicleInfo': {'Year': 1994,
#    'Make': 'Suzuki',
#    'Model': 'Samurai',
#    'Category': 'SUV'},
#   'vehicle_category': 'SUV',
#   'vehicle_make_model': 'Suzuki Samurai',
#   'vehicle_year_make_model': '1994 Suzuki Samurai',
#   'vehicle_year_make_model_cat': '1994 Suzuki Samurai (SUV)'},
#  {'vin': 'ZWHC8MAW2GB1MJCBS',
#   'license_plate': 'QK12CMV',
#   'vehicle_make': 'Mercedes-Benz',
#   'vehicle_model': 'S-Class',
#   'vehicle_year': 1996,
#   'full_vehicleInfo': {'Year': 1996,
#    'Make': 'Mercedes-Benz',
#    'Model': 'S-Class',
#    'Category': 'Sedan, Coupe'},
#   'vehicle_category': 'Sedan, Coupe',
#   'vehicle_make_model': 'Mercedes-Benz S-Class',
#   'vehicle_year_make_model': '1996 Mercedes-Benz S-Class',
#   'vehicle_year_make_model_cat': '1996 Mercedes-Benz S-Class (Sedan, Coupe)'},
#  {'vin': '9XLF1GRF3VHMK1GPF',
#   'license_plate': 'VD68 OJF',
#   'vehicle_make': 'Toyota',
#   'vehicle_model': 'RAV4 Hybrid',
#   'vehicle_year': 2018,
#   'full_vehicleInfo': {'Year': 2018,
#    'Make': 'Toyota',
#    'Model': 'RAV4 Hybrid',
#    'Category': 'SUV'},
#   'vehicle_category': 'SUV',
#   'vehicle_make_model': 'Toyota RAV4 Hybrid',
#   'vehicle_year_make_model': '2018 Toyota RAV4 Hybrid',
#   'vehicle_year_make_model_cat': '2018 Toyota RAV4 Hybrid (SUV)'},
#  {'vin': 'K8JPEE9X30WPTXDF6',
#   'license_plate': 'QW10LCS',
#   'vehicle_make': 'Volvo',
#   'vehicle_model': 'XC60',
#   'vehicle_year': 2013,
#   'full_vehicleInfo': {'Year': 2013,
#    'Make': 'Volvo',
#    'Model': 'XC60',
#    'Category': 'SUV'},
#   'vehicle_category': 'SUV',
#   'vehicle_make_model': 'Volvo XC60',
#   'vehicle_year_make_model': '2013 Volvo XC60',
#   'vehicle_year_make_model_cat': '2013 Volvo XC60 (SUV)'},
#  {'vin': 'ZC0ALV8DXY6ZV4W9Z',
#   'license_plate': 'OS40BRO',
#   'vehicle_make': 'Dodge',
#   'vehicle_model': 'Challenger',
#   'vehicle_year': 2009,
#   'full_vehicleInfo': {'Year': 2009,
#    'Make': 'Dodge',
#    'Model': 'Challenger',
#    'Category': 'Coupe'},
#   'vehicle_category': 'Coupe',
#   'vehicle_make_model': 'Dodge Challenger',
#   'vehicle_year_make_model': '2009 Dodge Challenger',
#   'vehicle_year_make_model_cat': '2009 Dodge Challenger (Coupe)'},
#  {'vin': 'SG1D53UN1545X3JTB',
#   'license_plate': 'YU56 XUN',
#   'vehicle_make': 'Lexus',
#   'vehicle_model': 'IS',
#   'vehicle_year': 2020,
#   'full_vehicleInfo': {'Year': 2020,
#    'Make': 'Lexus',
#    'Model': 'IS',
#    'Category': 'Sedan'},
#   'vehicle_category': 'Sedan',
#   'vehicle_make_model': 'Lexus IS',
#   'vehicle_year_make_model': '2020 Lexus IS',
#   'vehicle_year_make_model_cat': '2020 Lexus IS (Sedan)'},
#  {'vin': 'VRR69N8B9S9E12KWU',
#   'license_plate': 'HH43OLE',
#   'vehicle_make': 'Volvo',
#   'vehicle_model': 'C30',
#   'vehicle_year': 2013,
#   'full_vehicleInfo': {'Year': 2013,
#    'Make': 'Volvo',
#    'Model': 'C30',
#    'Category': 'Hatchback'},
#   'vehicle_category': 'Hatchback',
#   'vehicle_make_model': 'Volvo C30',
#   'vehicle_year_make_model': '2013 Volvo C30',
#   'vehicle_year_make_model_cat': '2013 Volvo C30 (Hatchback)'},
#  {'vin': '83T2FD5713V4F3SVE',
#   'license_plate': 'YY43 BEQ',
#   'vehicle_make': 'Buick',
#   'vehicle_model': 'Century',
#   'vehicle_year': 1998,
#   'full_vehicleInfo': {'Year': 1998,
#    'Make': 'Buick',
#    'Model': 'Century',
#    'Category': 'Sedan'},
#   'vehicle_category': 'Sedan',
#   'vehicle_make_model': 'Buick Century',
#   'vehicle_year_make_model': '1998 Buick Century',
#   'vehicle_year_make_model_cat': '1998 Buick Century (Sedan)'},
#  {'vin': 'LLFK0ETK0H4BUY4NR',
#   'license_plate': 'WN62NEJ',
#   'vehicle_make': 'GMC',
#   'vehicle_model': 'Sonoma Regular Cab',
#   'vehicle_year': 1995,
#   'full_vehicleInfo': {'Year': 1995,
#    'Make': 'GMC',
#    'Model': 'Sonoma Regular Cab',
#    'Category': 'Pickup'},
#   'vehicle_category': 'Pickup',
#   'vehicle_make_model': 'GMC Sonoma Regular Cab',
#   'vehicle_year_make_model': '1995 GMC Sonoma Regular Cab',
#   'vehicle_year_make_model_cat': '1995 GMC Sonoma Regular Cab (Pickup)'},
#  {'vin': 'XFEK0W4T5T9RFGDM6',
#   'license_plate': 'LC04RXG',
#   'vehicle_make': 'Toyota',
#   'vehicle_model': 'Avalon',
#   'vehicle_year': 2003,
#   'full_vehicleInfo': {'Year': 2003,
#    'Make': 'Toyota',
#    'Model': 'Avalon',
#    'Category': 'Sedan'},
#   'vehicle_category': 'Sedan',
#   'vehicle_make_model': 'Toyota Avalon',
#   'vehicle_year_make_model': '2003 Toyota Avalon',
#   'vehicle_year_make_model_cat': '2003 Toyota Avalon (Sedan)'},
#  {'vin': 'R35CDXDM4K1DC8XFD',
#   'license_plate': 'HR67KYJ',
#   'vehicle_make': 'Mercedes-Benz',
#   'vehicle_model': 'C-Class',
#   'vehicle_year': 2004,
#   'full_vehicleInfo': {'Year': 2004,
#    'Make': 'Mercedes-Benz',
#    'Model': 'C-Class',
#    'Category': 'Sedan, Coupe, Wagon'},
#   'vehicle_category': 'Sedan, Coupe, Wagon',
#   'vehicle_make_model': 'Mercedes-Benz C-Class',
#   'vehicle_year_make_model': '2004 Mercedes-Benz C-Class',
#   'vehicle_year_make_model_cat': '2004 Mercedes-Benz C-Class (Sedan, Coupe, Wagon)'},
#  {'vin': 'NKGPZYW73XLDPLT3E',
#   'license_plate': 'AI64 RSS',
#   'vehicle_make': 'Chevrolet',
#   'vehicle_model': 'Traverse',
#   'vehicle_year': 2018,
#   'full_vehicleInfo': {'Year': 2018,
#    'Make': 'Chevrolet',
#    'Model': 'Traverse',
#    'Category': 'SUV'},
#   'vehicle_category': 'SUV',
#   'vehicle_make_model': 'Chevrolet Traverse',
#   'vehicle_year_make_model': '2018 Chevrolet Traverse',
#   'vehicle_year_make_model_cat': '2018 Chevrolet Traverse (SUV)'},
#  {'vin': '0CMERFYM5GYYWANA9',
#   'license_plate': 'FR01UBQ',
#   'vehicle_make': 'Lincoln',
#   'vehicle_model': 'Navigator',
#   'vehicle_year': 2008,
#   'full_vehicleInfo': {'Year': 2008,
#    'Make': 'Lincoln',
#    'Model': 'Navigator',
#    'Category': 'SUV'},
#   'vehicle_category': 'SUV',
#   'vehicle_make_model': 'Lincoln Navigator',
#   'vehicle_year_make_model': '2008 Lincoln Navigator',
#   'vehicle_year_make_model_cat': '2008 Lincoln Navigator (SUV)'},
#  {'vin': '41T9E5018DZWP4XY2',
#   'license_plate': 'RR84 NAA',
#   'vehicle_make': 'Mitsubishi',
#   'vehicle_model': 'Diamante',
#   'vehicle_year': 1999,
#   'full_vehicleInfo': {'Year': 1999,
#    'Make': 'Mitsubishi',
#    'Model': 'Diamante',
#    'Category': 'Sedan'},
#   'vehicle_category': 'Sedan',
#   'vehicle_make_model': 'Mitsubishi Diamante',
#   'vehicle_year_make_model': '1999 Mitsubishi Diamante',
#   'vehicle_year_make_model_cat': '1999 Mitsubishi Diamante (Sedan)'},
#  {'vin': 'J2ZUB7702FCGNHS6P',
#   'license_plate': 'OS41HWH',
#   'vehicle_make': 'Cadillac',
#   'vehicle_model': 'SRX',
#   'vehicle_year': 2006,
#   'full_vehicleInfo': {'Year': 2006,
#    'Make': 'Cadillac',
#    'Model': 'SRX',
#    'Category': 'SUV'},
#   'vehicle_category': 'SUV',
#   'vehicle_make_model': 'Cadillac SRX',
#   'vehicle_year_make_model': '2006 Cadillac SRX',
#   'vehicle_year_make_model_cat': '2006 Cadillac SRX (SUV)'},
#  {'vin': '36SRRX416A6YUM73E',
#   'license_plate': 'WS14 PIB',
#   'vehicle_make': 'Acura',
#   'vehicle_model': 'RLX',
#   'vehicle_year': 2018,
#   'full_vehicleInfo': {'Year': 2018,
#    'Make': 'Acura',
#    'Model': 'RLX',
#    'Category': 'Sedan'},
#   'vehicle_category': 'Sedan',
#   'vehicle_make_model': 'Acura RLX',
#   'vehicle_year_make_model': '2018 Acura RLX',
#   'vehicle_year_make_model_cat': '2018 Acura RLX (Sedan)'},
#  {'vin': '3BL2D0S51KAFRMR96',
#   'license_plate': 'BD59NHC',
#   'vehicle_make': 'Ford',
#   'vehicle_model': 'Edge',
#   'vehicle_year': 2013,
#   'full_vehicleInfo': {'Year': 2013,
#    'Make': 'Ford',
#    'Model': 'Edge',
#    'Category': 'SUV'},
#   'vehicle_category': 'SUV',
#   'vehicle_make_model': 'Ford Edge',
#   'vehicle_year_make_model': '2013 Ford Edge',
#   'vehicle_year_make_model_cat': '2013 Ford Edge (SUV)'},
#  {'vin': 'SL2HVYEN7RUBR6JF5',
#   'license_plate': 'IE26 MWZ',
#   'vehicle_make': 'BMW',
#   'vehicle_model': '5 Series',
#   'vehicle_year': 2005,
#   'full_vehicleInfo': {'Year': 2005,
#    'Make': 'BMW',
#    'Model': '5 Series',
#    'Category': 'Sedan'},
#   'vehicle_category': 'Sedan',
#   'vehicle_make_model': 'BMW 5 Series',
#   'vehicle_year_make_model': '2005 BMW 5 Series',
#   'vehicle_year_make_model_cat': '2005 BMW 5 Series (Sedan)'},
#  {'vin': 'LP761KVP4H796BUVZ',
#   'license_plate': 'DA19CLR',
#   'vehicle_make': 'Acura',
#   'vehicle_model': 'TL',
#   'vehicle_year': 2008,
#   'full_vehicleInfo': {'Year': 2008,
#    'Make': 'Acura',
#    'Model': 'TL',
#    'Category': 'Sedan'},
#   'vehicle_category': 'Sedan',
#   'vehicle_make_model': 'Acura TL',
#   'vehicle_year_make_model': '2008 Acura TL',
#   'vehicle_year_make_model_cat': '2008 Acura TL (Sedan)'},
#  {'vin': 'LR1JTR6FXARA9HKHY',
#   'license_plate': 'CF47 NIN',
#   'vehicle_make': 'Chrysler',
#   'vehicle_model': '300M',
#   'vehicle_year': 2001,
#   'full_vehicleInfo': {'Year': 2001,
#    'Make': 'Chrysler',
#    'Model': '300M',
#    'Category': 'Sedan'},
#   'vehicle_category': 'Sedan',
#   'vehicle_make_model': 'Chrysler 300M',
# ...
#   'vehicle_year_make_model': '1996 Audi A6',
#   'vehicle_year_make_model_cat': '1996 Audi A6 (Sedan, Wagon)'},
#  {'vin': 'XJ32E5460EFPCB9AK',
#   'license_plate': 'CC00SHM',
#   'vehicle_make': 'Acura',
#   'vehicle_model': 'TLX',
#   'vehicle_year': 2016,
#   'full_vehicleInfo': {'Year': 2016,
#    'Make': 'Acura',
#    'Model': 'TLX',
#    'Category': 'Sedan'},
#   'vehicle_category': 'Sedan',
#   'vehicle_make_model': 'Acura TLX',
#   'vehicle_year_make_model': '2016 Acura TLX',
#   'vehicle_year_make_model_cat': '2016 Acura TLX (Sedan)'},
#  {'vin': 'T20WY3LS1HS8T4XU9',
#   'license_plate': 'JG50WQW',
#   'vehicle_make': 'Pontiac',
#   'vehicle_model': 'LeMans',
#   'vehicle_year': 1993,
#   'full_vehicleInfo': {'Year': 1993,
#    'Make': 'Pontiac',
#    'Model': 'LeMans',
#    'Category': 'Hatchback, Sedan'},
#   'vehicle_category': 'Hatchback, Sedan',
#   'vehicle_make_model': 'Pontiac LeMans',
#   'vehicle_year_make_model': '1993 Pontiac LeMans',
#   'vehicle_year_make_model_cat': '1993 Pontiac LeMans (Hatchback, Sedan)'},
#  {'vin': '1LEWBCHU76VU0E8DC',
#   'license_plate': 'DA44UZT',
#   'vehicle_make': 'Cadillac',
#   'vehicle_model': 'SRX',
#   'vehicle_year': 2011,
#   'full_vehicleInfo': {'Year': 2011,
#    'Make': 'Cadillac',
#    'Model': 'SRX',
#    'Category': 'SUV'},
#   'vehicle_category': 'SUV',
#   'vehicle_make_model': 'Cadillac SRX',
#   'vehicle_year_make_model': '2011 Cadillac SRX',
#   'vehicle_year_make_model_cat': '2011 Cadillac SRX (SUV)'},
#  {'vin': '6UK9C7RN7HJ8CWBWX',
#   'license_plate': 'QL06PNY',
#   'vehicle_make': 'BMW',
#   'vehicle_model': '5 Series',
#   'vehicle_year': 2007,
#   'full_vehicleInfo': {'Year': 2007,
#    'Make': 'BMW',
#    'Model': '5 Series',
#    'Category': 'Sedan, Wagon'},
#   'vehicle_category': 'Sedan, Wagon',
#   'vehicle_make_model': 'BMW 5 Series',
#   'vehicle_year_make_model': '2007 BMW 5 Series',
#   'vehicle_year_make_model_cat': '2007 BMW 5 Series (Sedan, Wagon)'},
#  {'vin': 'DGJB3HU52XLM7ZV26',
#   'license_plate': 'TT42SGF',
#   'vehicle_make': 'Volvo',
#   'vehicle_model': 'C70',
#   'vehicle_year': 2011,
#   'full_vehicleInfo': {'Year': 2011,
#    'Make': 'Volvo',
#    'Model': 'C70',
#    'Category': 'Convertible'},
#   'vehicle_category': 'Convertible',
#   'vehicle_make_model': 'Volvo C70',
#   'vehicle_year_make_model': '2011 Volvo C70',
#   'vehicle_year_make_model_cat': '2011 Volvo C70 (Convertible)'},
#  {'vin': '3AJEVKHH35YAEHNUM',
#   'license_plate': 'QM90 SIO',
#   'vehicle_make': 'Volkswagen',
#   'vehicle_model': 'Passat',
#   'vehicle_year': 1994,
#   'full_vehicleInfo': {'Year': 1994,
#    'Make': 'Volkswagen',
#    'Model': 'Passat',
#    'Category': 'Sedan, Wagon'},
#   'vehicle_category': 'Sedan, Wagon',
#   'vehicle_make_model': 'Volkswagen Passat',
#   'vehicle_year_make_model': '1994 Volkswagen Passat',
#   'vehicle_year_make_model_cat': '1994 Volkswagen Passat (Sedan, Wagon)'},
#  {'vin': 'ANJPER9T43HWBCUH5',
#   'license_plate': 'AT55 KHQ',
#   'vehicle_make': 'GMC',
#   'vehicle_model': 'Yukon',
#   'vehicle_year': 2000,
#   'full_vehicleInfo': {'Year': 2000,
#    'Make': 'GMC',
#    'Model': 'Yukon',
#    'Category': 'SUV'},
#   'vehicle_category': 'SUV',
#   'vehicle_make_model': 'GMC Yukon',
#   'vehicle_year_make_model': '2000 GMC Yukon',
#   'vehicle_year_make_model_cat': '2000 GMC Yukon (SUV)'},
#  {'vin': 'XHB6SHFL223EX5GU4',
#   'license_plate': 'PU14UNX',
#   'vehicle_make': 'Toyota',
#   'vehicle_model': 'Tundra CrewMax',
#   'vehicle_year': 2014,
#   'full_vehicleInfo': {'Year': 2014,
#    'Make': 'Toyota',
#    'Model': 'Tundra CrewMax',
#    'Category': 'Pickup'},
#   'vehicle_category': 'Pickup',
#   'vehicle_make_model': 'Toyota Tundra CrewMax',
#   'vehicle_year_make_model': '2014 Toyota Tundra CrewMax',
#   'vehicle_year_make_model_cat': '2014 Toyota Tundra CrewMax (Pickup)'},
#  {'vin': 'EWZGHDW49SR6VNTGT',
#   'license_plate': 'EV68MYH',
#   'vehicle_make': 'Lexus',
#   'vehicle_model': 'RX',
#   'vehicle_year': 1999,
#   'full_vehicleInfo': {'Year': 1999,
#    'Make': 'Lexus',
#    'Model': 'RX',
#    'Category': 'SUV'},
#   'vehicle_category': 'SUV',
#   'vehicle_make_model': 'Lexus RX',
#   'vehicle_year_make_model': '1999 Lexus RX',
#   'vehicle_year_make_model_cat': '1999 Lexus RX (SUV)'},
#  {'vin': '5PK6P3400VXA81KM3',
#   'license_plate': 'UR35MAJ',
#   'vehicle_make': 'Subaru',
#   'vehicle_model': 'XV Crosstrek',
#   'vehicle_year': 2014,
#   'full_vehicleInfo': {'Year': 2014,
#    'Make': 'Subaru',
#    'Model': 'XV Crosstrek',
#    'Category': 'SUV'},
#   'vehicle_category': 'SUV',
#   'vehicle_make_model': 'Subaru XV Crosstrek',
#   'vehicle_year_make_model': '2014 Subaru XV Crosstrek',
#   'vehicle_year_make_model_cat': '2014 Subaru XV Crosstrek (SUV)'},
#  {'vin': 'TU3M3EFV1HUZFD2SX',
#   'license_plate': 'VG18AMP',
#   'vehicle_make': 'Audi',
#   'vehicle_model': 'A7',
#   'vehicle_year': 2019,
#   'full_vehicleInfo': {'Year': 2019,
#    'Make': 'Audi',
#    'Model': 'A7',
#    'Category': 'Sedan'},
#   'vehicle_category': 'Sedan',
#   'vehicle_make_model': 'Audi A7',
#   'vehicle_year_make_model': '2019 Audi A7',
#   'vehicle_year_make_model_cat': '2019 Audi A7 (Sedan)'},
#  {'vin': '9BBTTXH692ZVZZUMD',
#   'license_plate': 'VT73ZBM',
#   'vehicle_make': 'Ferrari',
#   'vehicle_model': '599 GTB Fiorano',
#   'vehicle_year': 2011,
#   'full_vehicleInfo': {'Year': 2011,
#    'Make': 'Ferrari',
#    'Model': '599 GTB Fiorano',
#    'Category': 'Coupe'},
#   'vehicle_category': 'Coupe',
#   'vehicle_make_model': 'Ferrari 599 GTB Fiorano',
#   'vehicle_year_make_model': '2011 Ferrari 599 GTB Fiorano',
#   'vehicle_year_make_model_cat': '2011 Ferrari 599 GTB Fiorano (Coupe)'},
#  {'vin': 'TDKAZZXS02LL2K998',
#   'license_plate': 'BI18URN',
#   'vehicle_make': 'MAZDA',
#   'vehicle_model': 'MX-5 Miata',
#   'vehicle_year': 1996,
#   'full_vehicleInfo': {'Year': 1996,
#    'Make': 'MAZDA',
#    'Model': 'MX-5 Miata',
#    'Category': 'Convertible'},
#   'vehicle_category': 'Convertible',
#   'vehicle_make_model': 'MAZDA MX-5 Miata',
#   'vehicle_year_make_model': '1996 MAZDA MX-5 Miata',
#   'vehicle_year_make_model_cat': '1996 MAZDA MX-5 Miata (Convertible)'},
#  {'vin': 'SV2TSDB415SA1XCBZ',
#   'license_plate': 'VS18 RFP',
#   'vehicle_make': 'Buick',
#   'vehicle_model': 'Rendezvous',
#   'vehicle_year': 2006,
#   'full_vehicleInfo': {'Year': 2006,
#    'Make': 'Buick',
#    'Model': 'Rendezvous',
#    'Category': 'SUV'},
#   'vehicle_category': 'SUV',
#   'vehicle_make_model': 'Buick Rendezvous',
#   'vehicle_year_make_model': '2006 Buick Rendezvous',
#   'vehicle_year_make_model_cat': '2006 Buick Rendezvous (SUV)'},
#  {'vin': '0TLDEW6W91UKGASJA',
#   'license_plate': 'GW31 WSR',
#   'vehicle_make': 'Lexus',
#   'vehicle_model': 'RX',
#   'vehicle_year': 2017,
#   'full_vehicleInfo': {'Year': 2017,
#    'Make': 'Lexus',
#    'Model': 'RX',
#    'Category': 'SUV'},
#   'vehicle_category': 'SUV',
#   'vehicle_make_model': 'Lexus RX',
#   'vehicle_year_make_model': '2017 Lexus RX',
#   'vehicle_year_make_model_cat': '2017 Lexus RX (SUV)'},
#  {'vin': 'FLK28JNT1V2RB5MVC',
#   'license_plate': 'LI43 TQF',
#   'vehicle_make': 'Buick',
#   'vehicle_model': 'Enclave',
#   'vehicle_year': 2011,
#   'full_vehicleInfo': {'Year': 2011,
#    'Make': 'Buick',
#    'Model': 'Enclave',
#    'Category': 'SUV'},
#   'vehicle_category': 'SUV',
#   'vehicle_make_model': 'Buick Enclave',
#   'vehicle_year_make_model': '2011 Buick Enclave',
#   'vehicle_year_make_model_cat': '2011 Buick Enclave (SUV)'},
#  {'vin': 'ZHF405W88TXZ1RRHE',
#   'license_plate': 'KU01 QSY',
#   'vehicle_make': 'Isuzu',
#   'vehicle_model': 'Trooper',
#   'vehicle_year': 1998,
#   'full_vehicleInfo': {'Year': 1998,
#    'Make': 'Isuzu',
#    'Model': 'Trooper',
#    'Category': 'SUV'},
#   'vehicle_category': 'SUV',
#   'vehicle_make_model': 'Isuzu Trooper',
#   'vehicle_year_make_model': '1998 Isuzu Trooper',
#   'vehicle_year_make_model_cat': '1998 Isuzu Trooper (SUV)'},
#  {'vin': 'RG0Z6M1C5V38X40TK',
#   'license_plate': 'OB80 GAQ',
#   'vehicle_make': 'Porsche',
#   'vehicle_model': 'Cayenne',
#   'vehicle_year': 2010,
#   'full_vehicleInfo': {'Year': 2010,
#    'Make': 'Porsche',
#    'Model': 'Cayenne',
#    'Category': 'SUV'},
#   'vehicle_category': 'SUV',
#   'vehicle_make_model': 'Porsche Cayenne',
#   'vehicle_year_make_model': '2010 Porsche Cayenne',
#   'vehicle_year_make_model_cat': '2010 Porsche Cayenne (SUV)'},
#  {'vin': '5WAS0ATB6JKL22W0Z',
#   'license_plate': 'SF41UUO',
#   'vehicle_make': 'Dodge',
#   'vehicle_model': 'Ram Van 1500',
#   'vehicle_year': 2003,
#   'full_vehicleInfo': {'Year': 2003,
#    'Make': 'Dodge',
#    'Model': 'Ram Van 1500',
#    'Category': 'Van/Minivan'},
#   'vehicle_category': 'Van/Minivan',
#   'vehicle_make_model': 'Dodge Ram Van 1500',
#   'vehicle_year_make_model': '2003 Dodge Ram Van 1500',
#   'vehicle_year_make_model_cat': '2003 Dodge Ram Van 1500 (Van/Minivan)'},
#  {'vin': '5T1U8R8A4XSS91392',
#   'license_plate': 'TD26 OBU',
#   'vehicle_make': 'Toyota',
#   'vehicle_model': 'MR2',
#   'vehicle_year': 2004,
#   'full_vehicleInfo': {'Year': 2004,
#    'Make': 'Toyota',
#    'Model': 'MR2',
#    'Category': 'Convertible'},
#   'vehicle_category': 'Convertible',
#   'vehicle_make_model': 'Toyota MR2',
#   'vehicle_year_make_model': '2004 Toyota MR2',
#   'vehicle_year_make_model_cat': '2004 Toyota MR2 (Convertible)'},
#  {'vin': 'CGHHDLRB6GMY16B1J',
#   'license_plate': 'JF69 VLG',
#   'vehicle_make': 'Acura',
#   'vehicle_model': 'ILX',
#   'vehicle_year': 2014,
#   'full_vehicleInfo': {'Year': 2014,
#    'Make': 'Acura',
#    'Model': 'ILX',
#    'Category': 'Sedan'},
#   'vehicle_category': 'Sedan',
#   'vehicle_make_model': 'Acura ILX',
#   'vehicle_year_make_model': '2014 Acura ILX',
#   'vehicle_year_make_model_cat': '2014 Acura ILX (Sedan)'},
#  {'vin': '260EWPF18BHVS4FRV',
#   'license_plate': 'EY52 JHM',
#   'vehicle_make': 'Honda',
#   'vehicle_model': 'Odyssey',
#   'vehicle_year': 1998,
#   'full_vehicleInfo': {'Year': 1998,
#    'Make': 'Honda',
#    'Model': 'Odyssey',
#    'Category': 'Van/Minivan'},
#   'vehicle_category': 'Van/Minivan',
#   'vehicle_make_model': 'Honda Odyssey',
#   'vehicle_year_make_model': '1998 Honda Odyssey',
#   'vehicle_year_make_model_cat': '1998 Honda Odyssey (Van/Minivan)'},
#  {'vin': 'K3NNEUGZ26VPH2FSH',
#   'license_plate': 'DL73 WSO',
#   'vehicle_make': 'Ford',
#   'vehicle_model': 'F350 Crew Cab',
#   'vehicle_year': 1993,
#   'full_vehicleInfo': {'Year': 1993,
#    'Make': 'Ford',
#    'Model': 'F350 Crew Cab',
#    'Category': 'Pickup'},
#   'vehicle_category': 'Pickup',
#   'vehicle_make_model': 'Ford F350 Crew Cab',
#   'vehicle_year_make_model': '1993 Ford F350 Crew Cab',
#   'vehicle_year_make_model_cat': '1993 Ford F350 Crew Cab (Pickup)'},
#  {'vin': 'PHST0C9EXU3RSWTJ5',
#   'license_plate': 'LS22 JSP',
#   'vehicle_make': 'Ferrari',
#   'vehicle_model': '458 Spider',
#   'vehicle_year': 2014,
#   'full_vehicleInfo': {'Year': 2014,
#    'Make': 'Ferrari',
#    'Model': '458 Spider',
#    'Category': 'Convertible'},
#   'vehicle_category': 'Convertible',
#   'vehicle_make_model': 'Ferrari 458 Spider',
#   'vehicle_year_make_model': '2014 Ferrari 458 Spider',
#   'vehicle_year_make_model_cat': '2014 Ferrari 458 Spider (Convertible)'},
#  {'vin': '4GBRBAT931RTS5WTB',
#   'license_plate': 'LM29 TST',
#   'vehicle_make': 'Volvo',
#   'vehicle_model': 'XC60',
#   'vehicle_year': 2017,
#   'full_vehicleInfo': {'Year': 2017,
#    'Make': 'Volvo',
#    'Model': 'XC60',
#    'Category': 'SUV'},
#   'vehicle_category': 'SUV',
#   'vehicle_make_model': 'Volvo XC60',
#   'vehicle_year_make_model': '2017 Volvo XC60',
#   'vehicle_year_make_model_cat': '2017 Volvo XC60 (SUV)'},
#  {'vin': 'FDLXSZWYXVBPU1K8F',
#   'license_plate': 'QF49BQZ',
#   'vehicle_make': 'Ford',
#   'vehicle_model': 'Escape',
#   'vehicle_year': 2003,
#   'full_vehicleInfo': {'Year': 2003,
#    'Make': 'Ford',
#    'Model': 'Escape',
#    'Category': 'SUV'},
#   'vehicle_category': 'SUV',
#   'vehicle_make_model': 'Ford Escape',
#   'vehicle_year_make_model': '2003 Ford Escape',
#   'vehicle_year_make_model_cat': '2003 Ford Escape (SUV)'},
#  {'vin': 'F7LCC6099S1215JK4',
#   'license_plate': 'ME14TXX',
#   'vehicle_make': 'Maserati',
#   'vehicle_model': 'Coupe',
#   'vehicle_year': 2005,
#   'full_vehicleInfo': {'Year': 2005,
#    'Make': 'Maserati',
#    'Model': 'Coupe',
#    'Category': 'Coupe'},
#   'vehicle_category': 'Coupe',
#   'vehicle_make_model': 'Maserati Coupe',
#   'vehicle_year_make_model': '2005 Maserati Coupe',
#   'vehicle_year_make_model_cat': '2005 Maserati Coupe (Coupe)'},
#  {'vin': 'E3J5DK827DYL0X93U',
#   'license_plate': 'VM24JFX',
#   'vehicle_make': 'Buick',
#   'vehicle_model': 'Encore',
#   'vehicle_year': 2020,
#   'full_vehicleInfo': {'Year': 2020,
#    'Make': 'Buick',
#    'Model': 'Encore',
#    'Category': 'SUV'},
#   'vehicle_category': 'SUV',
#   'vehicle_make_model': 'Buick Encore',
#   'vehicle_year_make_model': '2020 Buick Encore',
#   'vehicle_year_make_model_cat': '2020 Buick Encore (SUV)'},
#  {'vin': '1M04BEME62YUU7GS9',
#   'license_plate': 'UL01 MRE',
#   'vehicle_make': 'Ford',
#   'vehicle_model': 'Expedition',
#   'vehicle_year': 2007,
#   'full_vehicleInfo': {'Year': 2007,
#    'Make': 'Ford',
#    'Model': 'Expedition',
#    'Category': 'SUV'},
#   'vehicle_category': 'SUV',
#   'vehicle_make_model': 'Ford Expedition',
#   'vehicle_year_make_model': '2007 Ford Expedition',
#   'vehicle_year_make_model_cat': '2007 Ford Expedition (SUV)'},
#  {'vin': 'XPF1VTT7XUMX0J1KF',
#   'license_plate': 'PI53DWF',
#   'vehicle_make': 'INFINITI',
#   'vehicle_model': 'I',
#   'vehicle_year': 2003,
#   'full_vehicleInfo': {'Year': 2003,
#    'Make': 'INFINITI',
#    'Model': 'I',
#    'Category': 'Sedan'},
#   'vehicle_category': 'Sedan',
#   'vehicle_make_model': 'INFINITI I',
#   'vehicle_year_make_model': '2003 INFINITI I',
#   'vehicle_year_make_model_cat': '2003 INFINITI I (Sedan)'},
#  {'vin': '5CXLS7147YYYCA5YN',
#   'license_plate': 'HN20 CYS',
#   'vehicle_make': 'Toyota',
#   'vehicle_model': 'RAV4',
#   'vehicle_year': 2006,
#   'full_vehicleInfo': {'Year': 2006,
#    'Make': 'Toyota',
#    'Model': 'RAV4',
#    'Category': 'SUV'},
#   'vehicle_category': 'SUV',
#   'vehicle_make_model': 'Toyota RAV4',
#   'vehicle_year_make_model': '2006 Toyota RAV4',
#   'vehicle_year_make_model_cat': '2006 Toyota RAV4 (SUV)'},
#  {'vin': '0M5CXCDW53CKBJKHV',
#   'license_plate': 'RT76AYI',
#   'vehicle_make': 'Ford',
#   'vehicle_model': 'F350 Super Duty Super Cab',
#   'vehicle_year': 2019,
#   'full_vehicleInfo': {'Year': 2019,
#    'Make': 'Ford',
#    'Model': 'F350 Super Duty Super Cab',
#    'Category': 'Pickup'},
#   'vehicle_category': 'Pickup',
#   'vehicle_make_model': 'Ford F350 Super Duty Super Cab',
#   'vehicle_year_make_model': '2019 Ford F350 Super Duty Super Cab',
#   'vehicle_year_make_model_cat': '2019 Ford F350 Super Duty Super Cab (Pickup)'},
#  {'vin': '2VT9EL51XXTL55X3N',
#   'license_plate': 'PW89 HVF',
#   'vehicle_make': 'Audi',
#   'vehicle_model': 'S8',
#   'vehicle_year': 2008,
#   'full_vehicleInfo': {'Year': 2008,
#    'Make': 'Audi',
#    'Model': 'S8',
#    'Category': 'Sedan'},
#   'vehicle_category': 'Sedan',
#   'vehicle_make_model': 'Audi S8',
#   'vehicle_year_make_model': '2008 Audi S8',
#   'vehicle_year_make_model_cat': '2008 Audi S8 (Sedan)'},
#  {'vin': 'N6HNRCG325NZ1NN67',
#   'license_plate': 'OI96IWZ',
#   'vehicle_make': 'Volkswagen',
#   'vehicle_model': 'Corrado',
#   'vehicle_year': 1994,
#   'full_vehicleInfo': {'Year': 1994,
#    'Make': 'Volkswagen',
#    'Model': 'Corrado',
#    'Category': 'Coupe'},
#   'vehicle_category': 'Coupe',
#   'vehicle_make_model': 'Volkswagen Corrado',
#   'vehicle_year_make_model': '1994 Volkswagen Corrado',
#   'vehicle_year_make_model_cat': '1994 Volkswagen Corrado (Coupe)'},
#  {'vin': 'PF8S4YX134J1F1KLK',
#   'license_plate': 'RI98 AYH',
#   'vehicle_make': 'MAZDA',
#   'vehicle_model': 'MX-6',
#   'vehicle_year': 1996,
#   'full_vehicleInfo': {'Year': 1996,
#    'Make': 'MAZDA',
#    'Model': 'MX-6',
#    'Category': 'Coupe'},
#   'vehicle_category': 'Coupe',
#   'vehicle_make_model': 'MAZDA MX-6',
#   'vehicle_year_make_model': '1996 MAZDA MX-6',
#   'vehicle_year_make_model_cat': '1996 MAZDA MX-6 (Coupe)'},
#  {'vin': '0B62DRSA33FZPSH2V',
#   'license_plate': 'EM51 KFT',
#   'vehicle_make': 'Land Rover',
#   'vehicle_model': 'Range Rover',
#   'vehicle_year': 2014,
#   'full_vehicleInfo': {'Year': 2014,
#    'Make': 'Land Rover',
#    'Model': 'Range Rover',
#    'Category': 'SUV'},
#   'vehicle_category': 'SUV',
#   'vehicle_make_model': 'Land Rover Range Rover',
#   'vehicle_year_make_model': '2014 Land Rover Range Rover',
#   'vehicle_year_make_model_cat': '2014 Land Rover Range Rover (SUV)'},
#  ...]

# %%
# Retrieve the latest record for a specific VIN
vin = "H1AUMH0D9M76R7NNG"
latest_record = get_latest_record(vin, w3)
print(f"Latest record for VIN {vin}: {latest_record}")

# %%
# Retrieve the latest record for a specific VIN
vin = "JPC53EJ63E7RHWPAP"
latest_record = get_latest_record(vin, w3)
print(f"Latest record for VIN {vin}: {latest_record}")

# %%
# Retrieve the latest record for a specific VIN
license_plate = "GV19IWV"
latest_record = get_latest_record(license_plate, w3, "license_plate")
print(f"Latest record for license plate {license_plate}: {latest_record}")

# %% [markdown]
# ## Test 2 - update the record and get the updated version

# %%
# Example Usage
# Append updated record to blockchain
updated_record = {
    "vin": "82HFE9767U326DEZ2",
    "license_plate": "WU37 WRN",
    "vehicle_make": "Mitsubishi",
    "vehicle_model": "Outlander",
    "vehicle_year": 2000,
    "full_vehicleInfo": {
        "Year": 2000,
        "Make": "Mitsubishi",
        "Model": "Outlander",
        "Category": "SUV"
    },
    "vehicle_category": "SUV",
    "vehicle_make_model": "Mitsubishi Outlander",
    "vehicle_year_make_model": "2000 Mitsubishi Outlander",
    "vehicle_year_make_model_cat": "2000 Mitsubishi Outlander (SUV)"
}

tx_hash = append_data_to_blockchain(updated_record, Web3, account, w3)
print(f"Updated record added to blockchain with transaction hash: {tx_hash.hex()}")

# %%
# Retrieve the latest record for a specific VIN
vin = "82HFE9767U326DEZ2"
latest_record = get_latest_record(vin, w3)
print(f"Latest record for VIN {vin}: {latest_record}")

# %% [markdown]
# ## Test 3 - Get historical data to see updates

# %%
vin = "82HFE9767U326DEZ2"
get_record_history(w3, vin)

# %% [markdown]
# ## Test 4 - delete the record

# %%
# Get current status of the record
vin="82HFE9767U326DEZ2"
latest_record = get_latest_record(vin, w3)
print(f"Latest record for VIN {vin}: {latest_record}")

# %%
# Remove the record
vin="82HFE9767U326DEZ2"
delete_record(vin, w3, account)

# %%
# Get current status of the record
vin="82HFE9767U326DEZ2"
latest_record = get_latest_record(vin, w3)
print(f"Latest record for VIN {vin}: {latest_record}")

# %%
# Get historical status of the record
vin="82HFE9767U326DEZ2"
get_record_history(w3, vin)

# %% [markdown]
# # Other

# %% [markdown]
# To test:
# - distributed ledger - how does it work
#   - examples, how, why does it work
# - more data
# - create a db (postgres) and run similar tests against it
# - simple check if existing data in, don't add new data
# - add asserts

# %%
# account, w3 = create_connection("http://127.0.0.1:8545")
# # Retrieve the latest record for a specific VIN
# vin = "JPC53EJ63E7RHWPAP"
# latest_record = get_latest_record(vin, w3)
# print(f"Latest record for VIN {vin}: {latest_record}")
