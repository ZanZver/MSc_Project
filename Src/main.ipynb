# %% [markdown]
# # Install libraries

# %%
# !pip3 install polars
# !pip3 install Web3

# %% [markdown]
# # Import libraries

# %%
from web3 import Web3
import polars as pl
import json

# %% [markdown]
# # Functions

# %%
def create_connection(node_ip="http://127.0.0.1:8545"):
    # Connect to the local Ethereum node
    w3 = Web3(Web3.HTTPProvider(node_ip))

    # Check connection
    if not w3.is_connected():
        raise Exception("Failed to connect to the Ethereum node.")

    # Use the first account for transactions (ensure it's unlocked)
    account = w3.eth.accounts[0]
    
    return account, w3

# %%
def read_data(data_path='data.parquet'):
    """
    Load data from a Parquet file using Polars.
    
    Args:
        data_path (str): Path to the Parquet file.
    
    Returns:
        list[dict]: Data loaded from the Parquet file, converted to a list of dictionaries.
    """
    # Load data from a Parquet file into a Polars DataFrame
    df = pl.read_parquet(data_path)
    
    # Convert Polars DataFrame to a list of dictionaries
    return df.to_dicts()

# %%
# Function to store data in blockchain
def store_data_in_blockchain(data_to_store, account, w3):
    # Convert the data to hexadecimal (Ethereum stores data in hex)
    data_hex = Web3.to_hex(text=json.dumps(data_to_store))

    # Create and send a transaction
    tx = {
        'from': account,
        'to': None,  # Null address for data-only transaction
        'value': 0,  # No Ether transfer
        'gas': 3000000,  # Gas limit
        'gasPrice': w3.to_wei('20', 'gwei'),
        'data': data_hex
    }
    tx_hash = w3.eth.send_transaction(tx)
    return tx_hash

# %%
# Function to retrieve data from blockchain
def retrieve_data_from_blockchain(w3, tx_hash):
    # Get the transaction details
    tx = w3.eth.get_transaction(tx_hash)
    # Decode the `input` field from HexBytes to text
    return Web3.to_text(hexstr=tx['input'].hex())

# %%
# Store data
def store_data(data, account, w3, tx_hashes):
    for record in data:
        tx_hash = store_data_in_blockchain(record, account, w3)
        #print(f"Stored record with transaction hash: {tx_hash.hex()}")
        tx_hashes.append(tx_hash)
    return tx_hashes

# %%
# Retrieve data
def retrive_data(w3, tx_hashes):
    for tx_hash in tx_hashes:
        stored_data = retrieve_data_from_blockchain(w3, tx_hash)
        print(f"Retrieved data from transaction {tx_hash.hex()}: {stored_data}")

# %%
# Function to append new data to the blockchain
def append_data_to_blockchain(record, Web3, account, w3):
    """
    Add a new record (or update) to the blockchain.
    
    Args:
        record (dict): The record to store or update.
    
    Returns:
        str: Transaction hash of the appended record.
    """
    # Convert the data to hexadecimal (Ethereum stores data in hex)
    data_hex = Web3.to_hex(text=json.dumps(record))

    # Create and send a transaction
    tx = {
        'from': account,
        'to': None,  # Null address for data-only transaction
        'value': 0,  # No Ether transfer
        'gas': 3000000,  # Gas limit
        'gasPrice': w3.to_wei('20', 'gwei'),
        'data': data_hex
    }
    tx_hash = w3.eth.send_transaction(tx)
    return tx_hash

# %%
# Function to fetch and decode the latest transaction for a specific key
def get_latest_record(key, w3, key_field='vin'):
    """
    Fetch the latest record for a given key from the blockchain.

    Args:
        key (str): The unique identifier for the record.
        key_field (str): The field name used as the key in the record.

    Returns:
        dict or None: The latest record if found, otherwise None.
    """
    latest_record = None

    # Iterate through the blockchain's transactions
    for block_number in range(w3.eth.block_number + 1):
        block = w3.eth.get_block(block_number, full_transactions=True)
        for tx in block.transactions:
            if tx.to is None:  # Data-only transactions
                # Decode the transaction input (data field)
                data_hex = tx.input.hex()  # Convert HexBytes to a hex string
                try:
                    record = json.loads(Web3.to_text(hexstr=data_hex))
                    if record.get(key_field) == key:
                        latest_record = record
                except Exception as e:
                    print(f"Error decoding transaction: {e}")

    return latest_record

# %%
def get_record_history(w3, key, key_field='vin'):
    """
    Fetch the history of a specific record from the blockchain.

    Args:
        key (str): The unique identifier for the record.
        key_field (str): The field name used as the key in the record.

    Returns:
        list[dict]: A list of all records matching the key in their history.
    """
    history = []

    # Iterate through all blocks
    for block_number in range(w3.eth.block_number + 1):
        block = w3.eth.get_block(block_number, full_transactions=True)
        for tx in block.transactions:
            if tx.to is None:  # Data-only transactions
                try:
                    # Decode the transaction input (data field)
                    data_hex = tx.input.hex()  # Convert HexBytes to a hex string
                    record = json.loads(Web3.to_text(hexstr=data_hex))
                    
                    # Check if the transaction contains the relevant key
                    if record.get(key_field) == key:
                        history.append(record)
                except Exception as e:
                    print(f"Error decoding transaction: {e}")

    return history

# %% [markdown]
# # Main

# %% [markdown]
# ## Create connection

# %%
tx_hashes = []

account, w3 = create_connection()

# %% [markdown]
# ## Read data from parquet

# %%
data = read_data("../Data/Transform/Small/data.parquet")

# %% [markdown]
# ## Save data to blockchain

# %%
tx_hashes = store_data(data, account, w3, tx_hashes)

# %% [markdown]
# ## Retrive data from blockchain

# %%
retrive_data(w3, tx_hashes)
# Out:
# Retrieved data from transaction b77d39e4c836a4c590b6e23c623eb9350a5b79a15f3b8a1ea5d248e0cb7f2a90: {"vin": "82HFE9767U326DEZ2", "license_plate": "WU37 WRN", "vehicle_make": "Mitsubishi", "vehicle_model": "Montero", "vehicle_year": 1999, "full_vehicleInfo": {"Year": 1999, "Make": "Mitsubishi", "Model": "Montero", "Category": "SUV"}, "vehicle_category": "SUV", "vehicle_make_model": "Mitsubishi Montero", "vehicle_year_make_model": "1999 Mitsubishi Montero", "vehicle_year_make_model_cat": "1999 Mitsubishi Montero (SUV)"}
# Retrieved data from transaction 6f76e0e63b29f72413fad000d70a5bf32a7eee56ba501add9c9c4bff62cc27f7: {"vin": "H1AUMH0D9M76R7NNG", "license_plate": "XO18 RDM", "vehicle_make": "Ferrari", "vehicle_model": "612 Scaglietti", "vehicle_year": 2006, "full_vehicleInfo": {"Year": 2006, "Make": "Ferrari", "Model": "612 Scaglietti", "Category": "Coupe"}, "vehicle_category": "Coupe", "vehicle_make_model": "Ferrari 612 Scaglietti", "vehicle_year_make_model": "2006 Ferrari 612 Scaglietti", "vehicle_year_make_model_cat": "2006 Ferrari 612 Scaglietti (Coupe)"}
# Retrieved data from transaction bc1bbfa98f4be03b64ee31f083095b43e74662fdf9159ebf49ecd3bcf0dc2210: {"vin": "JPC53EJ63E7RHWPAP", "license_plate": "GV19IWV", "vehicle_make": "GMC", "vehicle_model": "Envoy", "vehicle_year": 2002, "full_vehicleInfo": {"Year": 2002, "Make": "GMC", "Model": "Envoy", "Category": "SUV"}, "vehicle_category": "SUV", "vehicle_make_model": "GMC Envoy", "vehicle_year_make_model": "2002 GMC Envoy", "vehicle_year_make_model_cat": "2002 GMC Envoy (SUV)"}
# Retrieved data from transaction 0be9e085d42540ec6dc17d163972025d285b8d03da541ef0c5f19347a5ab8159: {"vin": "AFAWRHEL34E3LSH5D", "license_plate": "GU72PMU", "vehicle_make": "GMC", "vehicle_model": "Suburban 2500", "vehicle_year": 1995, "full_vehicleInfo": {"Year": 1995, "Make": "GMC", "Model": "Suburban 2500", "Category": "SUV"}, "vehicle_category": "SUV", "vehicle_make_model": "GMC Suburban 2500", "vehicle_year_make_model": "1995 GMC Suburban 2500", "vehicle_year_make_model_cat": "1995 GMC Suburban 2500 (SUV)"}
# Retrieved data from transaction 87eeadea2b5f49d6fba176e34fd33f5b8f89ae0a49e62ed193c79cb69f9bcc33: {"vin": "G9FGUSPE39ZY6480A", "license_plate": "TC78MMT", "vehicle_make": "GMC", "vehicle_model": "Terrain", "vehicle_year": 2019, "full_vehicleInfo": {"Year": 2019, "Make": "GMC", "Model": "Terrain", "Category": "SUV"}, "vehicle_category": "SUV", "vehicle_make_model": "GMC Terrain", "vehicle_year_make_model": "2019 GMC Terrain", "vehicle_year_make_model_cat": "2019 GMC Terrain (SUV)"}
# Retrieved data from transaction 5b8ce3f3d510d65c2cf0277d1a4146600a69e145db1a5c00bc0dd3367629edc6: {"vin": "G18HM8JU4AW1GZBZ7", "license_plate": "UQ52TGE", "vehicle_make": "Jeep", "vehicle_model": "Grand Cherokee", "vehicle_year": 1999, "full_vehicleInfo": {"Year": 1999, "Make": "Jeep", "Model": "Grand Cherokee", "Category": "SUV"}, "vehicle_category": "SUV", "vehicle_make_model": "Jeep Grand Cherokee", "vehicle_year_make_model": "1999 Jeep Grand Cherokee", "vehicle_year_make_model_cat": "1999 Jeep Grand Cherokee (SUV)"}
# Retrieved data from transaction 4d8a2614f477308a2f82db3e02a3ce0106eb70d042b36666a298fc16db97ef11: {"vin": "1LY28PKF94F66Y599", "license_plate": "RF63IQT", "vehicle_make": "Ford", "vehicle_model": "Econoline E250 Cargo", "vehicle_year": 1997, "full_vehicleInfo": {"Year": 1997, "Make": "Ford", "Model": "Econoline E250 Cargo", "Category": "Van/Minivan"}, "vehicle_category": "Van/Minivan", "vehicle_make_model": "Ford Econoline E250 Cargo", "vehicle_year_make_model": "1997 Ford Econoline E250 Cargo", "vehicle_year_make_model_cat": "1997 Ford Econoline E250 Cargo (Van/Minivan)"}
# Retrieved data from transaction c0bca2db3026fee43336ce5b91ec3c8fbef8f446256df8776fd62715382304bf: {"vin": "CKSPVV8F5E5M2EE15", "license_plate": "HC83 BKC", "vehicle_make": "BMW", "vehicle_model": "i3", "vehicle_year": 2018, "full_vehicleInfo": {"Year": 2018, "Make": "BMW", "Model": "i3", "Category": "Hatchback"}, "vehicle_category": "Hatchback", "vehicle_make_model": "BMW i3", "vehicle_year_make_model": "2018 BMW i3", "vehicle_year_make_model_cat": "2018 BMW i3 (Hatchback)"}
# Retrieved data from transaction 2848f1220c6b9bcec7cd8bc7a6f56c730d34a5357f7f60b9902ab694e44c2fed: {"vin": "HYD9XFXT2C77UNUTW", "license_plate": "VU65 UDB", "vehicle_make": "GMC", "vehicle_model": "Savana 2500 Cargo", "vehicle_year": 2013, "full_vehicleInfo": {"Year": 2013, "Make": "GMC", "Model": "Savana 2500 Cargo", "Category": "Van/Minivan"}, "vehicle_category": "Van/Minivan", "vehicle_make_model": "GMC Savana 2500 Cargo", "vehicle_year_make_model": "2013 GMC Savana 2500 Cargo", "vehicle_year_make_model_cat": "2013 GMC Savana 2500 Cargo (Van/Minivan)"}
# Retrieved data from transaction 00fbd6d0ddb0f32b6662f0f75ef948c76a5641d54df122050df5d3c420c1529e: {"vin": "7FCCV9UB3HWF5V741", "license_plate": "YH73 FNP", "vehicle_make": "Ford", "vehicle_model": "Escape", "vehicle_year": 2009, "full_vehicleInfo": {"Year": 2009, "Make": "Ford", "Model": "Escape", "Category": "SUV"}, "vehicle_category": "SUV", "vehicle_make_model": "Ford Escape", "vehicle_year_make_model": "2009 Ford Escape", "vehicle_year_make_model_cat": "2009 Ford Escape (SUV)"}
# Retrieved data from transaction 60d7d7ed428397f1da2f02066eb8922b4b9ebdfb7e1ee21115d1e8521ea05d52: {"vin": "S4AR1RGW6JUY0CJD4", "license_plate": "XK78 BBS", "vehicle_make": "Mitsubishi", "vehicle_model": "Outlander", "vehicle_year": 2019, "full_vehicleInfo": {"Year": 2019, "Make": "Mitsubishi", "Model": "Outlander", "Category": "SUV"}, "vehicle_category": "SUV", "vehicle_make_model": "Mitsubishi Outlander", "vehicle_year_make_model": "2019 Mitsubishi Outlander", "vehicle_year_make_model_cat": "2019 Mitsubishi Outlander (SUV)"}
# Retrieved data from transaction 87d0b9df5c33623f4460f33d6217fea0dd9dd950c37f7ede7b7ad21657227f1a: {"vin": "A4Z6B55F2S8F36TLG", "license_plate": "VW62 KHI", "vehicle_make": "Volkswagen", "vehicle_model": "Passat", "vehicle_year": 1992, "full_vehicleInfo": {"Year": 1992, "Make": "Volkswagen", "Model": "Passat", "Category": "Sedan, Wagon"}, "vehicle_category": "Sedan, Wagon", "vehicle_make_model": "Volkswagen Passat", "vehicle_year_make_model": "1992 Volkswagen Passat", "vehicle_year_make_model_cat": "1992 Volkswagen Passat (Sedan, Wagon)"}
# Retrieved data from transaction 6ae08173047802cbba291c9dcbc0f9ffc3577ad3bd04ee924ff9a835eea834ea: {"vin": "KWL51W752DZG9N5FP", "license_plate": "FO98RWJ", "vehicle_make": "Mercedes-Benz", "vehicle_model": "CL-Class", "vehicle_year": 2010, "full_vehicleInfo": {"Year": 2010, "Make": "Mercedes-Benz", "Model": "CL-Class", "Category": "Coupe"}, "vehicle_category": "Coupe", "vehicle_make_model": "Mercedes-Benz CL-Class", "vehicle_year_make_model": "2010 Mercedes-Benz CL-Class", "vehicle_year_make_model_cat": "2010 Mercedes-Benz CL-Class (Coupe)"}
# Retrieved data from transaction 9ab7ef1c5809cb9f319c9962f8349b90257b9b7980af8d8b5dee878b53fe12a3: {"vin": "1K79G8702HJDMDGZY", "license_plate": "BC00UNI", "vehicle_make": "Chevrolet", "vehicle_model": "G-Series 2500", "vehicle_year": 1997, "full_vehicleInfo": {"Year": 1997, "Make": "Chevrolet", "Model": "G-Series 2500", "Category": "Van/Minivan"}, "vehicle_category": "Van/Minivan", "vehicle_make_model": "Chevrolet G-Series 2500", "vehicle_year_make_model": "1997 Chevrolet G-Series 2500", "vehicle_year_make_model_cat": "1997 Chevrolet G-Series 2500 (Van/Minivan)"}
# Retrieved data from transaction db0ed8a0aeef7959aa8f95cd6e0c23385912274a691f33e8805b9351545f5913: {"vin": "M9GAVU186503P0U93", "license_plate": "LZ31BLG", "vehicle_make": "Land Rover", "vehicle_model": "Range Rover Velar", "vehicle_year": 2020, "full_vehicleInfo": {"Year": 2020, "Make": "Land Rover", "Model": "Range Rover Velar", "Category": "SUV"}, "vehicle_category": "SUV", "vehicle_make_model": "Land Rover Range Rover Velar", "vehicle_year_make_model": "2020 Land Rover Range Rover Velar", "vehicle_year_make_model_cat": "2020 Land Rover Range Rover Velar (SUV)"}
# Retrieved data from transaction 4b690118f489d8f817cfc1480473f9122cd696d08af5ceb55e797921eec9ea33: {"vin": "NT0FABT29BMTFHA7R", "license_plate": "PH43 GOL", "vehicle_make": "Volkswagen", "vehicle_model": "GTI", "vehicle_year": 2012, "full_vehicleInfo": {"Year": 2012, "Make": "Volkswagen", "Model": "GTI", "Category": "Hatchback"}, "vehicle_category": "Hatchback", "vehicle_make_model": "Volkswagen GTI", "vehicle_year_make_model": "2012 Volkswagen GTI", "vehicle_year_make_model_cat": "2012 Volkswagen GTI (Hatchback)"}
# Retrieved data from transaction 9023995c6a74862bade49a28cfa895db93fafc31b807e81eeff642bc39dd6fd3: {"vin": "E2CSMH5H5NZSM28GB", "license_plate": "BD56TNL", "vehicle_make": "Ford", "vehicle_model": "Escape", "vehicle_year": 2018, "full_vehicleInfo": {"Year": 2018, "Make": "Ford", "Model": "Escape", "Category": "SUV"}, "vehicle_category": "SUV", "vehicle_make_model": "Ford Escape", "vehicle_year_make_model": "2018 Ford Escape", "vehicle_year_make_model_cat": "2018 Ford Escape (SUV)"}
# Retrieved data from transaction e4dd083e5228b671e42e0406e5e437c0d003a8fd75cb0565e5e681479290f4d0: {"vin": "Z8RCG3U12CPU5ML8K", "license_plate": "VN48KMW", "vehicle_make": "Mercedes-Benz", "vehicle_model": "M-Class", "vehicle_year": 2013, "full_vehicleInfo": {"Year": 2013, "Make": "Mercedes-Benz", "Model": "M-Class", "Category": "SUV"}, "vehicle_category": "SUV", "vehicle_make_model": "Mercedes-Benz M-Class", "vehicle_year_make_model": "2013 Mercedes-Benz M-Class", "vehicle_year_make_model_cat": "2013 Mercedes-Benz M-Class (SUV)"}
# Retrieved data from transaction c2b17e95306dacaebcf2837951b1f7cddc572e3c9d6eaa230c506c6adf1747a3: {"vin": "9CTRBKS17KJDULWVV", "license_plate": "QP21 ZZX", "vehicle_make": "Acura", "vehicle_model": "TSX", "vehicle_year": 2008, "full_vehicleInfo": {"Year": 2008, "Make": "Acura", "Model": "TSX", "Category": "Sedan"}, "vehicle_category": "Sedan", "vehicle_make_model": "Acura TSX", "vehicle_year_make_model": "2008 Acura TSX", "vehicle_year_make_model_cat": "2008 Acura TSX (Sedan)"}
# Retrieved data from transaction bac7a3c5c8fd93e8d4790f4ecd80cbeb9b6276dac830c4ef0f304331643f0003: {"vin": "JZM6FKEC6023FX5WT", "license_plate": "WW32 MPM", "vehicle_make": "Lotus", "vehicle_model": "Elise", "vehicle_year": 2010, "full_vehicleInfo": {"Year": 2010, "Make": "Lotus", "Model": "Elise", "Category": "Coupe"}, "vehicle_category": "Coupe", "vehicle_make_model": "Lotus Elise", "vehicle_year_make_model": "2010 Lotus Elise", "vehicle_year_make_model_cat": "2010 Lotus Elise (Coupe)"}
# Retrieved data from transaction 6c79f13904bf42ae200eac2a271483834d3b51ba7297af1077ae22e211350efe: {"vin": "17UEBW4F58W9WLVZU", "license_plate": "FX34POI", "vehicle_make": "Toyota", "vehicle_model": "Highlander", "vehicle_year": 2009, "full_vehicleInfo": {"Year": 2009, "Make": "Toyota", "Model": "Highlander", "Category": "SUV"}, "vehicle_category": "SUV", "vehicle_make_model": "Toyota Highlander", "vehicle_year_make_model": "2009 Toyota Highlander", "vehicle_year_make_model_cat": "2009 Toyota Highlander (SUV)"}
# Retrieved data from transaction e76387a1394315809a484eacb4220a5f67bd96c648aff320005d895dedd281c8: {"vin": "YFHV5JFH2ML690ER0", "license_plate": "CN76 NKR", "vehicle_make": "Cadillac", "vehicle_model": "DeVille", "vehicle_year": 1992, "full_vehicleInfo": {"Year": 1992, "Make": "Cadillac", "Model": "DeVille", "Category": "Sedan, Coupe"}, "vehicle_category": "Sedan, Coupe", "vehicle_make_model": "Cadillac DeVille", "vehicle_year_make_model": "1992 Cadillac DeVille", "vehicle_year_make_model_cat": "1992 Cadillac DeVille (Sedan, Coupe)"}
# Retrieved data from transaction c93f10385c75bd90140e069581d4e37fe857d044e84233acaeaf0722edb52d38: {"vin": "4DTR2RX15NKRTEYEH", "license_plate": "PA62MKV", "vehicle_make": "Mitsubishi", "vehicle_model": "i-MiEV", "vehicle_year": 2017, "full_vehicleInfo": {"Year": 2017, "Make": "Mitsubishi", "Model": "i-MiEV", "Category": "Hatchback"}, "vehicle_category": "Hatchback", "vehicle_make_model": "Mitsubishi i-MiEV", "vehicle_year_make_model": "2017 Mitsubishi i-MiEV", "vehicle_year_make_model_cat": "2017 Mitsubishi i-MiEV (Hatchback)"}
# Retrieved data from transaction 07302156336f7b5f08b61601255466da997b9f56c8d326636814561d79073451: {"vin": "W92S26U95WB4GRLDW", "license_plate": "KY64MIY", "vehicle_make": "Chrysler", "vehicle_model": "LeBaron", "vehicle_year": 1992, "full_vehicleInfo": {"Year": 1992, "Make": "Chrysler", "Model": "LeBaron", "Category": "Sedan, Coupe, Convertible"}, "vehicle_category": "Sedan, Coupe, Convertible", "vehicle_make_model": "Chrysler LeBaron", "vehicle_year_make_model": "1992 Chrysler LeBaron", "vehicle_year_make_model_cat": "1992 Chrysler LeBaron (Sedan, Coupe, Convertible)"}
# Retrieved data from transaction 67d3f205aaf48e98cfa2c2f78ded823b16a0fe05374476af93810e41da148a8e: {"vin": "6X24NE5352FC20F9X", "license_plate": "SG52 OWI", "vehicle_make": "Ford", "vehicle_model": "Expedition", "vehicle_year": 2006, "full_vehicleInfo": {"Year": 2006, "Make": "Ford", "Model": "Expedition", "Category": "SUV"}, "vehicle_category": "SUV", "vehicle_make_model": "Ford Expedition", "vehicle_year_make_model": "2006 Ford Expedition", "vehicle_year_make_model_cat": "2006 Ford Expedition (SUV)"}
# Retrieved data from transaction ae9f2b1fb8583eb29af966e2cf1bde401aae46fcb92cbc8d9e4b923375c284aa: {"vin": "8AK72KRS8C5F7K83N", "license_plate": "VL50CQU", "vehicle_make": "Honda", "vehicle_model": "del Sol", "vehicle_year": 1995, "full_vehicleInfo": {"Year": 1995, "Make": "Honda", "Model": "del Sol", "Category": "Coupe"}, "vehicle_category": "Coupe", "vehicle_make_model": "Honda del Sol", "vehicle_year_make_model": "1995 Honda del Sol", "vehicle_year_make_model_cat": "1995 Honda del Sol (Coupe)"}
# Retrieved data from transaction 7235a187d1c11441051b2ed587b2b06dad099d874a137e04b3ebbbd7e07106a4: {"vin": "TY7UPW0U6BHXWUHLF", "license_plate": "IO99 HYO", "vehicle_make": "Chrysler", "vehicle_model": "300M", "vehicle_year": 2001, "full_vehicleInfo": {"Year": 2001, "Make": "Chrysler", "Model": "300M", "Category": "Sedan"}, "vehicle_category": "Sedan", "vehicle_make_model": "Chrysler 300M", "vehicle_year_make_model": "2001 Chrysler 300M", "vehicle_year_make_model_cat": "2001 Chrysler 300M (Sedan)"}
# Retrieved data from transaction 7b89ccd7d94785c23be71171180c1b2205037cbf366fe5c3f562c42969269b34: {"vin": "RM2YLBYD6NGMHH1C6", "license_plate": "XN37 PRY", "vehicle_make": "Ford", "vehicle_model": "F250 Super Cab", "vehicle_year": 1997, "full_vehicleInfo": {"Year": 1997, "Make": "Ford", "Model": "F250 Super Cab", "Category": "Pickup"}, "vehicle_category": "Pickup", "vehicle_make_model": "Ford F250 Super Cab", "vehicle_year_make_model": "1997 Ford F250 Super Cab", "vehicle_year_make_model_cat": "1997 Ford F250 Super Cab (Pickup)"}
# Retrieved data from transaction 914ec19ee49dbba21dde03a0e52ac10543295da293d504eda7f5bdf3468ad0f6: {"vin": "YV26JESF0KPXNUMNW", "license_plate": "JI35HDX", "vehicle_make": "Lexus", "vehicle_model": "GS", "vehicle_year": 2011, "full_vehicleInfo": {"Year": 2011, "Make": "Lexus", "Model": "GS", "Category": "Sedan"}, "vehicle_category": "Sedan", "vehicle_make_model": "Lexus GS", "vehicle_year_make_model": "2011 Lexus GS", "vehicle_year_make_model_cat": "2011 Lexus GS (Sedan)"}
# Retrieved data from transaction de3a012844805c38cbd2e24aa097ae82f732952af30ef1a95bbccea5ab0ecc32: {"vin": "8BCDXHJ76CJEPBK19", "license_plate": "BB27RJW", "vehicle_make": "Audi", "vehicle_model": "A8", "vehicle_year": 2002, "full_vehicleInfo": {"Year": 2002, "Make": "Audi", "Model": "A8", "Category": "Sedan"}, "vehicle_category": "Sedan", "vehicle_make_model": "Audi A8", "vehicle_year_make_model": "2002 Audi A8", "vehicle_year_make_model_cat": "2002 Audi A8 (Sedan)"}
# Retrieved data from transaction 3655263955f0d9e188b8d1d9dd6c16348d01e374b1893f4be6c3f36cce4d639e: {"vin": "71JXXVMB24GX85SY5", "license_plate": "EE13 ZSJ", "vehicle_make": "Toyota", "vehicle_model": "Sienna", "vehicle_year": 2013, "full_vehicleInfo": {"Year": 2013, "Make": "Toyota", "Model": "Sienna", "Category": "Van/Minivan"}, "vehicle_category": "Van/Minivan", "vehicle_make_model": "Toyota Sienna", "vehicle_year_make_model": "2013 Toyota Sienna", "vehicle_year_make_model_cat": "2013 Toyota Sienna (Van/Minivan)"}
# Retrieved data from transaction 983f73daedf9f1ab26bda0b910ff15cfa74c35d3caa6143bb778d324a5ce8339: {"vin": "8TERVVKU1K47DDG6A", "license_plate": "FR67 CFA", "vehicle_make": "Cadillac", "vehicle_model": "Escalade ESV", "vehicle_year": 2008, "full_vehicleInfo": {"Year": 2008, "Make": "Cadillac", "Model": "Escalade ESV", "Category": "SUV"}, "vehicle_category": "SUV", "vehicle_make_model": "Cadillac Escalade ESV", "vehicle_year_make_model": "2008 Cadillac Escalade ESV", "vehicle_year_make_model_cat": "2008 Cadillac Escalade ESV (SUV)"}
# Retrieved data from transaction 91f34259a07948532777b8edca76ae520426ecc805ac7f8464816df7bb5b5878: {"vin": "XJ3EJJW51EGCU8E0H", "license_plate": "CB99 FZJ", "vehicle_make": "Nissan", "vehicle_model": "LEAF", "vehicle_year": 2012, "full_vehicleInfo": {"Year": 2012, "Make": "Nissan", "Model": "LEAF", "Category": "Hatchback"}, "vehicle_category": "Hatchback", "vehicle_make_model": "Nissan LEAF", "vehicle_year_make_model": "2012 Nissan LEAF", "vehicle_year_make_model_cat": "2012 Nissan LEAF (Hatchback)"}
# Retrieved data from transaction dcdb82684ddf6ac505310c1b17f62269c9115024d5caf77a358bcdeba09a00df: {"vin": "JV8WKSHZ8YV63ULG2", "license_plate": "HV49 SSA", "vehicle_make": "MAZDA", "vehicle_model": "Millenia", "vehicle_year": 2001, "full_vehicleInfo": {"Year": 2001, "Make": "MAZDA", "Model": "Millenia", "Category": "Sedan"}, "vehicle_category": "Sedan", "vehicle_make_model": "MAZDA Millenia", "vehicle_year_make_model": "2001 MAZDA Millenia", "vehicle_year_make_model_cat": "2001 MAZDA Millenia (Sedan)"}
# Retrieved data from transaction cfadb934363d7060844f0a9ce0c14d757ebf87ea11a442b5a2f0042709883e6c: {"vin": "3BXVHBUY96XNTML7A", "license_plate": "NW68PJV", "vehicle_make": "Toyota", "vehicle_model": "Matrix", "vehicle_year": 2012, "full_vehicleInfo": {"Year": 2012, "Make": "Toyota", "Model": "Matrix", "Category": "Wagon"}, "vehicle_category": "Wagon", "vehicle_make_model": "Toyota Matrix", "vehicle_year_make_model": "2012 Toyota Matrix", "vehicle_year_make_model_cat": "2012 Toyota Matrix (Wagon)"}
# Retrieved data from transaction 281d1ad9165e5417bf83f6b999f46b1d61edda3cd92e363b3989b5796c7f97d4: {"vin": "3W6LGL8S1Z1WT4CPY", "license_plate": "YB24GIR", "vehicle_make": "Nissan", "vehicle_model": "Murano", "vehicle_year": 2006, "full_vehicleInfo": {"Year": 2006, "Make": "Nissan", "Model": "Murano", "Category": "SUV"}, "vehicle_category": "SUV", "vehicle_make_model": "Nissan Murano", "vehicle_year_make_model": "2006 Nissan Murano", "vehicle_year_make_model_cat": "2006 Nissan Murano (SUV)"}
# Retrieved data from transaction c3f52b88e76ecf2cc34d12a8f23c4fb9403594d09cc8ae452f35177cad3454a7: {"vin": "VY82FAK12T6E8W80Y", "license_plate": "QW73INP", "vehicle_make": "MAZDA", "vehicle_model": "B-Series Cab Plus", "vehicle_year": 1999, "full_vehicleInfo": {"Year": 1999, "Make": "MAZDA", "Model": "B-Series Cab Plus", "Category": "Pickup"}, "vehicle_category": "Pickup", "vehicle_make_model": "MAZDA B-Series Cab Plus", "vehicle_year_make_model": "1999 MAZDA B-Series Cab Plus", "vehicle_year_make_model_cat": "1999 MAZDA B-Series Cab Plus (Pickup)"}
# Retrieved data from transaction 9485e83e3028b4f3089467895597afbffe77ea50d6e57be82ffaa4a38cc252cf: {"vin": "W0RCZ95H9TMZH1JKY", "license_plate": "OR88 PLK", "vehicle_make": "Saab", "vehicle_model": "3-Sep", "vehicle_year": 2001, "full_vehicleInfo": {"Year": 2001, "Make": "Saab", "Model": "3-Sep", "Category": "Hatchback, Convertible"}, "vehicle_category": "Hatchback, Convertible", "vehicle_make_model": "Saab 3-Sep", "vehicle_year_make_model": "2001 Saab 3-Sep", "vehicle_year_make_model_cat": "2001 Saab 3-Sep (Hatchback, Convertible)"}
# Retrieved data from transaction 8d5d89383151e26961d21cbf31356b88751dc9bad0ba0cc0229ec7a46fdabab4: {"vin": "RWLCFRET53LXRR0Y3", "license_plate": "QS18 KDO", "vehicle_make": "Geo", "vehicle_model": "Storm", "vehicle_year": 1993, "full_vehicleInfo": {"Year": 1993, "Make": "Geo", "Model": "Storm", "Category": "Coupe"}, "vehicle_category": "Coupe", "vehicle_make_model": "Geo Storm", "vehicle_year_make_model": "1993 Geo Storm", "vehicle_year_make_model_cat": "1993 Geo Storm (Coupe)"}
# Retrieved data from transaction 28602d29cbd20e884b8f3a1615a63a3a4082e9a706f4a2105c107394a79af3d9: {"vin": "W10T05XG0MS6MRLY3", "license_plate": "HU16 VJH", "vehicle_make": "Audi", "vehicle_model": "TT", "vehicle_year": 2005, "full_vehicleInfo": {"Year": 2005, "Make": "Audi", "Model": "TT", "Category": "Coupe, Convertible"}, "vehicle_category": "Coupe, Convertible", "vehicle_make_model": "Audi TT", "vehicle_year_make_model": "2005 Audi TT", "vehicle_year_make_model_cat": "2005 Audi TT (Coupe, Convertible)"}
# Retrieved data from transaction 9a79a36aa337a504307a4e79dff6c18278bfbabd0d4eccfd16be0ad64bd824c2: {"vin": "77VAK23L34JNPU0FT", "license_plate": "FF93 CTM", "vehicle_make": "Nissan", "vehicle_model": "Maxima", "vehicle_year": 2003, "full_vehicleInfo": {"Year": 2003, "Make": "Nissan", "Model": "Maxima", "Category": "Sedan"}, "vehicle_category": "Sedan", "vehicle_make_model": "Nissan Maxima", "vehicle_year_make_model": "2003 Nissan Maxima", "vehicle_year_make_model_cat": "2003 Nissan Maxima (Sedan)"}
# Retrieved data from transaction 2654702cc2fc822880ed1bf83876c21ca4677e41ad48b7db48bbb8ebb471bea8: {"vin": "Y0EWGWG10WJA5VNKU", "license_plate": "OJ13GMP", "vehicle_make": "Acura", "vehicle_model": "RL", "vehicle_year": 2003, "full_vehicleInfo": {"Year": 2003, "Make": "Acura", "Model": "RL", "Category": "Sedan"}, "vehicle_category": "Sedan", "vehicle_make_model": "Acura RL", "vehicle_year_make_model": "2003 Acura RL", "vehicle_year_make_model_cat": "2003 Acura RL (Sedan)"}
# Retrieved data from transaction 52d0d99631a2057689fc2abb92d0c5965445e2cc601eb0f52774dc3c0d654e2d: {"vin": "RNJJ2SH104YJENECG", "license_plate": "UD47 UUB", "vehicle_make": "GMC", "vehicle_model": "Savana 2500 Cargo", "vehicle_year": 1999, "full_vehicleInfo": {"Year": 1999, "Make": "GMC", "Model": "Savana 2500 Cargo", "Category": "Van/Minivan"}, "vehicle_category": "Van/Minivan", "vehicle_make_model": "GMC Savana 2500 Cargo", "vehicle_year_make_model": "1999 GMC Savana 2500 Cargo", "vehicle_year_make_model_cat": "1999 GMC Savana 2500 Cargo (Van/Minivan)"}
# Retrieved data from transaction 7a4b5e57fa8ca3c7fb17057460daf730fe576e3cbe5d09acece4194d40582153: {"vin": "3P96JLTB4C9PZHAGX", "license_plate": "XK12ZDO", "vehicle_make": "Acura", "vehicle_model": "TSX", "vehicle_year": 2010, "full_vehicleInfo": {"Year": 2010, "Make": "Acura", "Model": "TSX", "Category": "Sedan"}, "vehicle_category": "Sedan", "vehicle_make_model": "Acura TSX", "vehicle_year_make_model": "2010 Acura TSX", "vehicle_year_make_model_cat": "2010 Acura TSX (Sedan)"}
# Retrieved data from transaction b7b275e6da104d5617f07524820d3285064ff51236a2ea73f7830331784926e3: {"vin": "ESP6S1G88WPGRP7EX", "license_plate": "TR17 KTH", "vehicle_make": "Chevrolet", "vehicle_model": "Silverado 1500 Crew Cab", "vehicle_year": 2011, "full_vehicleInfo": {"Year": 2011, "Make": "Chevrolet", "Model": "Silverado 1500 Crew Cab", "Category": "Pickup"}, "vehicle_category": "Pickup", "vehicle_make_model": "Chevrolet Silverado 1500 Crew Cab", "vehicle_year_make_model": "2011 Chevrolet Silverado 1500 Crew Cab", "vehicle_year_make_model_cat": "2011 Chevrolet Silverado 1500 Crew Cab (Pickup)"}
# Retrieved data from transaction d20d696264c1bb02dc2c82a12f1584506b7a7c4641234286566d83788f57bb7c: {"vin": "KT8933KY587F9RWPT", "license_plate": "NU64 DPT", "vehicle_make": "Chevrolet", "vehicle_model": "Suburban 3500HD", "vehicle_year": 2016, "full_vehicleInfo": {"Year": 2016, "Make": "Chevrolet", "Model": "Suburban 3500HD", "Category": "SUV"}, "vehicle_category": "SUV", "vehicle_make_model": "Chevrolet Suburban 3500HD", "vehicle_year_make_model": "2016 Chevrolet Suburban 3500HD", "vehicle_year_make_model_cat": "2016 Chevrolet Suburban 3500HD (SUV)"}
# Retrieved data from transaction e98105e380f171862076223b3833e1a6624c6a139cc2c60153187e0d3e16616d: {"vin": "3PDVVFP72PN4SHC8W", "license_plate": "VG00 UUT", "vehicle_make": "GMC", "vehicle_model": "1500 Club Coupe", "vehicle_year": 1999, "full_vehicleInfo": {"Year": 1999, "Make": "GMC", "Model": "1500 Club Coupe", "Category": "Pickup"}, "vehicle_category": "Pickup", "vehicle_make_model": "GMC 1500 Club Coupe", "vehicle_year_make_model": "1999 GMC 1500 Club Coupe", "vehicle_year_make_model_cat": "1999 GMC 1500 Club Coupe (Pickup)"}
# Retrieved data from transaction a5b0655dae8bbbfea66413974df50e83ecc3276948b38ada4d2d9439028d4266: {"vin": "MF9D5DDE5M01H09GB", "license_plate": "VA39 EAL", "vehicle_make": "Aston Martin", "vehicle_model": "DBS", "vehicle_year": 2008, "full_vehicleInfo": {"Year": 2008, "Make": "Aston Martin", "Model": "DBS", "Category": "Coupe"}, "vehicle_category": "Coupe", "vehicle_make_model": "Aston Martin DBS", "vehicle_year_make_model": "2008 Aston Martin DBS", "vehicle_year_make_model_cat": "2008 Aston Martin DBS (Coupe)"}
# Retrieved data from transaction 46b6ea0d4264b0bf5bc2151b084cbb3b395edeba9562af4470ad843c910ea2c4: {"vin": "L2BG49T835XVPZ7VZ", "license_plate": "TB84 XZV", "vehicle_make": "Chevrolet", "vehicle_model": "Express 2500 Cargo", "vehicle_year": 2017, "full_vehicleInfo": {"Year": 2017, "Make": "Chevrolet", "Model": "Express 2500 Cargo", "Category": "Van/Minivan"}, "vehicle_category": "Van/Minivan", "vehicle_make_model": "Chevrolet Express 2500 Cargo", "vehicle_year_make_model": "2017 Chevrolet Express 2500 Cargo", "vehicle_year_make_model_cat": "2017 Chevrolet Express 2500 Cargo (Van/Minivan)"}
# Retrieved data from transaction be1896058c63d0570112e19c49babf25b8f2528d7f85ece882c45395ba90eedf: {"vin": "W24XSU7Y3V56L059H", "license_plate": "MT89QJO", "vehicle_make": "Hyundai", "vehicle_model": "Equus", "vehicle_year": 2014, "full_vehicleInfo": {"Year": 2014, "Make": "Hyundai", "Model": "Equus", "Category": "Sedan"}, "vehicle_category": "Sedan", "vehicle_make_model": "Hyundai Equus", "vehicle_year_make_model": "2014 Hyundai Equus", "vehicle_year_make_model_cat": "2014 Hyundai Equus (Sedan)"}
# Retrieved data from transaction af8cc4fa11599ec85f9be65d4a64037d0514b12b0dd5cfceeb2688001d61dd0c: {"vin": "U78DUVET5MWST7LUL", "license_plate": "LE11VPC", "vehicle_make": "MAZDA", "vehicle_model": "B-Series Regular Cab", "vehicle_year": 2009, "full_vehicleInfo": {"Year": 2009, "Make": "MAZDA", "Model": "B-Series Regular Cab", "Category": "Pickup"}, "vehicle_category": "Pickup", "vehicle_make_model": "MAZDA B-Series Regular Cab", "vehicle_year_make_model": "2009 MAZDA B-Series Regular Cab", "vehicle_year_make_model_cat": "2009 MAZDA B-Series Regular Cab (Pickup)"}
# Retrieved data from transaction 5ffa03e8f331f4c5296a2f76c3ed816c41151f56e3ecaf01d3a0f96cf3eb5e37: {"vin": "6U7P94M8XTNU4JKN7", "license_plate": "EV58 PHD", "vehicle_make": "Mercedes-Benz", "vehicle_model": "Sprinter 2500 Crew", "vehicle_year": 2016, "full_vehicleInfo": {"Year": 2016, "Make": "Mercedes-Benz", "Model": "Sprinter 2500 Crew", "Category": "Van/Minivan"}, "vehicle_category": "Van/Minivan", "vehicle_make_model": "Mercedes-Benz Sprinter 2500 Crew", "vehicle_year_make_model": "2016 Mercedes-Benz Sprinter 2500 Crew", "vehicle_year_make_model_cat": "2016 Mercedes-Benz Sprinter 2500 Crew (Van/Minivan)"}
# Retrieved data from transaction 19c9f634abe32920d74766a4187356cc0c84d50a024c467d0b11bfc5f05420f0: {"vin": "P8HEU2H22BHKMN1B0", "license_plate": "CE18XUA", "vehicle_make": "Kia", "vehicle_model": "Sportage", "vehicle_year": 2019, "full_vehicleInfo": {"Year": 2019, "Make": "Kia", "Model": "Sportage", "Category": "SUV"}, "vehicle_category": "SUV", "vehicle_make_model": "Kia Sportage", "vehicle_year_make_model": "2019 Kia Sportage", "vehicle_year_make_model_cat": "2019 Kia Sportage (SUV)"}
# Retrieved data from transaction 21939a6049ddedf1db343309d039e8c193cbee02e038f12c5ba9eb692b7ef5e5: {"vin": "DRTWMAPK2L640A46H", "license_plate": "VN64PTO", "vehicle_make": "smart", "vehicle_model": "fortwo electric drive", "vehicle_year": 2014, "full_vehicleInfo": {"Year": 2014, "Make": "smart", "Model": "fortwo electric drive", "Category": "Hatchback, Convertible"}, "vehicle_category": "Hatchback, Convertible", "vehicle_make_model": "smart fortwo electric drive", "vehicle_year_make_model": "2014 smart fortwo electric drive", "vehicle_year_make_model_cat": "2014 smart fortwo electric drive (Hatchback, Convertible)"}
# Retrieved data from transaction 4ba6f8c83e3dc6da4164026e1860cca1afefea4ebbf0d36cddfda2c21d0f59d2: {"vin": "DZ8NU8JY1K3ES41DK", "license_plate": "YE51 YIJ", "vehicle_make": "INFINITI", "vehicle_model": "Q", "vehicle_year": 1996, "full_vehicleInfo": {"Year": 1996, "Make": "INFINITI", "Model": "Q", "Category": "Sedan"}, "vehicle_category": "Sedan", "vehicle_make_model": "INFINITI Q", "vehicle_year_make_model": "1996 INFINITI Q", "vehicle_year_make_model_cat": "1996 INFINITI Q (Sedan)"}
# Retrieved data from transaction ded53f5ef34e6883b0ba75b55134f7dae5fe5730d6757f5be5b397bfd92519e6: {"vin": "1YUB9REZ5N5S3U2W5", "license_plate": "SN64SMW", "vehicle_make": "Ford", "vehicle_model": "E350 Super Duty Cargo", "vehicle_year": 2003, "full_vehicleInfo": {"Year": 2003, "Make": "Ford", "Model": "E350 Super Duty Cargo", "Category": "Van/Minivan"}, "vehicle_category": "Van/Minivan", "vehicle_make_model": "Ford E350 Super Duty Cargo", "vehicle_year_make_model": "2003 Ford E350 Super Duty Cargo", "vehicle_year_make_model_cat": "2003 Ford E350 Super Duty Cargo (Van/Minivan)"}
# Retrieved data from transaction e4f471af0c0c88f4518d20d58341766a3ffb4930c0741a6e3ccf4114b3ab510d: {"vin": "8S2LAWP67U7FUS6SK", "license_plate": "HK81YFC", "vehicle_make": "Suzuki", "vehicle_model": "XL-7", "vehicle_year": 2002, "full_vehicleInfo": {"Year": 2002, "Make": "Suzuki", "Model": "XL-7", "Category": "SUV"}, "vehicle_category": "SUV", "vehicle_make_model": "Suzuki XL-7", "vehicle_year_make_model": "2002 Suzuki XL-7", "vehicle_year_make_model_cat": "2002 Suzuki XL-7 (SUV)"}
# Retrieved data from transaction 9017b8d7e99091e57a429e65b231e0b543bb6140c95a77f97cc7bec4f1d9d488: {"vin": "ZCNN0F709GCB05BYW", "license_plate": "VS55UUT", "vehicle_make": "GMC", "vehicle_model": "Sierra 3500 Extended Cab", "vehicle_year": 2001, "full_vehicleInfo": {"Year": 2001, "Make": "GMC", "Model": "Sierra 3500 Extended Cab", "Category": "Pickup"}, "vehicle_category": "Pickup", "vehicle_make_model": "GMC Sierra 3500 Extended Cab", "vehicle_year_make_model": "2001 GMC Sierra 3500 Extended Cab", "vehicle_year_make_model_cat": "2001 GMC Sierra 3500 Extended Cab (Pickup)"}
# Retrieved data from transaction 8d7c29024128f5d7158d79b97aaf6b6dcf1650a6d594bb2d96b6bc74d572d257: {"vin": "0V5XVKH46NZ5KWV34", "license_plate": "JC98UCT", "vehicle_make": "BMW", "vehicle_model": "Z3", "vehicle_year": 1999, "full_vehicleInfo": {"Year": 1999, "Make": "BMW", "Model": "Z3", "Category": "Convertible, Coupe"}, "vehicle_category": "Convertible, Coupe", "vehicle_make_model": "BMW Z3", "vehicle_year_make_model": "1999 BMW Z3", "vehicle_year_make_model_cat": "1999 BMW Z3 (Convertible, Coupe)"}
# Retrieved data from transaction 2dd3726407b98e185dd5aecd6220fce6d7083f20aba28c347ac22feb037bf76d: {"vin": "RW3VCLXZ404V7M6ZB", "license_plate": "HW89 OOQ", "vehicle_make": "Chevrolet", "vehicle_model": "Venture Cargo", "vehicle_year": 2004, "full_vehicleInfo": {"Year": 2004, "Make": "Chevrolet", "Model": "Venture Cargo", "Category": "Van/Minivan"}, "vehicle_category": "Van/Minivan", "vehicle_make_model": "Chevrolet Venture Cargo", "vehicle_year_make_model": "2004 Chevrolet Venture Cargo", "vehicle_year_make_model_cat": "2004 Chevrolet Venture Cargo (Van/Minivan)"}
# Retrieved data from transaction 53df6be15c537c6002d177b690ab0992780d56651d80055353da5ca4faaa7e18: {"vin": "APPJRTM46M5M7RJG0", "license_plate": "CS46VEL", "vehicle_make": "Toyota", "vehicle_model": "Supra", "vehicle_year": 1994, "full_vehicleInfo": {"Year": 1994, "Make": "Toyota", "Model": "Supra", "Category": "Hatchback"}, "vehicle_category": "Hatchback", "vehicle_make_model": "Toyota Supra", "vehicle_year_make_model": "1994 Toyota Supra", "vehicle_year_make_model_cat": "1994 Toyota Supra (Hatchback)"}
# Retrieved data from transaction 396dc3c7e536da47966893a2df174d0e8229a1d41ceed5235b2dc0be30b8130b: {"vin": "96KRM96U2ZP2PKBDM", "license_plate": "GH41EEC", "vehicle_make": "Audi", "vehicle_model": "RS 5", "vehicle_year": 2014, "full_vehicleInfo": {"Year": 2014, "Make": "Audi", "Model": "RS 5", "Category": "Convertible, Coupe"}, "vehicle_category": "Convertible, Coupe", "vehicle_make_model": "Audi RS 5", "vehicle_year_make_model": "2014 Audi RS 5", "vehicle_year_make_model_cat": "2014 Audi RS 5 (Convertible, Coupe)"}
# Retrieved data from transaction e8cc700be67b971b9290fa4c10ca8690f5215a87ebf03b8fb92e99a8614b402a: {"vin": "Z3M9R0ABXAV3TPFVJ", "license_plate": "HR73HJZ", "vehicle_make": "Toyota", "vehicle_model": "T100 Xtracab", "vehicle_year": 1995, "full_vehicleInfo": {"Year": 1995, "Make": "Toyota", "Model": "T100 Xtracab", "Category": "Pickup"}, "vehicle_category": "Pickup", "vehicle_make_model": "Toyota T100 Xtracab", "vehicle_year_make_model": "1995 Toyota T100 Xtracab", "vehicle_year_make_model_cat": "1995 Toyota T100 Xtracab (Pickup)"}
# Retrieved data from transaction e97f0c6e4f952f397df7122c259cea76d0c3b20f773fb9da92d4dc3993a6c971: {"vin": "PVWJRZTAXC9G4XP78", "license_plate": "CY82FIO", "vehicle_make": "Ford", "vehicle_model": "Econoline E250 Cargo", "vehicle_year": 1994, "full_vehicleInfo": {"Year": 1994, "Make": "Ford", "Model": "Econoline E250 Cargo", "Category": "Van/Minivan"}, "vehicle_category": "Van/Minivan", "vehicle_make_model": "Ford Econoline E250 Cargo", "vehicle_year_make_model": "1994 Ford Econoline E250 Cargo", "vehicle_year_make_model_cat": "1994 Ford Econoline E250 Cargo (Van/Minivan)"}
# Retrieved data from transaction a47ae0970a927343e5290308ca816998bc450ab51a6c55e17ff7abb393e66c51: {"vin": "U6EVN2T43SZPFR6PE", "license_plate": "KD22 WUK", "vehicle_make": "Ford", "vehicle_model": "Aerostar Passenger", "vehicle_year": 1997, "full_vehicleInfo": {"Year": 1997, "Make": "Ford", "Model": "Aerostar Passenger", "Category": "Van/Minivan"}, "vehicle_category": "Van/Minivan", "vehicle_make_model": "Ford Aerostar Passenger", "vehicle_year_make_model": "1997 Ford Aerostar Passenger", "vehicle_year_make_model_cat": "1997 Ford Aerostar Passenger (Van/Minivan)"}
# Retrieved data from transaction e86a1456bc9171a00adfbd94fba8d4fe2e9f8b66b4821394ef2768b249970ba4: {"vin": "3JX9XV1672GD0U8JF", "license_plate": "DB97HNU", "vehicle_make": "MAZDA", "vehicle_model": "CX-9", "vehicle_year": 2015, "full_vehicleInfo": {"Year": 2015, "Make": "MAZDA", "Model": "CX-9", "Category": "SUV"}, "vehicle_category": "SUV", "vehicle_make_model": "MAZDA CX-9", "vehicle_year_make_model": "2015 MAZDA CX-9", "vehicle_year_make_model_cat": "2015 MAZDA CX-9 (SUV)"}
# Retrieved data from transaction 96f777788c1a1c7cd3cb3197ab7cd099cd7028809edd295f809e853e91357c00: {"vin": "58Y2ZF0J3U1NFTB6P", "license_plate": "QR80 QZQ", "vehicle_make": "Ford", "vehicle_model": "Freestyle", "vehicle_year": 2007, "full_vehicleInfo": {"Year": 2007, "Make": "Ford", "Model": "Freestyle", "Category": "SUV"}, "vehicle_category": "SUV", "vehicle_make_model": "Ford Freestyle", "vehicle_year_make_model": "2007 Ford Freestyle", "vehicle_year_make_model_cat": "2007 Ford Freestyle (SUV)"}
# Retrieved data from transaction d6712f26e8d4c923f77240ded06bd1e23250c976e2b8ee96c5b0d9039f8a3a38: {"vin": "RX3RPG2N35NF7M93N", "license_plate": "UF72YVO", "vehicle_make": "Acura", "vehicle_model": "RL", "vehicle_year": 2004, "full_vehicleInfo": {"Year": 2004, "Make": "Acura", "Model": "RL", "Category": "Sedan"}, "vehicle_category": "Sedan", "vehicle_make_model": "Acura RL", "vehicle_year_make_model": "2004 Acura RL", "vehicle_year_make_model_cat": "2004 Acura RL (Sedan)"}
# Retrieved data from transaction 59b717b4e39a832d7ac90c0fdabf8ca4ca44d4280026c17113c7ac68d2d0ac15: {"vin": "95W3JC3C63LKZSXG3", "license_plate": "JL54 YBU", "vehicle_make": "Ford", "vehicle_model": "F150 Super Cab", "vehicle_year": 2007, "full_vehicleInfo": {"Year": 2007, "Make": "Ford", "Model": "F150 Super Cab", "Category": "Pickup"}, "vehicle_category": "Pickup", "vehicle_make_model": "Ford F150 Super Cab", "vehicle_year_make_model": "2007 Ford F150 Super Cab", "vehicle_year_make_model_cat": "2007 Ford F150 Super Cab (Pickup)"}
# Retrieved data from transaction 2da2ee7af75d918fd6c6044697a92c202f69000959563a475d8dfc936e72257c: {"vin": "8PUSVRMBXYYPH6U6U", "license_plate": "RJ54 KDC", "vehicle_make": "Chevrolet", "vehicle_model": "Avalanche 1500", "vehicle_year": 2003, "full_vehicleInfo": {"Year": 2003, "Make": "Chevrolet", "Model": "Avalanche 1500", "Category": "Pickup"}, "vehicle_category": "Pickup", "vehicle_make_model": "Chevrolet Avalanche 1500", "vehicle_year_make_model": "2003 Chevrolet Avalanche 1500", "vehicle_year_make_model_cat": "2003 Chevrolet Avalanche 1500 (Pickup)"}
# Retrieved data from transaction 0e843586b6fb674c01777606ac5a61346200a3c6f016dc6c3ccb815f6c8a3a8b: {"vin": "KVUAVNV3XNUH45SPZ", "license_plate": "AE70 TVZ", "vehicle_make": "Kia", "vehicle_model": "Forte", "vehicle_year": 2010, "full_vehicleInfo": {"Year": 2010, "Make": "Kia", "Model": "Forte", "Category": "Sedan, Coupe"}, "vehicle_category": "Sedan, Coupe", "vehicle_make_model": "Kia Forte", "vehicle_year_make_model": "2010 Kia Forte", "vehicle_year_make_model_cat": "2010 Kia Forte (Sedan, Coupe)"}
# Retrieved data from transaction 665ef1e57724c937b74af0844b7e1d44832709b22fb37fe482f9c9994df44fee: {"vin": "95FPPR30XVPPV59PS", "license_plate": "UI27HDA", "vehicle_make": "Chevrolet", "vehicle_model": "Tahoe (New)", "vehicle_year": 2000, "full_vehicleInfo": {"Year": 2000, "Make": "Chevrolet", "Model": "Tahoe (New)", "Category": "SUV"}, "vehicle_category": "SUV", "vehicle_make_model": "Chevrolet Tahoe (New)", "vehicle_year_make_model": "2000 Chevrolet Tahoe (New)", "vehicle_year_make_model_cat": "2000 Chevrolet Tahoe (New) (SUV)"}
# Retrieved data from transaction 7f89a0c84c6462a6292bda10eb1f9188a8a89a9ae74fb59e584c56aa2fc2f1e3: {"vin": "R8GGVDJY2C895VBV6", "license_plate": "VL84WCR", "vehicle_make": "Mercedes-Benz", "vehicle_model": "CL-Class", "vehicle_year": 2005, "full_vehicleInfo": {"Year": 2005, "Make": "Mercedes-Benz", "Model": "CL-Class", "Category": "Coupe"}, "vehicle_category": "Coupe", "vehicle_make_model": "Mercedes-Benz CL-Class", "vehicle_year_make_model": "2005 Mercedes-Benz CL-Class", "vehicle_year_make_model_cat": "2005 Mercedes-Benz CL-Class (Coupe)"}
# Retrieved data from transaction 9e300e6712478a0537b0654b716122abc984fb77091a3b05c1f3266c771c3c3f: {"vin": "KABPZE8C19FY2PPW9", "license_plate": "CJ78 MWX", "vehicle_make": "Toyota", "vehicle_model": "Yaris iA", "vehicle_year": 2017, "full_vehicleInfo": {"Year": 2017, "Make": "Toyota", "Model": "Yaris iA", "Category": "Sedan"}, "vehicle_category": "Sedan", "vehicle_make_model": "Toyota Yaris iA", "vehicle_year_make_model": "2017 Toyota Yaris iA", "vehicle_year_make_model_cat": "2017 Toyota Yaris iA (Sedan)"}
# Retrieved data from transaction 62b37dc82700f1b039ee5544746597ddf7f810c1d408c454481a5b3894489f54: {"vin": "TT59L5VW2N9B9UZ48", "license_plate": "JF35 FKW", "vehicle_make": "Toyota", "vehicle_model": "Prius", "vehicle_year": 2010, "full_vehicleInfo": {"Year": 2010, "Make": "Toyota", "Model": "Prius", "Category": "Hatchback"}, "vehicle_category": "Hatchback", "vehicle_make_model": "Toyota Prius", "vehicle_year_make_model": "2010 Toyota Prius", "vehicle_year_make_model_cat": "2010 Toyota Prius (Hatchback)"}
# Retrieved data from transaction aba878fa62676226befe134dc805dcf2205c955518719f7d979d8f07b2c4ae0b: {"vin": "J6GCH9K61ZA0AM326", "license_plate": "UY39 SIU", "vehicle_make": "BMW", "vehicle_model": "M6", "vehicle_year": 2019, "full_vehicleInfo": {"Year": 2019, "Make": "BMW", "Model": "M6", "Category": "Coupe"}, "vehicle_category": "Coupe", "vehicle_make_model": "BMW M6", "vehicle_year_make_model": "2019 BMW M6", "vehicle_year_make_model_cat": "2019 BMW M6 (Coupe)"}
# Retrieved data from transaction 2e39d1fbb4607ed476639a911754e4c035ebe042d26429b741309191b447296f: {"vin": "T2YJKXFS6KW54AVTX", "license_plate": "GK55TEK", "vehicle_make": "Mercedes-Benz", "vehicle_model": "Mercedes-AMG S-Class", "vehicle_year": 2017, "full_vehicleInfo": {"Year": 2017, "Make": "Mercedes-Benz", "Model": "Mercedes-AMG S-Class", "Category": "Sedan, Coupe, Convertible"}, "vehicle_category": "Sedan, Coupe, Convertible", "vehicle_make_model": "Mercedes-Benz Mercedes-AMG S-Class", "vehicle_year_make_model": "2017 Mercedes-Benz Mercedes-AMG S-Class", "vehicle_year_make_model_cat": "2017 Mercedes-Benz Mercedes-AMG S-Class (Sedan, Coupe, Convertible)"}
# Retrieved data from transaction 958097c58c6ac01af23327b86d5f0102efa9c74594b147bba8d85bc024d8022d: {"vin": "S9PZ7LFW78HVF074J", "license_plate": "TN95HFK", "vehicle_make": "Nissan", "vehicle_model": "Maxima", "vehicle_year": 2018, "full_vehicleInfo": {"Year": 2018, "Make": "Nissan", "Model": "Maxima", "Category": "Sedan"}, "vehicle_category": "Sedan", "vehicle_make_model": "Nissan Maxima", "vehicle_year_make_model": "2018 Nissan Maxima", "vehicle_year_make_model_cat": "2018 Nissan Maxima (Sedan)"}
# Retrieved data from transaction c4cc769135374745693eaeb44ee772fc4f0bd51545cb5a791b519e150e12e50c: {"vin": "CAYZWYKY426SZWFDN", "license_plate": "BJ74 PTU", "vehicle_make": "Nissan", "vehicle_model": "Rogue", "vehicle_year": 2018, "full_vehicleInfo": {"Year": 2018, "Make": "Nissan", "Model": "Rogue", "Category": "SUV"}, "vehicle_category": "SUV", "vehicle_make_model": "Nissan Rogue", "vehicle_year_make_model": "2018 Nissan Rogue", "vehicle_year_make_model_cat": "2018 Nissan Rogue (SUV)"}
# Retrieved data from transaction 80f3ca5e538ff294fa441fe7a23484f21507b2409e5104f552ea42a78bfe18c0: {"vin": "17U9GPSP33S4CPJ5R", "license_plate": "YR91ITV", "vehicle_make": "MAZDA", "vehicle_model": "Millenia", "vehicle_year": 2002, "full_vehicleInfo": {"Year": 2002, "Make": "MAZDA", "Model": "Millenia", "Category": "Sedan"}, "vehicle_category": "Sedan", "vehicle_make_model": "MAZDA Millenia", "vehicle_year_make_model": "2002 MAZDA Millenia", "vehicle_year_make_model_cat": "2002 MAZDA Millenia (Sedan)"}
# Retrieved data from transaction 96d4c3694bf19dc099431968c91190a31e80a67c7d395322df892b85b6e57ee1: {"vin": "97SPMP0C2ZSZ3339M", "license_plate": "QO25ETQ", "vehicle_make": "BMW", "vehicle_model": "X3", "vehicle_year": 2010, "full_vehicleInfo": {"Year": 2010, "Make": "BMW", "Model": "X3", "Category": "SUV"}, "vehicle_category": "SUV", "vehicle_make_model": "BMW X3", "vehicle_year_make_model": "2010 BMW X3", "vehicle_year_make_model_cat": "2010 BMW X3 (SUV)"}
# Retrieved data from transaction 6411da525b717996ae1771942e7266f05f6be4d3f2f74425ed6aec48f9659d22: {"vin": "LASKMZZY4KX2PM8TK", "license_plate": "TP99 IUZ", "vehicle_make": "Ford", "vehicle_model": "Expedition EL", "vehicle_year": 2016, "full_vehicleInfo": {"Year": 2016, "Make": "Ford", "Model": "Expedition EL", "Category": "SUV"}, "vehicle_category": "SUV", "vehicle_make_model": "Ford Expedition EL", "vehicle_year_make_model": "2016 Ford Expedition EL", "vehicle_year_make_model_cat": "2016 Ford Expedition EL (SUV)"}
# Retrieved data from transaction 0f95513fd8c786550ce67868013aae57b88c12a32734d0a82b18974b9921a860: {"vin": "E4XAR0F338C2VLT0T", "license_plate": "NQ02 YTP", "vehicle_make": "Toyota", "vehicle_model": "Highlander", "vehicle_year": 2004, "full_vehicleInfo": {"Year": 2004, "Make": "Toyota", "Model": "Highlander", "Category": "SUV"}, "vehicle_category": "SUV", "vehicle_make_model": "Toyota Highlander", "vehicle_year_make_model": "2004 Toyota Highlander", "vehicle_year_make_model_cat": "2004 Toyota Highlander (SUV)"}
# Retrieved data from transaction 0a94940e999bd6c3cec271fd4f94dbdc43faed0d89ada8fbc13fe8d7f0039395: {"vin": "DLXRLBWM5NGXCFHKE", "license_plate": "YJ75WGW", "vehicle_make": "BMW", "vehicle_model": "X1", "vehicle_year": 2014, "full_vehicleInfo": {"Year": 2014, "Make": "BMW", "Model": "X1", "Category": "SUV"}, "vehicle_category": "SUV", "vehicle_make_model": "BMW X1", "vehicle_year_make_model": "2014 BMW X1", "vehicle_year_make_model_cat": "2014 BMW X1 (SUV)"}
# Retrieved data from transaction 084a83b43be9ed67aaca712f16684ef99060299d46823e35e1d0e33c8ee9d14a: {"vin": "XNHJ8RSN80J3J6NVG", "license_plate": "GG42RIR", "vehicle_make": "Subaru", "vehicle_model": "Legacy", "vehicle_year": 1995, "full_vehicleInfo": {"Year": 1995, "Make": "Subaru", "Model": "Legacy", "Category": "Sedan, Wagon"}, "vehicle_category": "Sedan, Wagon", "vehicle_make_model": "Subaru Legacy", "vehicle_year_make_model": "1995 Subaru Legacy", "vehicle_year_make_model_cat": "1995 Subaru Legacy (Sedan, Wagon)"}
# Retrieved data from transaction 7176b290ad36d8ced0734db5f3a38f063aecc4a948c965c77b6c75509674ae79: {"vin": "7FF4EE472TMX791AT", "license_plate": "PU54GYJ", "vehicle_make": "Dodge", "vehicle_model": "Sprinter 2500 Cargo", "vehicle_year": 2006, "full_vehicleInfo": {"Year": 2006, "Make": "Dodge", "Model": "Sprinter 2500 Cargo", "Category": "Van/Minivan"}, "vehicle_category": "Van/Minivan", "vehicle_make_model": "Dodge Sprinter 2500 Cargo", "vehicle_year_make_model": "2006 Dodge Sprinter 2500 Cargo", "vehicle_year_make_model_cat": "2006 Dodge Sprinter 2500 Cargo (Van/Minivan)"}
# Retrieved data from transaction 929a79074d4ac4bcd54b67912396ae251eef3fe5eba8f417dd943385824a751d: {"vin": "46E3BTB33SYBJ31K7", "license_plate": "JO72URQ", "vehicle_make": "Suzuki", "vehicle_model": "Samurai", "vehicle_year": 1994, "full_vehicleInfo": {"Year": 1994, "Make": "Suzuki", "Model": "Samurai", "Category": "SUV"}, "vehicle_category": "SUV", "vehicle_make_model": "Suzuki Samurai", "vehicle_year_make_model": "1994 Suzuki Samurai", "vehicle_year_make_model_cat": "1994 Suzuki Samurai (SUV)"}
# Retrieved data from transaction 3d284779ddf5769a83e562d5a2e9debcbeecb026278e8541c76d7f3a80789b79: {"vin": "ZWHC8MAW2GB1MJCBS", "license_plate": "QK12CMV", "vehicle_make": "Mercedes-Benz", "vehicle_model": "S-Class", "vehicle_year": 1996, "full_vehicleInfo": {"Year": 1996, "Make": "Mercedes-Benz", "Model": "S-Class", "Category": "Sedan, Coupe"}, "vehicle_category": "Sedan, Coupe", "vehicle_make_model": "Mercedes-Benz S-Class", "vehicle_year_make_model": "1996 Mercedes-Benz S-Class", "vehicle_year_make_model_cat": "1996 Mercedes-Benz S-Class (Sedan, Coupe)"}
# Retrieved data from transaction 6c2a32d375178054a26c5070d844f2b74714d2137251479f36a2829de7dfa534: {"vin": "9XLF1GRF3VHMK1GPF", "license_plate": "VD68 OJF", "vehicle_make": "Toyota", "vehicle_model": "RAV4 Hybrid", "vehicle_year": 2018, "full_vehicleInfo": {"Year": 2018, "Make": "Toyota", "Model": "RAV4 Hybrid", "Category": "SUV"}, "vehicle_category": "SUV", "vehicle_make_model": "Toyota RAV4 Hybrid", "vehicle_year_make_model": "2018 Toyota RAV4 Hybrid", "vehicle_year_make_model_cat": "2018 Toyota RAV4 Hybrid (SUV)"}
# Retrieved data from transaction d3015d48720d0f911f7067f785f4a61d85c87ca3f2d88fc98a548e819331a8ce: {"vin": "K8JPEE9X30WPTXDF6", "license_plate": "QW10LCS", "vehicle_make": "Volvo", "vehicle_model": "XC60", "vehicle_year": 2013, "full_vehicleInfo": {"Year": 2013, "Make": "Volvo", "Model": "XC60", "Category": "SUV"}, "vehicle_category": "SUV", "vehicle_make_model": "Volvo XC60", "vehicle_year_make_model": "2013 Volvo XC60", "vehicle_year_make_model_cat": "2013 Volvo XC60 (SUV)"}
# Retrieved data from transaction 9218f257cdce069244b5af06cd8db13e708841a3ae12afac5ac546c2ea1c82b4: {"vin": "ZC0ALV8DXY6ZV4W9Z", "license_plate": "OS40BRO", "vehicle_make": "Dodge", "vehicle_model": "Challenger", "vehicle_year": 2009, "full_vehicleInfo": {"Year": 2009, "Make": "Dodge", "Model": "Challenger", "Category": "Coupe"}, "vehicle_category": "Coupe", "vehicle_make_model": "Dodge Challenger", "vehicle_year_make_model": "2009 Dodge Challenger", "vehicle_year_make_model_cat": "2009 Dodge Challenger (Coupe)"}
# ...
# Retrieved data from transaction b828ecdd0e5cee97bec1a78e47fbd5f01479faddf5d59e3eba1d545d2c79e869: {"vin": "3AJEVKHH35YAEHNUM", "license_plate": "QM90 SIO", "vehicle_make": "Volkswagen", "vehicle_model": "Passat", "vehicle_year": 1994, "full_vehicleInfo": {"Year": 1994, "Make": "Volkswagen", "Model": "Passat", "Category": "Sedan, Wagon"}, "vehicle_category": "Sedan, Wagon", "vehicle_make_model": "Volkswagen Passat", "vehicle_year_make_model": "1994 Volkswagen Passat", "vehicle_year_make_model_cat": "1994 Volkswagen Passat (Sedan, Wagon)"}
# Retrieved data from transaction c979d82b64d2384351883636f32e1c50391464d616b6c34d3a4c7884ea22f586: {"vin": "ANJPER9T43HWBCUH5", "license_plate": "AT55 KHQ", "vehicle_make": "GMC", "vehicle_model": "Yukon", "vehicle_year": 2000, "full_vehicleInfo": {"Year": 2000, "Make": "GMC", "Model": "Yukon", "Category": "SUV"}, "vehicle_category": "SUV", "vehicle_make_model": "GMC Yukon", "vehicle_year_make_model": "2000 GMC Yukon", "vehicle_year_make_model_cat": "2000 GMC Yukon (SUV)"}
# Retrieved data from transaction 2d78641137f0fa8540a7209d5feb92766e8d85b530df528debbfb539b221135d: {"vin": "XHB6SHFL223EX5GU4", "license_plate": "PU14UNX", "vehicle_make": "Toyota", "vehicle_model": "Tundra CrewMax", "vehicle_year": 2014, "full_vehicleInfo": {"Year": 2014, "Make": "Toyota", "Model": "Tundra CrewMax", "Category": "Pickup"}, "vehicle_category": "Pickup", "vehicle_make_model": "Toyota Tundra CrewMax", "vehicle_year_make_model": "2014 Toyota Tundra CrewMax", "vehicle_year_make_model_cat": "2014 Toyota Tundra CrewMax (Pickup)"}
# Retrieved data from transaction 8f63d9d48ff6e3fac26946a6e12858c6bb6a51adfc6fbb325ad56aa0fa1840cf: {"vin": "EWZGHDW49SR6VNTGT", "license_plate": "EV68MYH", "vehicle_make": "Lexus", "vehicle_model": "RX", "vehicle_year": 1999, "full_vehicleInfo": {"Year": 1999, "Make": "Lexus", "Model": "RX", "Category": "SUV"}, "vehicle_category": "SUV", "vehicle_make_model": "Lexus RX", "vehicle_year_make_model": "1999 Lexus RX", "vehicle_year_make_model_cat": "1999 Lexus RX (SUV)"}
# Retrieved data from transaction 36f3267f6182f97ab3a5fa24ebf767b84d34514fb5014d332f7aa7a2a86f80c4: {"vin": "5PK6P3400VXA81KM3", "license_plate": "UR35MAJ", "vehicle_make": "Subaru", "vehicle_model": "XV Crosstrek", "vehicle_year": 2014, "full_vehicleInfo": {"Year": 2014, "Make": "Subaru", "Model": "XV Crosstrek", "Category": "SUV"}, "vehicle_category": "SUV", "vehicle_make_model": "Subaru XV Crosstrek", "vehicle_year_make_model": "2014 Subaru XV Crosstrek", "vehicle_year_make_model_cat": "2014 Subaru XV Crosstrek (SUV)"}
# Retrieved data from transaction bd994a2a0af143ce6e467974d02a023dbfe8a35a3123b468ca92d28786eb76aa: {"vin": "TU3M3EFV1HUZFD2SX", "license_plate": "VG18AMP", "vehicle_make": "Audi", "vehicle_model": "A7", "vehicle_year": 2019, "full_vehicleInfo": {"Year": 2019, "Make": "Audi", "Model": "A7", "Category": "Sedan"}, "vehicle_category": "Sedan", "vehicle_make_model": "Audi A7", "vehicle_year_make_model": "2019 Audi A7", "vehicle_year_make_model_cat": "2019 Audi A7 (Sedan)"}
# Retrieved data from transaction 27aa1a5336618bd87056fd08c868847e444d0437ae6a63b4ef18dd7900765dab: {"vin": "9BBTTXH692ZVZZUMD", "license_plate": "VT73ZBM", "vehicle_make": "Ferrari", "vehicle_model": "599 GTB Fiorano", "vehicle_year": 2011, "full_vehicleInfo": {"Year": 2011, "Make": "Ferrari", "Model": "599 GTB Fiorano", "Category": "Coupe"}, "vehicle_category": "Coupe", "vehicle_make_model": "Ferrari 599 GTB Fiorano", "vehicle_year_make_model": "2011 Ferrari 599 GTB Fiorano", "vehicle_year_make_model_cat": "2011 Ferrari 599 GTB Fiorano (Coupe)"}
# Retrieved data from transaction b4e2141cef5a36d0a8545df3a8121a9c348859c46cf413125555481b4d22a3d4: {"vin": "TDKAZZXS02LL2K998", "license_plate": "BI18URN", "vehicle_make": "MAZDA", "vehicle_model": "MX-5 Miata", "vehicle_year": 1996, "full_vehicleInfo": {"Year": 1996, "Make": "MAZDA", "Model": "MX-5 Miata", "Category": "Convertible"}, "vehicle_category": "Convertible", "vehicle_make_model": "MAZDA MX-5 Miata", "vehicle_year_make_model": "1996 MAZDA MX-5 Miata", "vehicle_year_make_model_cat": "1996 MAZDA MX-5 Miata (Convertible)"}
# Retrieved data from transaction f6b86b8d54b239b32caedd31d2b9c71517aa58fa6c82757a07bf5b49847b3ea7: {"vin": "SV2TSDB415SA1XCBZ", "license_plate": "VS18 RFP", "vehicle_make": "Buick", "vehicle_model": "Rendezvous", "vehicle_year": 2006, "full_vehicleInfo": {"Year": 2006, "Make": "Buick", "Model": "Rendezvous", "Category": "SUV"}, "vehicle_category": "SUV", "vehicle_make_model": "Buick Rendezvous", "vehicle_year_make_model": "2006 Buick Rendezvous", "vehicle_year_make_model_cat": "2006 Buick Rendezvous (SUV)"}
# Retrieved data from transaction 8516694c8a432051a65f722daaf8a40b07dbda9d4896cca65786705d30c191dd: {"vin": "0TLDEW6W91UKGASJA", "license_plate": "GW31 WSR", "vehicle_make": "Lexus", "vehicle_model": "RX", "vehicle_year": 2017, "full_vehicleInfo": {"Year": 2017, "Make": "Lexus", "Model": "RX", "Category": "SUV"}, "vehicle_category": "SUV", "vehicle_make_model": "Lexus RX", "vehicle_year_make_model": "2017 Lexus RX", "vehicle_year_make_model_cat": "2017 Lexus RX (SUV)"}
# Retrieved data from transaction 409e614c289793b72e51eebf9065936f3633656e0d73ec3d9f302380ed10ac3e: {"vin": "FLK28JNT1V2RB5MVC", "license_plate": "LI43 TQF", "vehicle_make": "Buick", "vehicle_model": "Enclave", "vehicle_year": 2011, "full_vehicleInfo": {"Year": 2011, "Make": "Buick", "Model": "Enclave", "Category": "SUV"}, "vehicle_category": "SUV", "vehicle_make_model": "Buick Enclave", "vehicle_year_make_model": "2011 Buick Enclave", "vehicle_year_make_model_cat": "2011 Buick Enclave (SUV)"}
# Retrieved data from transaction 1a4678ededa362fbc3da7b67ebba6b46414bbb965c441085db78396d18d0c1ef: {"vin": "ZHF405W88TXZ1RRHE", "license_plate": "KU01 QSY", "vehicle_make": "Isuzu", "vehicle_model": "Trooper", "vehicle_year": 1998, "full_vehicleInfo": {"Year": 1998, "Make": "Isuzu", "Model": "Trooper", "Category": "SUV"}, "vehicle_category": "SUV", "vehicle_make_model": "Isuzu Trooper", "vehicle_year_make_model": "1998 Isuzu Trooper", "vehicle_year_make_model_cat": "1998 Isuzu Trooper (SUV)"}
# Retrieved data from transaction 9a7d57e5993a886cd292a6801b17c988bd11bb7e50e813c6c329a47c845c5f2c: {"vin": "RG0Z6M1C5V38X40TK", "license_plate": "OB80 GAQ", "vehicle_make": "Porsche", "vehicle_model": "Cayenne", "vehicle_year": 2010, "full_vehicleInfo": {"Year": 2010, "Make": "Porsche", "Model": "Cayenne", "Category": "SUV"}, "vehicle_category": "SUV", "vehicle_make_model": "Porsche Cayenne", "vehicle_year_make_model": "2010 Porsche Cayenne", "vehicle_year_make_model_cat": "2010 Porsche Cayenne (SUV)"}
# Retrieved data from transaction 25f988cc75909678078c5012897916bd1aac84ab5900eeb8e204ad1a3bac0778: {"vin": "5WAS0ATB6JKL22W0Z", "license_plate": "SF41UUO", "vehicle_make": "Dodge", "vehicle_model": "Ram Van 1500", "vehicle_year": 2003, "full_vehicleInfo": {"Year": 2003, "Make": "Dodge", "Model": "Ram Van 1500", "Category": "Van/Minivan"}, "vehicle_category": "Van/Minivan", "vehicle_make_model": "Dodge Ram Van 1500", "vehicle_year_make_model": "2003 Dodge Ram Van 1500", "vehicle_year_make_model_cat": "2003 Dodge Ram Van 1500 (Van/Minivan)"}
# Retrieved data from transaction e0e2364397e4fe39ecfed680eeccf2b8796fd0ca2ada9e8dc052d5f97980d521: {"vin": "5T1U8R8A4XSS91392", "license_plate": "TD26 OBU", "vehicle_make": "Toyota", "vehicle_model": "MR2", "vehicle_year": 2004, "full_vehicleInfo": {"Year": 2004, "Make": "Toyota", "Model": "MR2", "Category": "Convertible"}, "vehicle_category": "Convertible", "vehicle_make_model": "Toyota MR2", "vehicle_year_make_model": "2004 Toyota MR2", "vehicle_year_make_model_cat": "2004 Toyota MR2 (Convertible)"}
# Retrieved data from transaction a39252276984b273cee6550b88fea362b7ff664db926b14b1c42a9e5bcc516e8: {"vin": "CGHHDLRB6GMY16B1J", "license_plate": "JF69 VLG", "vehicle_make": "Acura", "vehicle_model": "ILX", "vehicle_year": 2014, "full_vehicleInfo": {"Year": 2014, "Make": "Acura", "Model": "ILX", "Category": "Sedan"}, "vehicle_category": "Sedan", "vehicle_make_model": "Acura ILX", "vehicle_year_make_model": "2014 Acura ILX", "vehicle_year_make_model_cat": "2014 Acura ILX (Sedan)"}
# Retrieved data from transaction 7a565b5e69838087c1a67f1195fc67beeb57f155e970a0e505b30e3836ff981d: {"vin": "260EWPF18BHVS4FRV", "license_plate": "EY52 JHM", "vehicle_make": "Honda", "vehicle_model": "Odyssey", "vehicle_year": 1998, "full_vehicleInfo": {"Year": 1998, "Make": "Honda", "Model": "Odyssey", "Category": "Van/Minivan"}, "vehicle_category": "Van/Minivan", "vehicle_make_model": "Honda Odyssey", "vehicle_year_make_model": "1998 Honda Odyssey", "vehicle_year_make_model_cat": "1998 Honda Odyssey (Van/Minivan)"}
# Retrieved data from transaction f3abd323797cd56def61a770589dca8074f9c72cc2f5c06432627b7400e810d3: {"vin": "K3NNEUGZ26VPH2FSH", "license_plate": "DL73 WSO", "vehicle_make": "Ford", "vehicle_model": "F350 Crew Cab", "vehicle_year": 1993, "full_vehicleInfo": {"Year": 1993, "Make": "Ford", "Model": "F350 Crew Cab", "Category": "Pickup"}, "vehicle_category": "Pickup", "vehicle_make_model": "Ford F350 Crew Cab", "vehicle_year_make_model": "1993 Ford F350 Crew Cab", "vehicle_year_make_model_cat": "1993 Ford F350 Crew Cab (Pickup)"}
# Retrieved data from transaction 5a3304297b98b3c2f7bcbe57bfacf94efac947c1a21863bce340adfb9d31342b: {"vin": "PHST0C9EXU3RSWTJ5", "license_plate": "LS22 JSP", "vehicle_make": "Ferrari", "vehicle_model": "458 Spider", "vehicle_year": 2014, "full_vehicleInfo": {"Year": 2014, "Make": "Ferrari", "Model": "458 Spider", "Category": "Convertible"}, "vehicle_category": "Convertible", "vehicle_make_model": "Ferrari 458 Spider", "vehicle_year_make_model": "2014 Ferrari 458 Spider", "vehicle_year_make_model_cat": "2014 Ferrari 458 Spider (Convertible)"}
# Retrieved data from transaction 7d138ad50161d2aadce66e2b16f6b34f759243922acc28296ff1ffbb1c0a3734: {"vin": "4GBRBAT931RTS5WTB", "license_plate": "LM29 TST", "vehicle_make": "Volvo", "vehicle_model": "XC60", "vehicle_year": 2017, "full_vehicleInfo": {"Year": 2017, "Make": "Volvo", "Model": "XC60", "Category": "SUV"}, "vehicle_category": "SUV", "vehicle_make_model": "Volvo XC60", "vehicle_year_make_model": "2017 Volvo XC60", "vehicle_year_make_model_cat": "2017 Volvo XC60 (SUV)"}
# Retrieved data from transaction 0c0a7ef36314d61042dac611733d15bb277030e5ea7fecdec49a75a3656837b6: {"vin": "FDLXSZWYXVBPU1K8F", "license_plate": "QF49BQZ", "vehicle_make": "Ford", "vehicle_model": "Escape", "vehicle_year": 2003, "full_vehicleInfo": {"Year": 2003, "Make": "Ford", "Model": "Escape", "Category": "SUV"}, "vehicle_category": "SUV", "vehicle_make_model": "Ford Escape", "vehicle_year_make_model": "2003 Ford Escape", "vehicle_year_make_model_cat": "2003 Ford Escape (SUV)"}
# Retrieved data from transaction 1cff58420b7ef3c836bd3887ee6e8f094dcd5032abd63fd4c85efa641ed978b0: {"vin": "F7LCC6099S1215JK4", "license_plate": "ME14TXX", "vehicle_make": "Maserati", "vehicle_model": "Coupe", "vehicle_year": 2005, "full_vehicleInfo": {"Year": 2005, "Make": "Maserati", "Model": "Coupe", "Category": "Coupe"}, "vehicle_category": "Coupe", "vehicle_make_model": "Maserati Coupe", "vehicle_year_make_model": "2005 Maserati Coupe", "vehicle_year_make_model_cat": "2005 Maserati Coupe (Coupe)"}
# Retrieved data from transaction f62691f31c7921bd452dda7af5189db6e863635b56cc35b179973e611c5d74c2: {"vin": "E3J5DK827DYL0X93U", "license_plate": "VM24JFX", "vehicle_make": "Buick", "vehicle_model": "Encore", "vehicle_year": 2020, "full_vehicleInfo": {"Year": 2020, "Make": "Buick", "Model": "Encore", "Category": "SUV"}, "vehicle_category": "SUV", "vehicle_make_model": "Buick Encore", "vehicle_year_make_model": "2020 Buick Encore", "vehicle_year_make_model_cat": "2020 Buick Encore (SUV)"}
# Retrieved data from transaction 05fb05fd92cc694075a97c67ebcbdad1d87144d202a3946b357e1dbbe3e60c17: {"vin": "1M04BEME62YUU7GS9", "license_plate": "UL01 MRE", "vehicle_make": "Ford", "vehicle_model": "Expedition", "vehicle_year": 2007, "full_vehicleInfo": {"Year": 2007, "Make": "Ford", "Model": "Expedition", "Category": "SUV"}, "vehicle_category": "SUV", "vehicle_make_model": "Ford Expedition", "vehicle_year_make_model": "2007 Ford Expedition", "vehicle_year_make_model_cat": "2007 Ford Expedition (SUV)"}
# Retrieved data from transaction 2898afc7b9aa62fef1e0811a41c5b3d8eaa491bd7669b42f2de8cb8c91fdc560: {"vin": "XPF1VTT7XUMX0J1KF", "license_plate": "PI53DWF", "vehicle_make": "INFINITI", "vehicle_model": "I", "vehicle_year": 2003, "full_vehicleInfo": {"Year": 2003, "Make": "INFINITI", "Model": "I", "Category": "Sedan"}, "vehicle_category": "Sedan", "vehicle_make_model": "INFINITI I", "vehicle_year_make_model": "2003 INFINITI I", "vehicle_year_make_model_cat": "2003 INFINITI I (Sedan)"}
# Retrieved data from transaction 3eec8517f8682d3a398543c1bd0678891dfd9bdc20245c624775366afa2dccf8: {"vin": "5CXLS7147YYYCA5YN", "license_plate": "HN20 CYS", "vehicle_make": "Toyota", "vehicle_model": "RAV4", "vehicle_year": 2006, "full_vehicleInfo": {"Year": 2006, "Make": "Toyota", "Model": "RAV4", "Category": "SUV"}, "vehicle_category": "SUV", "vehicle_make_model": "Toyota RAV4", "vehicle_year_make_model": "2006 Toyota RAV4", "vehicle_year_make_model_cat": "2006 Toyota RAV4 (SUV)"}
# Retrieved data from transaction 2ba15e01a4d20c6c69e5f3698261d87e690250a53064dc18a3fb775b3caa0d23: {"vin": "0M5CXCDW53CKBJKHV", "license_plate": "RT76AYI", "vehicle_make": "Ford", "vehicle_model": "F350 Super Duty Super Cab", "vehicle_year": 2019, "full_vehicleInfo": {"Year": 2019, "Make": "Ford", "Model": "F350 Super Duty Super Cab", "Category": "Pickup"}, "vehicle_category": "Pickup", "vehicle_make_model": "Ford F350 Super Duty Super Cab", "vehicle_year_make_model": "2019 Ford F350 Super Duty Super Cab", "vehicle_year_make_model_cat": "2019 Ford F350 Super Duty Super Cab (Pickup)"}
# Retrieved data from transaction 3debb722fd89da894b5788dfd7f1b0da9eda404692933f98f7290b9c0d32d9cb: {"vin": "2VT9EL51XXTL55X3N", "license_plate": "PW89 HVF", "vehicle_make": "Audi", "vehicle_model": "S8", "vehicle_year": 2008, "full_vehicleInfo": {"Year": 2008, "Make": "Audi", "Model": "S8", "Category": "Sedan"}, "vehicle_category": "Sedan", "vehicle_make_model": "Audi S8", "vehicle_year_make_model": "2008 Audi S8", "vehicle_year_make_model_cat": "2008 Audi S8 (Sedan)"}
# Retrieved data from transaction fd4fc04eae60f5411cd6c468c15deff1773ffbd074e86557a66b9bc8b11af7fc: {"vin": "N6HNRCG325NZ1NN67", "license_plate": "OI96IWZ", "vehicle_make": "Volkswagen", "vehicle_model": "Corrado", "vehicle_year": 1994, "full_vehicleInfo": {"Year": 1994, "Make": "Volkswagen", "Model": "Corrado", "Category": "Coupe"}, "vehicle_category": "Coupe", "vehicle_make_model": "Volkswagen Corrado", "vehicle_year_make_model": "1994 Volkswagen Corrado", "vehicle_year_make_model_cat": "1994 Volkswagen Corrado (Coupe)"}
# Retrieved data from transaction dcd1c61259b9c7f1fa7ff736d630f31a2262c68681ff8f220276277d474652a8: {"vin": "PF8S4YX134J1F1KLK", "license_plate": "RI98 AYH", "vehicle_make": "MAZDA", "vehicle_model": "MX-6", "vehicle_year": 1996, "full_vehicleInfo": {"Year": 1996, "Make": "MAZDA", "Model": "MX-6", "Category": "Coupe"}, "vehicle_category": "Coupe", "vehicle_make_model": "MAZDA MX-6", "vehicle_year_make_model": "1996 MAZDA MX-6", "vehicle_year_make_model_cat": "1996 MAZDA MX-6 (Coupe)"}
# Retrieved data from transaction f704a74aff47be83a4e00102c3d41b24f0429d42da6b61c19e45130fd45f65ca: {"vin": "0B62DRSA33FZPSH2V", "license_plate": "EM51 KFT", "vehicle_make": "Land Rover", "vehicle_model": "Range Rover", "vehicle_year": 2014, "full_vehicleInfo": {"Year": 2014, "Make": "Land Rover", "Model": "Range Rover", "Category": "SUV"}, "vehicle_category": "SUV", "vehicle_make_model": "Land Rover Range Rover", "vehicle_year_make_model": "2014 Land Rover Range Rover", "vehicle_year_make_model_cat": "2014 Land Rover Range Rover (SUV)"}

# %% [markdown]
# # Testing

# %% [markdown]
# ## Test 1 - fetch data from blockchain

# %%
# Retrieve the latest record for a specific VIN
vin = "82HFE9767U326DEZ2"
latest_record = get_latest_record(vin, w3)
print(f"Latest record for VIN {vin}: {latest_record}")
# Out:
# Latest record for VIN 82HFE9767U326DEZ2: {'vin': '82HFE9767U326DEZ2', 'license_plate': 'WU37 WRN', 'vehicle_make': 'Mitsubishi', 'vehicle_model': 'Montero', 'vehicle_year': 1999, 'full_vehicleInfo': {'Year': 1999, 'Make': 'Mitsubishi', 'Model': 'Montero', 'Category': 'SUV'}, 'vehicle_category': 'SUV', 'vehicle_make_model': 'Mitsubishi Montero', 'vehicle_year_make_model': '1999 Mitsubishi Montero', 'vehicle_year_make_model_cat': '1999 Mitsubishi Montero (SUV)'}

# %%
# Retrieve the latest record for a specific VIN
vin = "H1AUMH0D9M76R7NNG"
latest_record = get_latest_record(vin, w3)
print(f"Latest record for VIN {vin}: {latest_record}")
# Out:
# Latest record for VIN H1AUMH0D9M76R7NNG: {'vin': 'H1AUMH0D9M76R7NNG', 'license_plate': 'XO18 RDM', 'vehicle_make': 'Ferrari', 'vehicle_model': '612 Scaglietti', 'vehicle_year': 2006, 'full_vehicleInfo': {'Year': 2006, 'Make': 'Ferrari', 'Model': '612 Scaglietti', 'Category': 'Coupe'}, 'vehicle_category': 'Coupe', 'vehicle_make_model': 'Ferrari 612 Scaglietti', 'vehicle_year_make_model': '2006 Ferrari 612 Scaglietti', 'vehicle_year_make_model_cat': '2006 Ferrari 612 Scaglietti (Coupe)'}

# %%
# Retrieve the latest record for a specific VIN
vin = "JPC53EJ63E7RHWPAP"
latest_record = get_latest_record(vin, w3)
print(f"Latest record for VIN {vin}: {latest_record}")
# Out:
# Latest record for VIN JPC53EJ63E7RHWPAP: {'vin': 'JPC53EJ63E7RHWPAP', 'license_plate': 'GV19IWV', 'vehicle_make': 'GMC', 'vehicle_model': 'Envoy', 'vehicle_year': 2002, 'full_vehicleInfo': {'Year': 2002, 'Make': 'GMC', 'Model': 'Envoy', 'Category': 'SUV'}, 'vehicle_category': 'SUV', 'vehicle_make_model': 'GMC Envoy', 'vehicle_year_make_model': '2002 GMC Envoy', 'vehicle_year_make_model_cat': '2002 GMC Envoy (SUV)'}

# %%
# Retrieve the latest record for a specific VIN
license_plate = "GV19IWV"
latest_record = get_latest_record(license_plate, w3, "license_plate")
print(f"Latest record for license plate {license_plate}: {latest_record}")
# Out:
# Latest record for license plate GV19IWV: {'vin': 'JPC53EJ63E7RHWPAP', 'license_plate': 'GV19IWV', 'vehicle_make': 'GMC', 'vehicle_model': 'Envoy', 'vehicle_year': 2002, 'full_vehicleInfo': {'Year': 2002, 'Make': 'GMC', 'Model': 'Envoy', 'Category': 'SUV'}, 'vehicle_category': 'SUV', 'vehicle_make_model': 'GMC Envoy', 'vehicle_year_make_model': '2002 GMC Envoy', 'vehicle_year_make_model_cat': '2002 GMC Envoy (SUV)'}

# %% [markdown]
# ## Test 2 - update the record and get the updated version

# %%
# Example Usage
# Append updated record to blockchain
updated_record = {
    "vin": "82HFE9767U326DEZ2",
    "license_plate": "WU37 WRN",
    "vehicle_make": "Mitsubishi",
    "vehicle_model": "Outlander",
    "vehicle_year": 2000,
    "full_vehicleInfo": {
        "Year": 2000,
        "Make": "Mitsubishi",
        "Model": "Outlander",
        "Category": "SUV"
    },
    "vehicle_category": "SUV",
    "vehicle_make_model": "Mitsubishi Outlander",
    "vehicle_year_make_model": "2000 Mitsubishi Outlander",
    "vehicle_year_make_model_cat": "2000 Mitsubishi Outlander (SUV)"
}

tx_hash = append_data_to_blockchain(updated_record, Web3, account, w3)
print(f"Updated record added to blockchain with transaction hash: {tx_hash.hex()}")
# Out:
# Updated record added to blockchain with transaction hash: c2e973d4959f1945ad27e254b3d46bed7bf4c09fb4ffb739eadbc331d8b16407

# %%
# Retrieve the latest record for a specific VIN
vin = "82HFE9767U326DEZ2"
latest_record = get_latest_record(vin, w3)
print(f"Latest record for VIN {vin}: {latest_record}")
# Out:
# Latest record for VIN 82HFE9767U326DEZ2: {'vin': '82HFE9767U326DEZ2', 'license_plate': 'WU37 WRN', 'vehicle_make': 'Mitsubishi', 'vehicle_model': 'Outlander', 'vehicle_year': 2000, 'full_vehicleInfo': {'Year': 2000, 'Make': 'Mitsubishi', 'Model': 'Outlander', 'Category': 'SUV'}, 'vehicle_category': 'SUV', 'vehicle_make_model': 'Mitsubishi Outlander', 'vehicle_year_make_model': '2000 Mitsubishi Outlander', 'vehicle_year_make_model_cat': '2000 Mitsubishi Outlander (SUV)'}

# %% [markdown]
# ## Test 3 - Get historical data to see updates

# %%
vin = "82HFE9767U326DEZ2"
get_record_history(w3, vin)
# Out:
# [{'vin': '82HFE9767U326DEZ2',
#   'license_plate': 'WU37 WRN',
#   'vehicle_make': 'Mitsubishi',
#   'vehicle_model': 'Montero',
#   'vehicle_year': 1999,
#   'full_vehicleInfo': {'Year': 1999,
#    'Make': 'Mitsubishi',
#    'Model': 'Montero',
#    'Category': 'SUV'},
#   'vehicle_category': 'SUV',
#   'vehicle_make_model': 'Mitsubishi Montero',
#   'vehicle_year_make_model': '1999 Mitsubishi Montero',
#   'vehicle_year_make_model_cat': '1999 Mitsubishi Montero (SUV)'},
#  {'vin': '82HFE9767U326DEZ2',
#   'license_plate': 'WU37 WRN',
#   'vehicle_make': 'Mitsubishi',
#   'vehicle_model': 'Outlander',
#   'vehicle_year': 2000,
#   'full_vehicleInfo': {'Year': 2000,
#    'Make': 'Mitsubishi',
#    'Model': 'Outlander',
#    'Category': 'SUV'},
#   'vehicle_category': 'SUV',
#   'vehicle_make_model': 'Mitsubishi Outlander',
#   'vehicle_year_make_model': '2000 Mitsubishi Outlander',
#   'vehicle_year_make_model_cat': '2000 Mitsubishi Outlander (SUV)'}]

# %% [markdown]
# # Other
